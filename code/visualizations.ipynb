# %% [markdown]
# # Visualizations

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/recipes_cleaned.csv')
df.head()
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 1  No Bake Espresso Martini Cheesecakes
# 2                         Blackout Cake
# 3           Sleeping Gingerbread Treats
# 4        Little Debbie Brownie Tree Dip
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 1  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 2  Blackout cake is a moist and tender cake with ...       40.0       20.0
# 3                            Shhhh they're sleeping!       15.0       15.0
# 4  Turn your favorite sweet treat into the best h...       15.0        NaN
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 1          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 2         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
# 3          30       9.0  https://www.allrecipes.com/sleeping-gingerbrea...
# 4         135       6.0  https://www.allrecipes.com/little-debbie-brown...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 1      1058   65    113       10
# 2       824   55     80        9
# 3       231   12     29        3
# 4       534   31     61        6
#
#                                  cleaned_ingredients
# 0  ['butter', 'white sugar', 'chocolate graham cr...
# 1  ['chocolate chips', 'cremefilled chocolate coo...
# 2  ['cooking spray', 'allpurpose flour', 'white s...
# 3  ['puff pastry', 'chocolate squares', 'gingerbr...
# 4  ['little debbie® christmas tree brownies', 'cr...

# %% [markdown]
# ### Look into prep_time

# %%
# Max
df['prep_time'].max()
# Out:
# 300.0

# %%
# Min
df['prep_time'].min()
# Out:
# 2.0

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['prep_time'])

# Add labels and title
plt.xlabel("Preparation Time (minutes)")
plt.title("Distribution of Recipe Preparation Times");

# %%
# There is an extreme outlier at 300 minutes, and another around 120 minutes
df[df['prep_time'] == 300]

# Recipe is Pineapple Smoothie, I looked at the recipe on the website from url, the time is correct at 5 hours or 300 minutes
# I'm going to guess that the author is including the time it takes to freeze the fruit into prep_time
# Out:
#                    title                                              intro  \
# 1176  Pineapple Smoothie  A tropical pineapple smoothie made with fresh ...
#
#       prep_time  cook_time  total_time  servings  \
# 1176      300.0        NaN         300       2.0
#
#                                              recipe_url  calories  fat  carbs  \
# 1176  https://www.allrecipes.com/pineapple-smoothie-...       343   24     33
#
#       protein                                cleaned_ingredients
# 1176        4  ['pineapple', 'banana', 'coconut milk', 'cocon...

# %%
df[df['prep_time'] > 100]

# Recipe is S'mores Cupcakes, the prep time is correct, from the url it does say the recipe takes 2 hours of prep_time
# Out:
#                    title                                              intro  \
# 15      S'mores Cupcakes  These s'mores cupcakes take quite a bit of tim...
# 1176  Pineapple Smoothie  A tropical pineapple smoothie made with fresh ...
#
#       prep_time  cook_time  total_time  servings  \
# 15        120.0       40.0         160      18.0
# 1176      300.0        NaN         300       2.0
#
#                                              recipe_url  calories  fat  carbs  \
# 15    https://www.allrecipes.com/s-mores-cupcakes-re...       268   11     40
# 1176  https://www.allrecipes.com/pineapple-smoothie-...       343   24     33
#
#       protein                                cleaned_ingredients
# 15          3  ['graham cracker', 'unsalted butter', 'brown s...
# 1176        4  ['pineapple', 'banana', 'coconut milk', 'cocon...

# %% [markdown]
# ### Look into total_time

# %%
# Max
df['total_time'].max()
# Out:
# 5833

# %%
# Min
df['total_time'].min()
df['total_time'].mean()
# Out:
# 117.05614973262033

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['total_time'])

# Add labels and title
plt.xlabel("Total Time (minutes)")
plt.title("Distribution of Recipe Total Times");

# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['total_time'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Total Time per Recipe")
plt.ylabel("Number of Recipes")
plt.title("Distribution of Total Time")
# Out:
# Text(0.5, 1.0, 'Distribution of Total Time')

# %%
# There is a lot of spread regarding a recipes total time
# The most extreme recipes being above 2_500 mins
df[df['total_time'] > 2_500]
# Out:
#                                                 title  \
# 119                                 Roman-Style Pizza
# 1010  Philippine Longanisa de Eugenio (Sweet Sausage)
# 1257                                 Dry Brine Turkey
# 1261     Juicy Two-Stage Thanksgiving Turkey Marinade
# 1797                                     Homemade Lox
#
#                                                   intro  prep_time  cook_time  \
# 119   This Roman-style pizza has a long-fermented th...       30.0       45.0
# 1010  This Phillippine longanisa de Eugenio is for t...       45.0       28.0
# 1257  Dry brining, or pre-salting, is the easiest wa...       15.0      150.0
# 1261  This recipe has two different marinades that a...       25.0        NaN
# 1797  This homemade lox recipe takes some time to pr...       20.0        NaN
#
#       total_time  servings                                         recipe_url  \
# 119         3060      12.0  https://www.allrecipes.com/roman-style-pizza-r...
# 1010        5833      12.0  https://www.allrecipes.com/recipe/138109/phili...
# 1257        5055      15.0  https://www.allrecipes.com/recipe/245524/dry-b...
# 1261        2905      15.0  https://www.allrecipes.com/recipe/94543/juicy-...
# 1797        2930       8.0  https://www.allrecipes.com/recipe/254896/homem...
#
#       calories  fat  carbs  protein  \
# 119        413   20     39       17
# 1010       496   44      9       15
# 1257       684   32      1       92
# 1261       814   36     27       93
# 1797       120    3     13       10
#
#                                     cleaned_ingredients
# 119   ['bread flour', 'rounded yeast', 'water', 'gen...
# 1010  ['white sugar', 'salt', 'oregano', 'black pepp...
# 1257  ['turkey neck giblets', 'salt', 'black pepper'...
# 1261  ['salt', 'orange juice', 'brown sugar', 'gallo...
# 1797  ['salmon fillet bones', 'salt', 'white sugar',...

# %%
# After looking into each of the recipes on the webiste they are all valid recipes with correctly inputed information

# %% [markdown]
# ### Look into calories

# %%
# Max
df['calories'].max()
# Out:
# 4455

# %%
# Min
df['calories'].min()
df['calories'].mean()
# Out:
# 462.4433155080214

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['calories'])

# Add labels and title
plt.xlabel("Total Calories (kcal)")
plt.title("Distribution of a Recipe Total Calories");

# %%
# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['calories'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Calories per Serving")
plt.ylabel("Number of Recipes")
plt.title("Distribution of Recipe Calories");
# Out:
# Text(0.5, 1.0, 'Distribution of Recipe Calories')

# %%
# The most extreme recipes are 2_000 and above
df[df['calories'] >= 2_000]

# There are all valid recipes
# Out:
#                                       title  \
# 153                  Chicken Parmesan Pizza
# 735                   Café Tropical Burrito
# 897        Karaage (Japanese Fried Chicken)
# 937                        Cuban Crunchwrap
# 1089      Indian Tacos with Yeast Fry Bread
# 1368                 Low and Slow Prime Rib
# 1736                          Steak Burrito
# 1845  Boeuf en Croûte (Beef in Puff Pastry)
#
#                                                   intro  prep_time  cook_time  \
# 153   This pizza comes together in a flash and looks...        5.0       18.0
# 735   This breakfast burrito comes together quickly....        5.0       15.0
# 897   The only karaage recipe you'll ever need. Lear...       20.0       10.0
# 937   Try this Cuban crunchwrap with ham, cheese, po...        5.0        5.0
# 1089  My cousins grew up on a reservation in South D...       60.0       45.0
# 1368  The simplest, most fail-safe version for cooki...       15.0        NaN
# 1736  My husband grills ribeye steaks at least once ...       10.0        NaN
# 1845  This boeuf en croûte (beef in puff pastry) rec...       35.0       20.0
#
#       total_time  servings                                         recipe_url  \
# 153           23       4.0  https://www.allrecipes.com/chicken-parmesan-pi...
# 735           20       1.0  https://www.allrecipes.com/cafe-tropical-burri...
# 897          105       4.0  https://www.allrecipes.com/recipe/8325387/kara...
# 937           10       1.0  https://www.allrecipes.com/cuban-crunchwrap-re...
# 1089         105       6.0  https://www.allrecipes.com/recipe/222993/india...
# 1368        1555       4.0  https://www.allrecipes.com/recipe/8520971/low-...
# 1736          10       1.0  https://www.allrecipes.com/steak-burrito-recip...
# 1845         115       2.0  https://www.allrecipes.com/recipe/213512/boeuf...
#
#       calories  fat  carbs  protein  \
# 153       4455  105    746      117
# 735       2580   81    372       84
# 897       2263  226     32       29
# 937       2010   71    264       76
# 1089      2643  245     79       42
# 1368      2152  196      1       90
# 1736      2456   83    321      101
# 1845      3274  215    232       69
#
#                                     cleaned_ingredients
# 153   ['chicken nuggets', 'prebaked pizza crust', 'm...
# 735   ['bacon', 'hashbrown patty', 'eggs', 'cheddar ...
# 897   ['garlic', 'ginger', 'soy sauce', 'sake', 'mir...
# 937   ['flour tortilla', 'ham', 'pork', 'mustard', '...
# 1089  ['active yeast', 'white sugar', 'water', 'allp...
# 1368  ['prime rib', 'salt', 'unsalted butter', 'salt...
# 1736  ['flour tortilla', 'ribeye steak', 'mexican ri...
# 1845  ['olive oil', 'beef tenderloin', 'butter', 'wh...

# %% [markdown]
# ### Look into fat

# %%
# Max
df['fat'].max()
# Out:
# 245

# %%
# Min
df['fat'].min()
df['fat'].mean()
# Out:
# 24.519251336898396

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['fat'])

# Add labels and title
plt.xlabel("Total Fat (g)")
plt.title("Distribution of a Recipe Total Fat");

# %%
# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['fat'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Fats per Serving")
plt.ylabel("Number of Recipes")
plt.title("Distribution of Recipe Fats")
# Out:
# Text(0.5, 1.0, 'Distribution of Recipe Fats')

# %%
# The most extreme recipes being above 140
df[df['fat'] > 140]
# Out:
#                                        title  \
# 514   Ultimate Thanksgiving Leftovers Burger
# 897         Karaage (Japanese Fried Chicken)
# 1089       Indian Tacos with Yeast Fry Bread
# 1368                  Low and Slow Prime Rib
# 1375           Chef John's Perfect Prime Rib
# 1845   Boeuf en Croûte (Beef in Puff Pastry)
#
#                                                   intro  prep_time  cook_time  \
# 514   This ultimate Thanksgiving leftover burger is ...       15.0       10.0
# 897   The only karaage recipe you'll ever need. Lear...       20.0       10.0
# 1089  My cousins grew up on a reservation in South D...       60.0       45.0
# 1368  The simplest, most fail-safe version for cooki...       15.0        NaN
# 1375  Use my easy "mathematical method" for cooking ...       10.0      140.0
# 1845  This boeuf en croûte (beef in puff pastry) rec...       35.0       20.0
#
#       total_time  servings                                         recipe_url  \
# 514           25       4.0  https://www.allrecipes.com/ultimate-thanksgivi...
# 897          105       4.0  https://www.allrecipes.com/recipe/8325387/kara...
# 1089         105       6.0  https://www.allrecipes.com/recipe/222993/india...
# 1368        1555       4.0  https://www.allrecipes.com/recipe/8520971/low-...
# 1375         270       4.0  https://www.allrecipes.com/recipe/221958/chef-...
# 1845         115       2.0  https://www.allrecipes.com/recipe/213512/boeuf...
#
#       calories  fat  carbs  protein  \
# 514       1892  145    108       40
# 897       2263  226     32       29
# 1089      2643  245     79       42
# 1368      2152  196      1       90
# 1375      1757  161      1       73
# 1845      3274  215    232       69
#
#                                     cleaned_ingredients
# 514   ['leftover stuffing dressing', 'turkey gravy',...
# 897   ['garlic', 'ginger', 'soy sauce', 'sake', 'mir...
# 1089  ['active yeast', 'white sugar', 'water', 'allp...
# 1368  ['prime rib', 'salt', 'unsalted butter', 'salt...
# 1375  ['prime rib', 'unsalted butter', 'black pepper...
# 1845  ['olive oil', 'beef tenderloin', 'butter', 'wh...

# %% [markdown]
# ### Look into carbs column

# %%
# Max
df['carbs'].max()
# Out:
# 746

# %%
# Min
df['carbs'].min()
df['carbs'].mean()
# Out:
# 36.0620320855615

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['carbs'])

# Add labels and title
plt.xlabel("Total Carbs (grams)")
plt.title("Distribution of Carbs");

# %%
# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['carbs'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Carbs per Serving")
plt.ylabel("Number of Recipes")
plt.title("Distribution of Recipe Carbs")
# Out:
# Text(0.5, 1.0, 'Distribution of Recipe Carbs')

# %% [markdown]
# ### Look into protein column

# %%
# Max
df['protein'].max()
# Out:
# 137

# %%
# Min
df['protein'].min()
# Out:
# 0

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['protein'])

# Add labels and title
plt.xlabel("Total Protein (grams)")
plt.title("Distribution of Proteins");

# %%
# Plot the histogram
plt.figure(figsize=(12, 6))
sns.histplot(df['protein'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Protein per Serving")
plt.ylabel("Number of Recipes")
plt.title("Distribution of Recipe Protein")
# Out:
# Text(0.5, 1.0, 'Distribution of Recipe Protein')

# %%
# The most extreme recipes being above 120 grams
df[df['protein'] > 120]
# Out:
#                                   title  \
# 407     Dooky Chase-Style Fried Chicken
# 1248                   Gas Grill Turkey
# 1264         Smoked Whole Turkey Breast
# 1286             Guinness Chili for Two
# 1364  Italian Braised Beef and Potatoes
#
#                                                   intro  prep_time  cook_time  \
# 407   I'm going to show you my version of the famous...       20.0       20.0
# 1248  This turkey cooked on a gas grill comes out ju...       15.0      215.0
# 1264  Great as a main dish, with some yummy sides, o...       20.0      210.0
# 1286  This Guinness chili for two, inspired by the I...       20.0       90.0
# 1364  Italian braised beef and potatoes is one of my...       15.0      190.0
#
#       total_time  servings                                         recipe_url  \
# 407          765       4.0  https://www.allrecipes.com/dooky-chase-style-f...
# 1248         240       8.0  https://www.allrecipes.com/recipe/258726/gas-g...
# 1264         275       8.0  https://www.allrecipes.com/recipe/282204/smoke...
# 1286         110       2.0  https://www.allrecipes.com/guinness-chili-for-...
# 1364         205       4.0  https://www.allrecipes.com/italian-braised-bee...
#
#       calories  fat  carbs  protein  \
# 407       1763  110     49      135
# 1248      1422   93      2      137
# 1264       610    6      0      130
# 1286      1014   37     44      122
# 1364      1124   33     79      125
#
#                                     cleaned_ingredients
# 407   ['salt', 'black pepper', 'garlic powder', 'cay...
# 1248  ['turkey neck giblets', 'water', 'butter', 'sa...
# 1264  ['wood chips choice', 'water', 'turkey breast'...
# 1286  ['olive oil', 'bacon', 'salt black pepper', 'b...
# 1364  ['salt', 'black pepper', 'cayenne pepper', 'ol...
