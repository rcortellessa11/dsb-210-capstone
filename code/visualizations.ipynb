# %% [markdown]
# # Visualizations

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/recipes_cleaned.csv')
df.head()
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 1  No Bake Espresso Martini Cheesecakes
# 2                         Blackout Cake
# 3           Sleeping Gingerbread Treats
# 4        Little Debbie Brownie Tree Dip
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 1  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 2  Blackout cake is a moist and tender cake with ...       40.0       20.0
# 3                            Shhhh they're sleeping!       15.0       15.0
# 4  Turn your favorite sweet treat into the best h...       15.0        NaN
#
#    total_time  servings                                        ingredients  \
# 0         300      16.0  ['1/3 cup butter, melted', '1/4 cup white suga...
# 1          25       6.0  ['1 cup dark chocolate chips', '20 creme-fille...
# 2         135      12.0  ['cooking spray', '2 1/4 cups all-purpose flou...
# 3          30       9.0  ['1 sheet of prepared puff pastry, thawed', '9...
# 4         135       6.0  ['5 Little Debbie® Christmas Tree Brownies', '...
#
#                                           directions  \
# 0  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 1  ['Melt chocolate chips in a microwave-safe bow...
# 2  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 3  ['Gather the ingredients. Preheat the oven to ...
# 4  ['Cut 4 brownies into small pieces, and set as...
#
#                                           recipe_url  calories  fat  carbs  \
# 0  https://www.allrecipes.com/french-silk-pie-bar...       405   31     28
# 1  https://www.allrecipes.com/no-bake-espresso-ma...      1058   65    113
# 2  https://www.allrecipes.com/blackout-cake-recip...       824   55     80
# 3  https://www.allrecipes.com/sleeping-gingerbrea...       231   12     29
# 4  https://www.allrecipes.com/little-debbie-brown...       534   31     61
#
#    protein                                cleaned_ingredients  \
# 0        5  ['butter', 'white sugar', 'chocolate graham cr...
# 1       10  ['chocolate chips', 'cremefilled chocolate coo...
# 2        9  ['cooking spray', 'allpurpose flour', 'white s...
# 3        3  ['puff pastry', 'chocolate squares', 'gingerbr...
# 4        6  ['little debbie® christmas tree brownies', 'cr...
#
#            time_category     calorie_category          fat_category  \
# 0  Livin in the kitchin!    Average (300–600)      High Fat! (> 25)
# 1    30 minutes or less!  Don't look! (>1000)      High Fat! (> 25)
# 2  Livin in the kitchin!      High (600–1000)      High Fat! (> 25)
# 3    30 minutes or less!       Low cal (<300)  Average Fat! (11-25)
# 4  Livin in the kitchin!    Average (300–600)      High Fat! (> 25)
#
#            carbs_category     protein_category
# 0  Average Carbs! (25-80)  Low Protein! (< 10)
# 1      High Carbs! (> 80)  Low Protein! (< 10)
# 2  Average Carbs! (25-80)  Low Protein! (< 10)
# 3  Average Carbs! (25-80)  Low Protein! (< 10)
# 4  Average Carbs! (25-80)  Low Protein! (< 10)

# %% [markdown]
# ### Look into prep_time

# %%
# Max
df['prep_time'].max()
# Out:
# 300.0

# %%
# Min
df['prep_time'].min()
# Out:
# 2.0

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['prep_time'])

# Add labels and title
plt.xlabel("Preparation Time (minutes)")
plt.title("Distribution of Recipe Preparation Times");

# %%
# There is an extreme outlier at 300 minutes, and another around 120 minutes
df[df['prep_time'] == 300]

# Recipe is Pineapple Smoothie, I looked at the recipe on the website from url, the time is correct at 5 hours or 300 minutes
# I'm going to guess that the author is including the time it takes to freeze the fruit into prep_time
# Out:
#                    title                                              intro  \
# 1176  Pineapple Smoothie  A tropical pineapple smoothie made with fresh ...
#
#       prep_time  cook_time  total_time  servings  \
# 1176      300.0        NaN         300       2.0
#
#                                             ingredients  \
# 1176  ['1 1/2 cups cubed pineapple, frozen', '1 bana...
#
#                                              directions  \
# 1176  ['Combine pineapple, banana, coconut milk, coc...
#
#                                              recipe_url  calories  fat  carbs  \
# 1176  https://www.allrecipes.com/pineapple-smoothie-...       343   24     33
#
#       protein                                cleaned_ingredients  \
# 1176        4  ['pineapple', 'banana', 'coconut milk', 'cocon...
#
#               time_category   calorie_category          fat_category  \
# 1176  Livin in the kitchin!  Average (300–600)  Average Fat! (11-25)
#
#               carbs_category     protein_category
# 1176  Average Carbs! (25-80)  Low Protein! (< 10)

# %%
df[df['prep_time'] > 100]

# Recipe is S'mores Cupcakes, the prep time is correct, from the url it does say the recipe takes 2 hours of prep_time
# Out:
#                    title                                              intro  \
# 15      S'mores Cupcakes  These s'mores cupcakes take quite a bit of tim...
# 1176  Pineapple Smoothie  A tropical pineapple smoothie made with fresh ...
#
#       prep_time  cook_time  total_time  servings  \
# 15        120.0       40.0         160      18.0
# 1176      300.0        NaN         300       2.0
#
#                                             ingredients  \
# 15    ['1 1/2 cups graham cracker crumbs', '6 tables...
# 1176  ['1 1/2 cups cubed pineapple, frozen', '1 bana...
#
#                                              directions  \
# 15    ['Preheat the oven to 350 degrees F (175 degre...
# 1176  ['Combine pineapple, banana, coconut milk, coc...
#
#                                              recipe_url  calories  fat  carbs  \
# 15    https://www.allrecipes.com/s-mores-cupcakes-re...       268   11     40
# 1176  https://www.allrecipes.com/pineapple-smoothie-...       343   24     33
#
#       protein                                cleaned_ingredients  \
# 15          3  ['graham cracker', 'unsalted butter', 'brown s...
# 1176        4  ['pineapple', 'banana', 'coconut milk', 'cocon...
#
#               time_category   calorie_category          fat_category  \
# 15    Livin in the kitchin!     Low cal (<300)  Average Fat! (11-25)
# 1176  Livin in the kitchin!  Average (300–600)  Average Fat! (11-25)
#
#               carbs_category     protein_category
# 15    Average Carbs! (25-80)  Low Protein! (< 10)
# 1176  Average Carbs! (25-80)  Low Protein! (< 10)

# %% [markdown]
# ### Look into total_time

# %%
# Max
df['total_time'].max()
# Out:
# 5833

# %%
# Min
df['total_time'].min()
df['total_time'].mean()
# Out:
# 117.05614973262033

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['total_time'])

# Add labels and title
plt.xlabel("Total Time (minutes)")
plt.title("Distribution of Recipe Total Times");

# Plot the histogram
plt.figure(figsize=(9, 6))
sns.histplot(df['total_time'], bins=30, kde=True, color = 'teal')  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Total Time per Recipe (mins)")
plt.ylabel("Number of Recipes")
plt.title("Quicker Recipes Appear Most Frequently")
# Out:
# Text(0.5, 1.0, 'Quicker Recipes Appear Most Frequently')

# %%
# There is a lot of spread regarding a recipes total time
# The most extreme recipes being above 2_500 mins
df[df['total_time'] > 2_500]
# Out:
#                                                 title  \
# 119                                 Roman-Style Pizza
# 1010  Philippine Longanisa de Eugenio (Sweet Sausage)
# 1257                                 Dry Brine Turkey
# 1261     Juicy Two-Stage Thanksgiving Turkey Marinade
# 1797                                     Homemade Lox
#
#                                                   intro  prep_time  cook_time  \
# 119   This Roman-style pizza has a long-fermented th...       30.0       45.0
# 1010  This Phillippine longanisa de Eugenio is for t...       45.0       28.0
# 1257  Dry brining, or pre-salting, is the easiest wa...       15.0      150.0
# 1261  This recipe has two different marinades that a...       25.0        NaN
# 1797  This homemade lox recipe takes some time to pr...       20.0        NaN
#
#       total_time  servings                                        ingredients  \
# 119         3060      12.0  ['4 1/4 cups bread flour (500 grams)', '1 roun...
# 1010        5833      12.0  ['½ cup white sugar', '4 ½ teaspoons fine salt...
# 1257        5055      15.0  ['1 (15 pound) whole turkey, neck and giblets ...
# 1261        2905      15.0  ['1 cup salt', '1 cup orange juice', '1 cup br...
# 1797        2930       8.0  ['1 pound salmon fillet, bones removed', '½ cu...
#
#                                              directions  \
# 119   ['For dough, mix together flour, yeast, and wa...
# 1010  ['Stir sugar, salt, oregano, black pepper, cur...
# 1257  ['Pat turkey dry with paper towels. Season ins...
# 1261  ['On the Tuesday morning before Thanksgiving, ...
# 1797  ['Rinse salmon with water; pat dry with paper ...
#
#                                              recipe_url  calories  fat  carbs  \
# 119   https://www.allrecipes.com/roman-style-pizza-r...       413   20     39
# 1010  https://www.allrecipes.com/recipe/138109/phili...       496   44      9
# 1257  https://www.allrecipes.com/recipe/245524/dry-b...       684   32      1
# 1261  https://www.allrecipes.com/recipe/94543/juicy-...       814   36     27
# 1797  https://www.allrecipes.com/recipe/254896/homem...       120    3     13
#
#       protein                                cleaned_ingredients  \
# 119        17  ['bread flour', 'rounded yeast', 'water', 'gen...
# 1010       15  ['white sugar', 'salt', 'oregano', 'black pepp...
# 1257       92  ['turkey neck giblets', 'salt', 'black pepper'...
# 1261       93  ['salt', 'orange juice', 'brown sugar', 'gallo...
# 1797       10  ['salmon fillet bones', 'salt', 'white sugar',...
#
#               time_category   calorie_category          fat_category  \
# 119   Livin in the kitchin!  Average (300–600)  Average Fat! (11-25)
# 1010  Livin in the kitchin!  Average (300–600)      High Fat! (> 25)
# 1257  Livin in the kitchin!    High (600–1000)      High Fat! (> 25)
# 1261  Livin in the kitchin!    High (600–1000)      High Fat! (> 25)
# 1797  Livin in the kitchin!     Low cal (<300)       Low Fat! (< 10)
#
#               carbs_category          protein_category
# 119   Average Carbs! (25-80)  Average Protein! (11-29)
# 1010       Low Carbs! (< 25)  Average Protein! (11-29)
# 1257       Low Carbs! (< 25)      High Protein! (> 30)
# 1261  Average Carbs! (25-80)      High Protein! (> 30)
# 1797       Low Carbs! (< 25)       Low Protein! (< 10)

# %%
# After looking into each of the recipes on the webiste they are all valid recipes with correctly inputed information

# %% [markdown]
# ### Look into calories

# %%
# Max
df['calories'].max()
# Out:
# 4455

# %%
# Min
df['calories'].min()
df['calories'].mean()
# Out:
# 462.4433155080214

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['calories'])

# Add labels and title
plt.xlabel("Total Calories (kcal)")
plt.title("Distribution of a Recipe Total Calories");

# %%
# Plot the histogram
plt.figure(figsize=(9, 6))
sns.histplot(df['calories'], bins=30, kde=True, color = 'orange')  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Calories per Serving (kcal)")
plt.ylabel("Number of Recipes")
plt.title("Majority of Recipes Under 1K Calories");

# %%
# The most extreme recipes are 2_000 and above
df[df['calories'] >= 2_000]

# There are all valid recipes
# Out:
#                                       title  \
# 153                  Chicken Parmesan Pizza
# 735                   Café Tropical Burrito
# 897        Karaage (Japanese Fried Chicken)
# 937                        Cuban Crunchwrap
# 1089      Indian Tacos with Yeast Fry Bread
# 1368                 Low and Slow Prime Rib
# 1736                          Steak Burrito
# 1845  Boeuf en Croûte (Beef in Puff Pastry)
#
#                                                   intro  prep_time  cook_time  \
# 153   This pizza comes together in a flash and looks...        5.0       18.0
# 735   This breakfast burrito comes together quickly....        5.0       15.0
# 897   The only karaage recipe you'll ever need. Lear...       20.0       10.0
# 937   Try this Cuban crunchwrap with ham, cheese, po...        5.0        5.0
# 1089  My cousins grew up on a reservation in South D...       60.0       45.0
# 1368  The simplest, most fail-safe version for cooki...       15.0        NaN
# 1736  My husband grills ribeye steaks at least once ...       10.0        NaN
# 1845  This boeuf en croûte (beef in puff pastry) rec...       35.0       20.0
#
#       total_time  servings                                        ingredients  \
# 153           23       4.0  ['12 frozen chicken nuggets', '1 12-inch pre-b...
# 735           20       1.0  ['2 strips bacon, or more to taste', '1 frozen...
# 897          105       4.0  ['1 clove garlic, finely grated', '1 tablespoo...
# 937           10       1.0  ['1 extra large flour tortilla (12 inches or l...
# 1089         105       6.0  ['1 (.25 ounce) package active dry yeast', '1 ...
# 1368        1555       4.0  ['5 pounds prime rib roast', '1 tablespoon kos...
# 1736          10       1.0  ['1 (10-inch) flour tortilla', '3/4 cup cubed,...
# 1845         115       2.0  ['1 teaspoon olive oil', '2 (6 ounce) beef ten...
#
#                                              directions  \
# 153   ['Preheat the oven to 425 degrees F (220 degre...
# 735   ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 897   ['Mix garlic, ginger, soy sauce, sake, mirin, ...
# 937   ['Place tortilla down on a work surface.\xa0Ad...
# 1089  ['Mix yeast, sugar, and 1/4 cup warm water in ...
# 1368  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 1736  ['Fold a paper towel around tortilla. Microwav...
# 1845  ['Heat olive oil in a heavy skillet over high ...
#
#                                              recipe_url  calories  fat  carbs  \
# 153   https://www.allrecipes.com/chicken-parmesan-pi...      4455  105    746
# 735   https://www.allrecipes.com/cafe-tropical-burri...      2580   81    372
# 897   https://www.allrecipes.com/recipe/8325387/kara...      2263  226     32
# 937   https://www.allrecipes.com/cuban-crunchwrap-re...      2010   71    264
# 1089  https://www.allrecipes.com/recipe/222993/india...      2643  245     79
# 1368  https://www.allrecipes.com/recipe/8520971/low-...      2152  196      1
# 1736  https://www.allrecipes.com/steak-burrito-recip...      2456   83    321
# 1845  https://www.allrecipes.com/recipe/213512/boeuf...      3274  215    232
#
#       protein                                cleaned_ingredients  \
# 153       117  ['chicken nuggets', 'prebaked pizza crust', 'm...
# 735        84  ['bacon', 'hashbrown patty', 'eggs', 'cheddar ...
# 897        29  ['garlic', 'ginger', 'soy sauce', 'sake', 'mir...
# 937        76  ['flour tortilla', 'ham', 'pork', 'mustard', '...
# 1089       42  ['active yeast', 'white sugar', 'water', 'allp...
# 1368       90  ['prime rib', 'salt', 'unsalted butter', 'salt...
# 1736      101  ['flour tortilla', 'ribeye steak', 'mexican ri...
# 1845       69  ['olive oil', 'beef tenderloin', 'butter', 'wh...
#
#                time_category     calorie_category      fat_category  \
# 153      30 minutes or less!  Don't look! (>1000)  High Fat! (> 25)
# 735      30 minutes or less!  Don't look! (>1000)  High Fat! (> 25)
# 897   Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
# 937      30 minutes or less!  Don't look! (>1000)  High Fat! (> 25)
# 1089  Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
# 1368   Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
# 1736     30 minutes or less!  Don't look! (>1000)  High Fat! (> 25)
# 1845  Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
#
#               carbs_category          protein_category
# 153       High Carbs! (> 80)      High Protein! (> 30)
# 735       High Carbs! (> 80)      High Protein! (> 30)
# 897   Average Carbs! (25-80)  Average Protein! (11-29)
# 937       High Carbs! (> 80)      High Protein! (> 30)
# 1089  Average Carbs! (25-80)      High Protein! (> 30)
# 1368       Low Carbs! (< 25)      High Protein! (> 30)
# 1736      High Carbs! (> 80)      High Protein! (> 30)
# 1845      High Carbs! (> 80)      High Protein! (> 30)

# %% [markdown]
# ### Look into fat

# %%
# Max
df['fat'].max()
# Out:
# 245

# %%
# Min
df['fat'].min()
df['fat'].mean()
# Out:
# 24.519251336898396

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['fat'])

# Add labels and title
plt.xlabel("Total Fat (g)")
plt.title("Distribution of a Recipe Total Fat");

# %%
# Plot the histogram
plt.figure(figsize=(9, 6))
sns.histplot(df['fat'], bins=30, kde=True)  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Fats per Serving (grams)")
plt.ylabel("Number of Recipes")
plt.title("Most Recipes are Moderate to Low in Fat");

# %%
# The most extreme recipes being above 140
df[df['fat'] > 140]
# Out:
#                                        title  \
# 514   Ultimate Thanksgiving Leftovers Burger
# 897         Karaage (Japanese Fried Chicken)
# 1089       Indian Tacos with Yeast Fry Bread
# 1368                  Low and Slow Prime Rib
# 1375           Chef John's Perfect Prime Rib
# 1845   Boeuf en Croûte (Beef in Puff Pastry)
#
#                                                   intro  prep_time  cook_time  \
# 514   This ultimate Thanksgiving leftover burger is ...       15.0       10.0
# 897   The only karaage recipe you'll ever need. Lear...       20.0       10.0
# 1089  My cousins grew up on a reservation in South D...       60.0       45.0
# 1368  The simplest, most fail-safe version for cooki...       15.0        NaN
# 1375  Use my easy "mathematical method" for cooking ...       10.0      140.0
# 1845  This boeuf en croûte (beef in puff pastry) rec...       35.0       20.0
#
#       total_time  servings                                        ingredients  \
# 514           25       4.0  ['4 cups leftover cooked stuffing or dressing'...
# 897          105       4.0  ['1 clove garlic, finely grated', '1 tablespoo...
# 1089         105       6.0  ['1 (.25 ounce) package active dry yeast', '1 ...
# 1368        1555       4.0  ['5 pounds prime rib roast', '1 tablespoon kos...
# 1375         270       4.0  ['1 (4 pound) bone-in prime rib roast (room te...
# 1845         115       2.0  ['1 teaspoon olive oil', '2 (6 ounce) beef ten...
#
#                                              directions  \
# 514   ['Crumble leftover stuffing into a bowl. Add g...
# 897   ['Mix garlic, ginger, soy sauce, sake, mirin, ...
# 1089  ['Mix yeast, sugar, and 1/4 cup warm water in ...
# 1368  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 1375  ['Gather the ingredients. Place prime rib roas...
# 1845  ['Heat olive oil in a heavy skillet over high ...
#
#                                              recipe_url  calories  fat  carbs  \
# 514   https://www.allrecipes.com/ultimate-thanksgivi...      1892  145    108
# 897   https://www.allrecipes.com/recipe/8325387/kara...      2263  226     32
# 1089  https://www.allrecipes.com/recipe/222993/india...      2643  245     79
# 1368  https://www.allrecipes.com/recipe/8520971/low-...      2152  196      1
# 1375  https://www.allrecipes.com/recipe/221958/chef-...      1757  161      1
# 1845  https://www.allrecipes.com/recipe/213512/boeuf...      3274  215    232
#
#       protein                                cleaned_ingredients  \
# 514        40  ['leftover stuffing dressing', 'turkey gravy',...
# 897        29  ['garlic', 'ginger', 'soy sauce', 'sake', 'mir...
# 1089       42  ['active yeast', 'white sugar', 'water', 'allp...
# 1368       90  ['prime rib', 'salt', 'unsalted butter', 'salt...
# 1375       73  ['prime rib', 'unsalted butter', 'black pepper...
# 1845       69  ['olive oil', 'beef tenderloin', 'butter', 'wh...
#
#                time_category     calorie_category      fat_category  \
# 514      30 minutes or less!  Don't look! (>1000)  High Fat! (> 25)
# 897   Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
# 1089  Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
# 1368   Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
# 1375   Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
# 1845  Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
#
#               carbs_category          protein_category
# 514       High Carbs! (> 80)      High Protein! (> 30)
# 897   Average Carbs! (25-80)  Average Protein! (11-29)
# 1089  Average Carbs! (25-80)      High Protein! (> 30)
# 1368       Low Carbs! (< 25)      High Protein! (> 30)
# 1375       Low Carbs! (< 25)      High Protein! (> 30)
# 1845      High Carbs! (> 80)      High Protein! (> 30)

# %% [markdown]
# ### Look into carbs column

# %%
# Max
df['carbs'].max()
# Out:
# 746

# %%
# Min
df['carbs'].min()
df['carbs'].mean()
# Out:
# 36.0620320855615

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['carbs'])

# Add labels and title
plt.xlabel("Total Carbs (grams)")
plt.title("Distribution of Carbs");

# %%
# Plot the histogram
plt.figure(figsize=(9, 6))
sns.histplot(df['carbs'], bins=30, kde=True, color = 'blue')  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Carbs per Serving (grams)")
plt.ylabel("Number of Recipes")
plt.title("High Frequency of Low to Average Carb Counts");

# %% [markdown]
# ### Look into protein column

# %%
# Max
df['protein'].max()
# Out:
# 137

# %%
# Min
df['protein'].min()
# Out:
# 0

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (12, 6))

# Create a boxplot to look at time distribution
sns.boxplot(x=df['protein'])

# Add labels and title
plt.xlabel("Total Protein (grams)")
plt.title("Distribution of Proteins");

# %%
# Plot the histogram
plt.figure(figsize=(9, 6))
sns.histplot(df['protein'], bins=30, kde=True, color = 'green')  # `kde=True` adds a smoothed curve

# Add labels
plt.xlabel("Protein per Serving (grams)")
plt.ylabel("Number of Recipes")
plt.title("Fairly Even Spread of Recipes for Recipes Under 40 grams");

# %%
# The most extreme recipes being above 120 grams
df[df['protein'] > 120]
# Out:
#                                   title  \
# 407     Dooky Chase-Style Fried Chicken
# 1248                   Gas Grill Turkey
# 1264         Smoked Whole Turkey Breast
# 1286             Guinness Chili for Two
# 1364  Italian Braised Beef and Potatoes
#
#                                                   intro  prep_time  cook_time  \
# 407   I'm going to show you my version of the famous...       20.0       20.0
# 1248  This turkey cooked on a gas grill comes out ju...       15.0      215.0
# 1264  Great as a main dish, with some yummy sides, o...       20.0      210.0
# 1286  This Guinness chili for two, inspired by the I...       20.0       90.0
# 1364  Italian braised beef and potatoes is one of my...       15.0      190.0
#
#       total_time  servings                                        ingredients  \
# 407          765       4.0  ['4 teaspoons fine salt', '2 teaspoons freshly...
# 1248         240       8.0  ['1 (12 pound) whole turkey, neck and giblets ...
# 1264         275       8.0  ['wood chips of choice, soaked in water', 'wat...
# 1286         110       2.0  ['1 tablespoon olive oil', '1 slice bacon', '1...
# 1364         205       4.0  ['2 teaspoons kosher salt', '1 teaspoon freshl...
#
#                                              directions  \
# 407   ['Mix together 4 teaspoons salt, black pepper,...
# 1248  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 1264  ['Preheat a smoker to 350 degrees F (175 degre...
# 1286  ['Preheat the oven to 325 degrees F (165 degre...
# 1364  ['Preheat the oven to 325 degrees F (165 degre...
#
#                                              recipe_url  calories  fat  carbs  \
# 407   https://www.allrecipes.com/dooky-chase-style-f...      1763  110     49
# 1248  https://www.allrecipes.com/recipe/258726/gas-g...      1422   93      2
# 1264  https://www.allrecipes.com/recipe/282204/smoke...       610    6      0
# 1286  https://www.allrecipes.com/guinness-chili-for-...      1014   37     44
# 1364  https://www.allrecipes.com/italian-braised-bee...      1124   33     79
#
#       protein                                cleaned_ingredients  \
# 407       135  ['salt', 'black pepper', 'garlic powder', 'cay...
# 1248      137  ['turkey neck giblets', 'water', 'butter', 'sa...
# 1264      130  ['wood chips choice', 'water', 'turkey breast'...
# 1286      122  ['olive oil', 'bacon', 'salt black pepper', 'b...
# 1364      125  ['salt', 'black pepper', 'cayenne pepper', 'ol...
#
#                time_category     calorie_category      fat_category  \
# 407    Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
# 1248   Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
# 1264   Livin in the kitchin!      High (600–1000)   Low Fat! (< 10)
# 1286  Long recipes! (60-120)  Don't look! (>1000)  High Fat! (> 25)
# 1364   Livin in the kitchin!  Don't look! (>1000)  High Fat! (> 25)
#
#               carbs_category      protein_category
# 407   Average Carbs! (25-80)  High Protein! (> 30)
# 1248       Low Carbs! (< 25)  High Protein! (> 30)
# 1264       Low Carbs! (< 25)  High Protein! (> 30)
# 1286  Average Carbs! (25-80)  High Protein! (> 30)
# 1364  Average Carbs! (25-80)  High Protein! (> 30)
