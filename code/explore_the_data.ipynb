# %% [markdown]
# # Data Munging
# - Cleaning the Data: Handle missing values, duplicates, data types, and errors
# - Transform the Data: Normalize, encode, aggregate, filter, new features
# - Restructure: change shape or format of data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re # searches for patterns in a string
import ast
import string

# %% [markdown]
# ### Load in csv

# %%
df = pd.read_csv('../data/all_recipes_combined.csv')
df.head()
# Out:
#                                      title  \
# 0                     French Silk Pie Bars
# 1  Our 15 Best Brownie Recipes of All Time
# 2     No Bake Espresso Martini Cheesecakes
# 3                            Blackout Cake
# 4              Sleeping Gingerbread Treats
#
#                                                intro prep_time cook_time  \
# 0  These French silk pie bars are sooo good. They...   40 mins   20 mins
# 1                There's a sweet treat for everyone.       NaN       NaN
# 2  These no bake espresso martini cheesecakes hav...   20 mins    5 mins
# 3  Blackout cake is a moist and tender cake with ...   40 mins   20 mins
# 4                            Shhhh they're sleeping!   15 mins   15 mins
#
#       total_time servings                                        ingredients  \
# 0          5 hrs       16  ['1/3 cup butter, melted', '1/4 cup white suga...
# 1            NaN      NaN                                                 []
# 2        25 mins        6  ['1 cup dark chocolate chips', '20 creme-fille...
# 3  2 hrs 15 mins       12  ['cooking spray', '2 1/4 cups all-purpose flou...
# 4        30 mins        9  ['1 sheet of prepared puff pastry, thawed', '9...
#
#                                           directions  \
# 0  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 1                                                 []
# 2  ['Melt chocolate chips in a microwave-safe bow...
# 3  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 4  ['Gather the ingredients. Preheat the oven to ...
#
#                                            nutrition  \
# 0  {'Calories': '405', 'Fat': '31g', 'Carbs': '28...
# 1                                                NaN
# 2  {'Calories': '1058', 'Fat': '65g', 'Carbs': '1...
# 3  {'Calories': '824', 'Fat': '55g', 'Carbs': '80...
# 4  {'Calories': '231', 'Fat': '12g', 'Carbs': '29...
#
#                                           recipe_url
# 0  https://www.allrecipes.com/french-silk-pie-bar...
# 1  https://www.allrecipes.com/best-brownie-recipe...
# 2  https://www.allrecipes.com/no-bake-espresso-ma...
# 3  https://www.allrecipes.com/blackout-cake-recip...
# 4  https://www.allrecipes.com/sleeping-gingerbrea...

# %% [markdown]
# ### Shape of data
# - 2_304 rows, 10 columns

# %%
df.shape
# Out:
# (2304, 10)

# %% [markdown]
# ### Data types
# - All columns are stored as string data types

# %%
df.dtypes
# Out:
# title          object
# intro          object
# prep_time      object
# cook_time      object
# total_time     object
# servings       object
# ingredients    object
# directions     object
# nutrition      object
# recipe_url     object
# dtype: object

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### 1. Handle Missing Values
# - Null values in 'intro', 'prep_time', 'cook_time', 'total_time', 'servings', 'nutrition', 'recipe_url'
# - Dropped a total of 161 rows containing null values (64 rows in recipe_urls, 23 rows in intro, 88 rows in nutrition, 4 rows in serving, 9 rows in total_time)
# - 14 null rows remaining in column prep_time: The user will have the option to filter recipes based on total time so it's not vital that all prep_time rows are filled
# - 187 null rows remaining in column cook_time: Same reasoning used from prep_time

# %%
# Check for nulls
df.isnull().sum()
# Out:
# title            0
# intro           23
# prep_time       90
# cook_time      268
# total_time      76
# servings        71
# ingredients      0
# directions       0
# nutrition       88
# recipe_url      64
# dtype: int64

# %% [markdown]
# #### Look into 'recipe_url'
# - 64 recipes with nulls
# - Drop these 64 rows b/c end goal is to return a recipes url for the user to have access to

# %%
# View null values
df[df['recipe_url'].isnull()]
# Out:
#                                            title  \
# 384                   Cheesy Lasagna Sheet Pasta
# 385                Creamy Beef and Bow Tie Pasta
# 386                                   Reuben Mac
# 387             Dump and Bake Meatball Casserole
# 388                Soy Butter Pasta with Chicken
# ..                                           ...
# 443                  Creamy Chicken Fajita Pasta
# 444                        Marry Me Shrimp Pasta
# 445  7 Pasta Dinners for Every Night of the Week
# 446                                   Lemon Orzo
# 447                  Pancetta Primavera Rigatoni
#
#                                                  intro prep_time cook_time  \
# 384  This 3 ingredient cheesy lasagna sheet pasta c...    5 mins   15 mins
# 385  This creamy beef and bow tie pasta is a fun ta...   15 mins   20 mins
# 386  Not your typical mac and cheese. This recipe w...   30 mins   30 mins
# 387  This super easy dump and bake meatball cassero...    5 mins   40 mins
# 388  This soy butter pasta with chicken has a simpl...   10 mins   15 mins
# ..                                                 ...       ...       ...
# 443  This chicken fajita pasta dish has all the fla...   15 mins   30 mins
# 444  This creamy shrimp dish will make any pasta lo...   10 mins   20 mins
# 445  Even the pickiest of eaters will love these pa...       NaN       NaN
# 446  Serve this lemon orzo as a side with chicken o...    5 mins   20 mins
# 447  This pancetta primavera rigatoni really is a t...   20 mins   20 mins
#
#     total_time servings                                        ingredients  \
# 384    20 mins        6  ['8 ounces lasagna noodles, broken in half', '...
# 385    35 mins        4  ['6 ounces bowtie pasta (farfalle)', '1 pound ...
# 386       1 hr        6  ['8 ounces large elbow macaroni', '¼ cup butte...
# 387    45 mins        8  ['12 ounces dry rotini pasta', '2 1/2 cups wat...
# 388    25 mins        3  ['8 ounces bucatini or linguine pasta', '4 tab...
# ..         ...      ...                                                ...
# 443    45 mins        8  ['2 tablespoons chili powder', '1 tablespoon c...
# 444    30 mins        8  ['12 ounces \xa0uncooked calamarata or rigaton...
# 445        NaN      NaN                                                 []
# 446    25 mins        4  ['2 tablespoons unsalted butter, divided', '1 ...
# 447    40 mins        4  ['3 tablespoons olive oil, divided', '8 ounces...
#
#                                             directions  \
# 384  ['Bring a large pot of lightly salted water to...
# 385  ['Bring a large pot of lightly salted water to...
# 386  ['Bring a large pot of lightly salted water to...
# 387  ['Gather all ingredients.\xa0Preheat the oven ...
# 388  ['Bring a large pot of salted water to a boil....
# ..                                                 ...
# 443  ['Combine chili powder, cumin, salt, onion pow...
# 444  ['Gather all ingredients. Cook pasta in salted...
# 445                                                 []
# 446  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 447  ['Pour 2 tablespoons of the olive oil to a lar...
#
#                                              nutrition recipe_url
# 384  {'Calories': '203', 'Fat': '9g', 'Carbs': '19g...        NaN
# 385  {'Calories': '498', 'Fat': '26g', 'Carbs': '26...        NaN
# 386  {'Calories': '757', 'Fat': '44g', 'Carbs': '56...        NaN
# 387  {'Calories': '362', 'Fat': '19g', 'Carbs': '28...        NaN
# 388  {'Calories': '399', 'Fat': '23g', 'Carbs': '33...        NaN
# ..                                                 ...        ...
# 443  {'Calories': '555', 'Fat': '25g', 'Carbs': '34...        NaN
# 444  {'Calories': '300', 'Fat': '16g', 'Carbs': '20...        NaN
# 445                                                NaN        NaN
# 446  {'Calories': '442', 'Fat': '11g', 'Carbs': '76...        NaN
# 447  {'Calories': '574', 'Fat': '44g', 'Carbs': '30...        NaN
#
# [64 rows x 10 columns]

# %%
# Drop null values in url column
df.dropna(subset = ['recipe_url'], inplace = True)

# %%
# Confirm
df[df['recipe_url'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, intro, prep_time, cook_time, total_time, servings, ingredients, directions, nutrition, recipe_url]
# Index: []

# %% [markdown]
# #### Look into 'intro'
# - 23 recipes with nulls
# - Drop these 23 rows b/c they are not individual recipes, they are scrapped pages that include multiple recipes

# %%
# View null values
df[df['intro'].isnull()]
# Out:
#                                                   title intro prep_time  \
# 21    25 Recipes to Make With Brownie Mix (That Tast...   NaN       NaN
# 370            8 Favorite Indian Butter Chicken Recipes   NaN       NaN
# 536                           11 Thai Red Curry Recipes   NaN       NaN
# 558                   Our Best Thai Green Curry Recipes   NaN       NaN
# 563                              18 Thai Shrimp Recipes   NaN       NaN
# 687           12 Refreshing Thai-Inspired Summer Salads   NaN       NaN
# 701   12 Recipes to Turn Extra Chicken into Healthy ...   NaN       NaN
# 719            18 Best Savory Recipes With Phyllo Dough   NaN       NaN
# 744   These Greek Lamb Recipes Are a True Taste of G...   NaN       NaN
# 1038                  15 Unbeatable Udon Noodle Recipes   NaN       NaN
# 1053  20 Easy Japanese Recipes for Quick Weeknight D...   NaN       NaN
# 1079  12 Japanese Beef Recipes for Simple Comforting...   NaN       NaN
# 1081           12+ Scrumptious Soba Noodle Bowl Recipes   NaN       NaN
# 1179               The 10 Best Filipino Chicken Recipes   NaN       NaN
# 1207                     The Best Filipino Pork Recipes   NaN       NaN
# 1267   11 Shrimp Taco Recipes for Any Night of the Week   NaN       NaN
# 1369             Best Smoothies for Pre & Post Workouts   NaN       NaN
# 1375  20 Breakfast Smoothie Recipes to Start Your Da...   NaN       NaN
# 1510  20 Recipes That Start With Cream of Mushroom Soup   NaN       NaN
# 1875                 26 Simple, Healthy Meals in a Bowl   NaN       NaN
# 1877                 16 Delicious Rice Bowls for Dinner   NaN       NaN
# 1888  22 Hearty One-Bowl Meals That Win Weeknight Di...   NaN       NaN
# 1891           12+ Scrumptious Soba Noodle Bowl Recipes   NaN       NaN
#
#      cook_time total_time servings ingredients directions nutrition  \
# 21         NaN        NaN      NaN          []         []       NaN
# 370        NaN        NaN      NaN          []         []       NaN
# 536        NaN        NaN      NaN          []         []       NaN
# 558        NaN        NaN      NaN          []         []       NaN
# 563        NaN        NaN      NaN          []         []       NaN
# 687        NaN        NaN      NaN          []         []       NaN
# 701        NaN        NaN      NaN          []         []       NaN
# 719        NaN        NaN      NaN          []         []       NaN
# 744        NaN        NaN      NaN          []         []       NaN
# 1038       NaN        NaN      NaN          []         []       NaN
# 1053       NaN        NaN      NaN          []         []       NaN
# 1079       NaN        NaN      NaN          []         []       NaN
# 1081       NaN        NaN      NaN          []         []       NaN
# 1179       NaN        NaN      NaN          []         []       NaN
# 1207       NaN        NaN      NaN          []         []       NaN
# 1267       NaN        NaN      NaN          []         []       NaN
# 1369       NaN        NaN      NaN          []         []       NaN
# 1375       NaN        NaN      NaN          []         []       NaN
# 1510       NaN        NaN      NaN          []         []       NaN
# 1875       NaN        NaN      NaN          []         []       NaN
# 1877       NaN        NaN      NaN          []         []       NaN
# 1888       NaN        NaN      NaN          []         []       NaN
# 1891       NaN        NaN      NaN          []         []       NaN
#
#                                              recipe_url
# 21    https://www.allrecipes.com/brownie-mix-recipes...
# 370   https://www.allrecipes.com/gallery/butter-chic...
# 536   https://www.allrecipes.com/gallery/thai-red-cu...
# 558   https://www.allrecipes.com/gallery/thai-green-...
# 563   https://www.allrecipes.com/gallery/thai-shrimp...
# 687   https://www.allrecipes.com/gallery/refreshing-...
# 701   https://www.allrecipes.com/gallery/turn-leftov...
# 719   https://www.allrecipes.com/gallery/the-best-sa...
# 744   https://www.allrecipes.com/gallery/greek-lamb-...
# 1038  https://www.allrecipes.com/gallery/udon-noodle...
# 1053  https://www.allrecipes.com/gallery/easy-japane...
# 1079  https://www.allrecipes.com/gallery/japanese-be...
# 1081  https://www.allrecipes.com/gallery/soba-noodle...
# 1179  https://www.allrecipes.com/gallery/the-best-fi...
# 1207  https://www.allrecipes.com/gallery/the-best-fi...
# 1267  https://www.allrecipes.com/gallery/shrimp-taco...
# 1369  https://www.allrecipes.com/article/best-smooth...
# 1375  https://www.allrecipes.com/gallery/breakfast-s...
# 1510  https://www.allrecipes.com/gallery/recipes-tha...
# 1875  https://www.allrecipes.com/gallery/easy-health...
# 1877  https://www.allrecipes.com/gallery/best-rice-b...
# 1888  https://www.allrecipes.com/gallery/one-bowl-me...
# 1891  https://www.allrecipes.com/gallery/soba-noodle...

# %%
# Drop null values in intro column
df.dropna(subset = ['intro'], inplace = True)

# %%
# Confirm
df[df['recipe_url'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, intro, prep_time, cook_time, total_time, servings, ingredients, directions, nutrition, recipe_url]
# Index: []

# %% [markdown]
# #### Look into 'nutrition'
# - 88 recipes with nulls
# - Drop these 88 rows b/c one goal is to be able to cluster recipes based on user nutrition preference

# %%
# View null values
df[df['nutrition'].isnull()]
# Out:
#                                                   title  \
# 1               Our 15 Best Brownie Recipes of All Time
# 6     28 Mint Chocolate Recipes You'll Want to Make ...
# 19    15 Chocolate and Strawberry Recipes (That Go W...
# 25                              Copycat Cosmic Brownies
# 38    The No-Fail Secret to the Chewiest, Fudgiest B...
# ...                                                 ...
# 1938  Nabisco Discontinued the Beloved Wafer Cookies...
# 1945  13 Easy Frozen Treats You Can Make With 5 Ingr...
# 2080  Our 50 Best Breakfast Egg Recipes Make Morning...
# 2118                                Chicken Adobo Tacos
# 2203                     Jimmy Dean Breakfast Casserole
#
#                                                   intro prep_time  \
# 1                   There's a sweet treat for everyone.       NaN
# 6            You're going to want to bookmark this one.       NaN
# 19                Put your strawberry haul to good use.       NaN
# 25                  Little Debbie has some competition!   30 mins
# 38    It took years to figure this out. You’re welcome.       NaN
# ...                                                 ...       ...
# 1938                   No chocolate wafers, no problem.       NaN
# 1945                            Get your freezer ready.       NaN
# 2080  Our best breakfast egg recipes ever make break...       NaN
# 2118  These chicken adobo tacos fuse Mexican and Fil...   20 mins
# 2203  This breakfast casserole with bread, sausage, ...   15 mins
#
#         cook_time     total_time servings  \
# 1             NaN            NaN      NaN
# 6             NaN            NaN      NaN
# 19            NaN            NaN      NaN
# 25    1 hr 5 mins  3 hrs 35 mins       12
# 38            NaN            NaN      NaN
# ...           ...            ...      ...
# 1938          NaN            NaN      NaN
# 1945          NaN            NaN      NaN
# 2080          NaN            NaN      NaN
# 2118      40 mins   1 hr 20 mins      8.0
# 2203  1 hr 5 mins   1 hr 20 mins        6
#
#                                             ingredients  \
# 1                                                    []
# 6                                                    []
# 19                                                   []
# 25    ['baking spray', '14 ounces (60% cacao) bitter...
# 38                                                   []
# ...                                                 ...
# 1938                                                 []
# 1945                                                 []
# 2080                                                 []
# 2118  ['1/3 cup soy sauce', '1/3 cup white vinegar',...
# 2203  ['cooking spray', '1 (16 ounce) package Regula...
#
#                                              directions nutrition  \
# 1                                                    []       NaN
# 6                                                    []       NaN
# 19                                                   []       NaN
# 25    ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...       NaN
# 38                                                   []       NaN
# ...                                                 ...       ...
# 1938                                                 []       NaN
# 1945                                                 []       NaN
# 2080                                                 []       NaN
# 2118  ['Combine soy sauce, vinegar, bay leaves, and ...       NaN
# 2203  ['Preheat the oven to 325 degrees F (165 degre...       NaN
#
#                                              recipe_url
# 1     https://www.allrecipes.com/best-brownie-recipe...
# 6     https://www.allrecipes.com/mint-chocolate-reci...
# 19    https://www.allrecipes.com/strawberries-and-ch...
# 25    https://www.allrecipes.com/copycat-cosmic-brow...
# 38    https://www.allrecipes.com/article/how-to-make...
# ...                                                 ...
# 1938  https://www.allrecipes.com/14-icebox-cakes-tha...
# 1945  https://www.allrecipes.com/5-ingredient-frozen...
# 2080  https://www.allrecipes.com/breakfast-egg-recip...
# 2118  https://www.allrecipes.com/chicken-adobo-tacos...
# 2203  https://www.allrecipes.com/recipe/84065/jimmy-...
#
# [61 rows x 10 columns]

# %%
# Drop null values in intro column
df.dropna(subset = ['nutrition'], inplace = True)

# %%
# Confirm
df[df['nutrition'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, intro, prep_time, cook_time, total_time, servings, ingredients, directions, nutrition, recipe_url]
# Index: []

# %% [markdown]
# #### Look into 'servings'
# - 4 recipes with nulls
# - Drop these 4 rows b/c one goal is to be able to filter recipes based on number of servings

# %%
# View null values
df[df['servings'].isnull()]
# Out:
#                                    title  \
# 906           Nicole’s Salmon Wellington
# 1282  Easy Rotisserie Chicken Enchiladas
# 1747              Coconut Milk Ice Cream
# 2112  Easy Rotisserie Chicken Enchiladas
#
#                                                   intro prep_time cook_time  \
# 906   Nicole's salmon Wellington is much more elegan...   20 mins   35 mins
# 1282  These easy rotisserie chicken enchiladas can b...   10 mins   30 mins
# 1747  This coconut milk ice cream, lightly flavored ...    5 mins       NaN
# 2112  These easy rotisserie chicken enchiladas can b...   10 mins   30 mins
#
#         total_time servings  \
# 906           1 hr      NaN
# 1282       40 mins      NaN
# 1747  6 hrs 5 mins      NaN
# 2112       40 mins      NaN
#
#                                             ingredients  \
# 906   ['1 tablespoon olive oil', '10 ounces frozen c...
# 1282  ['1 1/2 tablespoons canola oil', '6 corn torti...
# 1747  ['1 (13.5 ounce) can unsweetened coconut milk'...
# 2112  ['1 1/2 tablespoons canola oil', '6 corn torti...
#
#                                              directions  \
# 906   ['Heat a large nonstick skillet over medium-hi...
# 1282  ['Preheat the oven to 375 degrees F (190 degre...
# 1747  ['Whisk together coconut milk, sugar, vanilla ...
# 2112  ['Preheat the oven to 375 degrees F (190 degre...
#
#                                               nutrition  \
# 906   {'Calories': '5144', 'Fat': '354g', 'Carbs': '...
# 1282  {'Calories': '1008', 'Fat': '50g', 'Carbs': '8...
# 1747  {'Calories': '346', 'Fat': '8g', 'Carbs': '68g...
# 2112  {'Calories': '1008', 'Fat': '50g', 'Carbs': '8...
#
#                                              recipe_url
# 906   https://www.allrecipes.com/nicole-s-salmon-wel...
# 1282  https://www.allrecipes.com/easy-rotisserie-chi...
# 1747  https://www.allrecipes.com/coconut-milk-ice-cr...
# 2112  https://www.allrecipes.com/easy-rotisserie-chi...

# %%
# Drop null values in servings column
df.dropna(subset = ['servings'], inplace = True)

# %%
# Confirm
df[df['nutrition'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, intro, prep_time, cook_time, total_time, servings, ingredients, directions, nutrition, recipe_url]
# Index: []

# %% [markdown]
# #### Look into 'prep_time'
# - 23 recipes with nulls
# - Will leave these 23 recipes as is, goal is to filter out recipes based on total_time so prep_time is not vital. I would rather have the extra 23 recipes

# %%
# View null values
df[df['prep_time'].isnull()]
# Out:
#                                                   title  \
# 62                                     Cocoa Apple Cake
# 74                             Country Ham and Biscuits
# 94                                       Pork Schnitzel
# 144   This Viral Pan Pizza Recipe Uses Your 9x13 and...
# 208                               Mama's Banana Pudding
# 217                     Raspberry and Strawberry Buckle
# 276                                           Yaki Udon
# 378               Biryani with Yogurt Marinated Chicken
# 381                                   Spicy Indian Dahl
# 542                                        Thai Noodles
# 554                            Amazing Simple Thai Tofu
# 730                             My Big Fat Greek Omelet
# 982                              Coconut Chickpea Curry
# 1024                                          Yaki Udon
# 1222             Birria de Pollo (Chicken Birria) Tacos
# 1261                            Air Fryer Tacos de Papa
# 1285                               Chicken Biscuit Stew
# 1475                               Chicken Biscuit Stew
# 1522                       Rustic Chicken and Dumplin's
# 1600                       Rustic Chicken and Dumplin's
# 1642                                      Pierogi Dough
# 1963                                             Gelato
# 2158             Birria de Pollo (Chicken Birria) Tacos
#
#                                                   intro prep_time cook_time  \
# 62    This recipe is very moist and rich. I have als...       NaN       NaN
# 74    Dolly Parton and Rachel Parton George's famous...       NaN       NaN
# 94    To make German-style pork schnitzel, pork loin...       NaN   10 mins
# 144   Let the store do the work, you just have to as...       NaN       NaN
# 208   Dolly Parton and her sister Rachel Parton Gero...       NaN       NaN
# 217   I've always called this a buckle (I'm from the...       NaN       NaN
# 276   Yaki Udon is a classic Japanese stir-fry dish ...       NaN   15 mins
# 378   This is, as called by my mom, my signature bir...       NaN   45 mins
# 381   A spicy Indian lentil soup that can be enjoyed...       NaN       NaN
# 542   A spicy Thai noodle dish with chicken and vege...       NaN       NaN
# 554   You'd never guess it's Tofu! Peanut and ginger...       NaN       NaN
# 730   If you're low-carbing it, try my spinach omele...       NaN       NaN
# 982   A delicious vegetarian curry that is spicy, bu...       NaN   20 mins
# 1024  Yaki Udon is a classic Japanese stir-fry dish ...       NaN   15 mins
# 1222  These Mexican birria de pollo tacos, or chicke...       NaN       NaN
# 1261  Crispy potato tacos made simple in the air fryer.       NaN   25 mins
# 1285  This chicken biscuit stew is a good recipe to ...       NaN   30 mins
# 1475  This chicken biscuit stew is a good recipe to ...       NaN   30 mins
# 1522  Rachel Parton George makes this rustic chicken...       NaN       NaN
# 1600  Rachel Parton George makes this rustic chicken...       NaN       NaN
# 1642  Ukranian Pierogi ready to be stuffed with your...       NaN       NaN
# 1963  This gelato recipe is from my Italian mother-i...       NaN     3 hrs
# 2158  These Mexican birria de pollo tacos, or chicke...       NaN       NaN
#
#          total_time    servings  \
# 62              NaN          12
# 74          45 mins  6 servings
# 94          30 mins           4
# 144         45 mins  4 servings
# 208   2 hrs 20 mins          24
# 217             NaN          15
# 276         35 mins         4.0
# 378    1 hr 50 mins        12.0
# 381             NaN         6.0
# 542             NaN         4.0
# 554             NaN         4.0
# 730             NaN           4
# 982         35 mins           4
# 1024        35 mins         4.0
# 1222            NaN           6
# 1261        30 mins          10
# 1285        30 mins           4
# 1475        30 mins           4
# 1522  2 hrs 15 mins           8
# 1600  2 hrs 15 mins           8
# 1642            NaN          30
# 1963          3 hrs           4
# 2158            NaN         6.0
#
#                                             ingredients  \
# 62    ['3  eggs', '2 cups white sugar', '1 cup butte...
# 74    ['1/4 cup shortening, plus morefor greasing', ...
# 94    ['4 (5 ounce) boneless pork loin chops, trimme...
# 144   ['1 pound fresh\xa0pizza dough,\xa0thawed', 'c...
# 208   ['1 cup plus 1 tablespoon sugar', '1/2 cup flo...
# 217   ['½ cup butter, softened', '½ cup white sugar'...
# 276   ['¼ cup oyster sauce', '3 tablespoons soy sauc...
# 378   ['1 (8 ounce) container whole milk yogurt', '6...
# 381   ['1 cup red lentils', '2 tablespoons ginger ro...
# 542   ['½ pound dried rice noodles', '1 pound skinle...
# 554   ['1 (14 ounce) package firm tofu, cut into 3/4...
# 730   ['1 cup halved grape tomatoes', '1 teaspoon dr...
# 982   ['2 tablespoons grapeseed oil', '½ cup chopped...
# 1024  ['¼ cup oyster sauce', '3 tablespoons soy sauc...
# 1222  ['4 cups chicken broth', '4  dried guajillo ch...
# 1261  ['2 cups water', '1 (4 ounce) package instant ...
# 1285  ['2 tablespoons unsalted butter', '2 tablespoo...
# 1475  ['2 tablespoons unsalted butter', '2 tablespoo...
# 1522  ['1 whole chicken, cut into pieces (drumsticks...
# 1600  ['1 whole chicken, cut into pieces (drumsticks...
# 1642  ['4 cups all-purpose flour', '1 teaspoon salt'...
# 1963  ['2 cups milk', '1 cup heavy cream', '4  egg y...
# 2158  ['4 cups chicken broth', '4  dried guajillo ch...
#
#                                              directions  \
# 62    ['Cream together until fluffy the eggs, sugar,...
# 74    ['Preheat oven to 425 degrees F (220 degrees C...
# 94    ['Place 1 pork chop between 2 sheets of plasti...
# 144   ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 208   ['Stir together 1 cup sugar, the flour, and sa...
# 217   ['Preheat oven to 375 degrees F (190 degrees C...
# 276   ['Whisk together oyster sauce, soy sauce, miri...
# 378   ['Mix yogurt, garlic, ginger, garam masala, tu...
# 381   ['Cook the lentils by boiling or pressure cook...
# 542   ['Cook rice noodles according to package direc...
# 554   ['Heat olive oil and sesame oil in a skillet o...
# 730   ['Heat a 12-inch non-stick skillet over low he...
# 982   ['Heat oil in a large high-sided skillet over ...
# 1024  ['Whisk together oyster sauce, soy sauce, miri...
# 1222  ['Add chicken broth to a medium saucepan and b...
# 1261  ['Heat water in a medium saucepan to boiling. ...
# 1285  ['Preheat the oven to 375 degrees F (190 degre...
# 1475  ['Preheat the oven to 375 degrees F (190 degre...
# 1522  ['Season chicken pieces all over with the Mort...
# 1600  ['Season chicken pieces all over with the Mort...
# 1642  ['In a large bowl mix together the flour, salt...
# 1963  ['Gather the ingredients.', 'Mix milk and crea...
# 2158  ['Add chicken broth to a medium saucepan and b...
#
#                                               nutrition  \
# 62    {'Calories': '418', 'Fat': '19g', 'Carbs': '60...
# 74    {'Calories': '656', 'Fat': '40g', 'Carbs': '57...
# 94    {'Calories': '599', 'Fat': '39g', 'Carbs': '35...
# 144   {'Calories': '578', 'Fat': '28g', 'Carbs': '59...
# 208   {'Calories': '318', 'Fat': '13g', 'Carbs': '44...
# 217   {'Calories': '266', 'Fat': '13g', 'Carbs': '35...
# 276   {'Calories': '212', 'Fat': '11g', 'Carbs': '23...
# 378   {'Calories': '507', 'Fat': '9g', 'Carbs': '83g...
# 381   {'Calories': '209', 'Fat': '6g', 'Carbs': '31g...
# 542   {'Calories': '571', 'Fat': '19g', 'Carbs': '65...
# 554   {'Calories': '285', 'Fat': '21g', 'Carbs': '11...
# 730   {'Calories': '253', 'Fat': '18g', 'Carbs': '7g...
# 982   {'Calories': '480', 'Fat': '40g', 'Carbs': '37...
# 1024  {'Calories': '212', 'Fat': '11g', 'Carbs': '23...
# 1222  {'Calories': '255', 'Fat': '11g', 'Carbs': '8g...
# 1261  {'Calories': '137', 'Fat': '4g', 'Carbs': '22g...
# 1285  {'Calories': '446', 'Fat': '18g', 'Carbs': '40...
# 1475  {'Calories': '446', 'Fat': '18g', 'Carbs': '40...
# 1522  {'Calories': '465', 'Fat': '29g', 'Carbs': '21...
# 1600  {'Calories': '465', 'Fat': '29g', 'Carbs': '21...
# 1642  {'Calories': '66', 'Fat': '1g', 'Carbs': '13g'...
# 1963  {'Calories': '416', 'Fat': '29g', 'Carbs': '33...
# 2158  {'Calories': '255', 'Fat': '11g', 'Carbs': '8g...
#
#                                              recipe_url
# 62    https://www.allrecipes.com/recipe/7266/cocoa-a...
# 74    https://www.allrecipes.com/country-ham-and-bis...
# 94    https://www.allrecipes.com/recipe/8532147/pork...
# 144   https://www.allrecipes.com/trader-joes-spicy-g...
# 208   https://www.allrecipes.com/mamas-banana-puddin...
# 217   https://www.allrecipes.com/recipe/7603/raspber...
# 276   https://www.allrecipes.com/recipe/8539106/yaki...
# 378   https://www.allrecipes.com/recipe/246559/birya...
# 381   https://www.allrecipes.com/recipe/13059/spicy-...
# 542   https://www.allrecipes.com/recipe/11690/thai-n...
# 554   https://www.allrecipes.com/recipe/58097/amazin...
# 730   https://www.allrecipes.com/recipe/80046/my-big...
# 982   https://www.allrecipes.com/recipe/8527854/coco...
# 1024  https://www.allrecipes.com/recipe/8539106/yaki...
# 1222  https://www.allrecipes.com/recipe/8463920/birr...
# 1261  https://www.allrecipes.com/recipe/279985/air-f...
# 1285  https://www.allrecipes.com/chicken-biscuit-ste...
# 1475  https://www.allrecipes.com/chicken-biscuit-ste...
# 1522  https://www.allrecipes.com/rustic-chicken-and-...
# 1600  https://www.allrecipes.com/rustic-chicken-and-...
# 1642  https://www.allrecipes.com/recipe/12063/pierog...
# 1963    https://www.allrecipes.com/recipe/55609/gelato/
# 2158  https://www.allrecipes.com/recipe/8463920/birr...

# %% [markdown]
# #### Look into 'total_time'
# - 9 recipes with nulls
# - Will drop these 9 recipes b/c on goal is to filter out recipes for the user based on total_time

# %%
# View null values
df[df['total_time'].isnull()]
# Out:
#                                        title  \
# 62                          Cocoa Apple Cake
# 217          Raspberry and Strawberry Buckle
# 381                        Spicy Indian Dahl
# 542                             Thai Noodles
# 554                 Amazing Simple Thai Tofu
# 730                  My Big Fat Greek Omelet
# 1222  Birria de Pollo (Chicken Birria) Tacos
# 1642                           Pierogi Dough
# 2158  Birria de Pollo (Chicken Birria) Tacos
#
#                                                   intro prep_time cook_time  \
# 62    This recipe is very moist and rich. I have als...       NaN       NaN
# 217   I've always called this a buckle (I'm from the...       NaN       NaN
# 381   A spicy Indian lentil soup that can be enjoyed...       NaN       NaN
# 542   A spicy Thai noodle dish with chicken and vege...       NaN       NaN
# 554   You'd never guess it's Tofu! Peanut and ginger...       NaN       NaN
# 730   If you're low-carbing it, try my spinach omele...       NaN       NaN
# 1222  These Mexican birria de pollo tacos, or chicke...       NaN       NaN
# 1642  Ukranian Pierogi ready to be stuffed with your...       NaN       NaN
# 2158  These Mexican birria de pollo tacos, or chicke...       NaN       NaN
#
#      total_time servings                                        ingredients  \
# 62          NaN       12  ['3  eggs', '2 cups white sugar', '1 cup butte...
# 217         NaN       15  ['½ cup butter, softened', '½ cup white sugar'...
# 381         NaN      6.0  ['1 cup red lentils', '2 tablespoons ginger ro...
# 542         NaN      4.0  ['½ pound dried rice noodles', '1 pound skinle...
# 554         NaN      4.0  ['1 (14 ounce) package firm tofu, cut into 3/4...
# 730         NaN        4  ['1 cup halved grape tomatoes', '1 teaspoon dr...
# 1222        NaN        6  ['4 cups chicken broth', '4  dried guajillo ch...
# 1642        NaN       30  ['4 cups all-purpose flour', '1 teaspoon salt'...
# 2158        NaN      6.0  ['4 cups chicken broth', '4  dried guajillo ch...
#
#                                              directions  \
# 62    ['Cream together until fluffy the eggs, sugar,...
# 217   ['Preheat oven to 375 degrees F (190 degrees C...
# 381   ['Cook the lentils by boiling or pressure cook...
# 542   ['Cook rice noodles according to package direc...
# 554   ['Heat olive oil and sesame oil in a skillet o...
# 730   ['Heat a 12-inch non-stick skillet over low he...
# 1222  ['Add chicken broth to a medium saucepan and b...
# 1642  ['In a large bowl mix together the flour, salt...
# 2158  ['Add chicken broth to a medium saucepan and b...
#
#                                               nutrition  \
# 62    {'Calories': '418', 'Fat': '19g', 'Carbs': '60...
# 217   {'Calories': '266', 'Fat': '13g', 'Carbs': '35...
# 381   {'Calories': '209', 'Fat': '6g', 'Carbs': '31g...
# 542   {'Calories': '571', 'Fat': '19g', 'Carbs': '65...
# 554   {'Calories': '285', 'Fat': '21g', 'Carbs': '11...
# 730   {'Calories': '253', 'Fat': '18g', 'Carbs': '7g...
# 1222  {'Calories': '255', 'Fat': '11g', 'Carbs': '8g...
# 1642  {'Calories': '66', 'Fat': '1g', 'Carbs': '13g'...
# 2158  {'Calories': '255', 'Fat': '11g', 'Carbs': '8g...
#
#                                              recipe_url
# 62    https://www.allrecipes.com/recipe/7266/cocoa-a...
# 217   https://www.allrecipes.com/recipe/7603/raspber...
# 381   https://www.allrecipes.com/recipe/13059/spicy-...
# 542   https://www.allrecipes.com/recipe/11690/thai-n...
# 554   https://www.allrecipes.com/recipe/58097/amazin...
# 730   https://www.allrecipes.com/recipe/80046/my-big...
# 1222  https://www.allrecipes.com/recipe/8463920/birr...
# 1642  https://www.allrecipes.com/recipe/12063/pierog...
# 2158  https://www.allrecipes.com/recipe/8463920/birr...

# %%
# Drop null values in total_time column
df.dropna(subset = ['total_time'], inplace = True)

# %%
# Confirm
df[df['total_time'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, intro, prep_time, cook_time, total_time, servings, ingredients, directions, nutrition, recipe_url]
# Index: []

# %% [markdown]
# #### Look into 'cook_time'
# - 187 recipes with nulls
# - Will leave these 187 recipes as is, goal is to filter out recipes based on total_time so cook_time is not vital. I would rather have the extra 187 recipes

# %%
# View null values
df[df['cook_time'].isnull()]
# Out:
#                                            title  \
# 5                 Little Debbie Brownie Tree Dip
# 8     Cottage Cheese Chocolate Chip Cookie Dough
# 16                      Blender Chocolate Mousse
# 31             Best No-Bake Chocolate Cheesecake
# 41             5 Minute Baileys Chocolate Mousse
# ...                                          ...
# 2020                         Asian Chicken Salad
# 2111                    Sheet Pan Breakfast Bake
# 2148                               Steak Burrito
# 2229                                Homemade Lox
# 2294                               Prawn Banh Mi
#
#                                                   intro prep_time cook_time  \
# 5     Turn your favorite sweet treat into the best h...   15 mins       NaN
# 8     This cottage cheese chocolate chip cookie doug...   10 mins       NaN
# 16    This blender chocolate mousse, with espresso p...   10 mins       NaN
# 31    This no-bake chocolate cheesecake has a delici...   30 mins       NaN
# 41    In a hurry for a quick and delicious dessert? ...    5 mins       NaN
# ...                                                 ...       ...       ...
# 2020  This Asian chicken salad makes good use of lef...   20 mins       NaN
# 2111  This breakfast bake starts out with a two ingr...   10 mins       NaN
# 2148  My husband grills ribeye steaks at least once ...   10 mins       NaN
# 2229  This homemade lox recipe takes some time to pr...   20 mins       NaN
# 2294             A French-inspired Vietnamese sandwich.   20 mins       NaN
#
#           total_time servings  \
# 5      2 hrs 15 mins        6
# 8            10 mins        6
# 16           40 mins        4
# 31             2 hrs        8
# 41            5 mins        4
# ...              ...      ...
# 2020         30 mins        6
# 2111         47 mins        8
# 2148         10 mins      1.0
# 2229  2 days 50 mins        8
# 2294         20 mins        6
#
#                                             ingredients  \
# 5     ['5 Little Debbie® Christmas Tree Brownies', '...
# 8     ['1 cup 4% milkfat small curd cottage cheese',...
# 16    ['1 cup heavy cream', '1/4 cup unsweetened coc...
# 31    ['1  cup graham cracker crumbs', '1/4 cup salt...
# 41    ['1 cup heavy whipping cream', '¼ cup Baileys®...
# ...                                                 ...
# 2020  ['¼ cup vegetable oil', '3 tablespoons rice vi...
# 2111  ['1 cup Greek yogurt', '1 ¼ cups self-rising f...
# 2148  ['1 (10-inch) flour tortilla', '3/4 cup cubed,...
# 2229  ['1 pound salmon fillet, bones removed', '½ cu...
# 2294  ['1 large carrot, peeled and shredded', '1 sta...
#
#                                              directions  \
# 5     ['Cut 4 brownies into small pieces, and set as...
# 8     ['Place cottage cheese, maple syrup, oats, alm...
# 16    ["Combine heavy cream, cocoa powder, confectio...
# 31    ['Gather your ingredients.\n\n \n\n\n\n\n\n \n...
# 41    ["Combine heavy whipping cream, Bailey's, coco...
# ...                                                 ...
# 2020  ['Gather all ingredients.', 'Make the dressing...
# 2111  ['Preheat the oven to 350 degrees F (175 degre...
# 2148  ['Fold a paper towel around tortilla. Microwav...
# 2229  ['Rinse salmon with water; pat dry with paper ...
# 2294  ['Combine carrot, celery, and scallions in a b...
#
#                                               nutrition  \
# 5     {'Calories': '534', 'Fat': '31g', 'Carbs': '61...
# 8     {'Calories': '256', 'Fat': '15g', 'Carbs': '24...
# 16    {'Calories': '252', 'Fat': '22g', 'Carbs': '12...
# 31    {'Calories': '405', 'Fat': '30g', 'Carbs': '32...
# 41    {'Calories': '305', 'Fat': '23g', 'Carbs': '19...
# ...                                                 ...
# 2020  {'Calories': '414', 'Fat': '18g', 'Carbs': '39...
# 2111  {'Calories': '286', 'Fat': '18g', 'Carbs': '19...
# 2148  {'Calories': '2456', 'Fat': '83g', 'Carbs': '3...
# 2229  {'Calories': '120', 'Fat': '3g', 'Carbs': '13g...
# 2294  {'Calories': '388', 'Fat': '3g', 'Carbs': '61g...
#
#                                              recipe_url
# 5     https://www.allrecipes.com/little-debbie-brown...
# 8     https://www.allrecipes.com/cottage-cheese-choc...
# 16    https://www.allrecipes.com/blender-chocolate-m...
# 31    https://www.allrecipes.com/no-bake-chocolate-c...
# 41    https://www.allrecipes.com/recipe/8529769/5-mi...
# ...                                                 ...
# 2020  https://www.allrecipes.com/recipe/14252/asian-...
# 2111  https://www.allrecipes.com/recipe/8516222/shee...
# 2148  https://www.allrecipes.com/steak-burrito-recip...
# 2229  https://www.allrecipes.com/recipe/254896/homem...
# 2294  https://www.allrecipes.com/recipe/237135/prawn...
#
# [187 rows x 10 columns]

# %%
# Final null value spread
df.isnull().sum()
# Out:
# title            0
# intro            0
# prep_time       14
# cook_time      187
# total_time       0
# servings         0
# ingredients      0
# directions       0
# nutrition        0
# recipe_url       0
# dtype: int64

# %%
# Shape after dropped nulls
df.shape
# Out:
# (2143, 10)

# %% [markdown]
# ### 2. Handle Duplicate Values
# - There were 273 duplicated recipes in the data frame
# - 273 rows dropped from dataframe
# - Left with 1_870 unique recipes

# %%
# Check for duplicate recipes
df['title'].value_counts()
# Out:
# title
# NYC Deli Bacon, Egg, and Cheese Sandwich    5
# Ground Pork Tacos with Pineapple Salsa      4
# Copycat McDonald's Filet-o-Fish Sandwich    4
# Authentic Saag Paneer                       3
# Authentic Mexican Chile Rellenos            3
#                                            ..
# Lamb Feta Peppers                           1
# Feta Cheese Turkey Burgers                  1
# Roasted Greek Chicken                       1
# Margaret's Keftedes (Greek Meatballs)       1
# Beef Bourguignon II                         1
# Name: count, Length: 1870, dtype: int64

# %%
# How many recipes are duplicated ?
df['title'].duplicated().sum()
# Out:
# 273

# %%
# Want only unique recipes, dropping duplicates
df.drop_duplicates(subset = ['title'], inplace = True)

# %%
# Confirm
df['title'].duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1870, 10)

# %% [markdown]
# ### 3. Handle Data Types
# - All data intially stored as strings (object)

# %%
# Check data types
df.dtypes
# Out:
# title          object
# intro          object
# prep_time      object
# cook_time      object
# total_time     object
# servings       object
# ingredients    object
# directions     object
# nutrition      object
# recipe_url     object
# dtype: object

# %% [markdown]
# ### 4. Time Conversion
# - Columns prep_time, cook_time, total_time have values stored as differnet units: minutes, hours, & days
# - Columns prep_time, cook_time, total_time converted to data type float and all units are in minutes

# %%
# Look at values in prep_time column
df['prep_time'].value_counts()
# Out:
# prep_time
# 15 mins         502
# 10 mins         434
# 20 mins         373
# 5 mins          179
# 30 mins         159
# 25 mins          99
# 40 mins          27
# 45 mins          26
# 35 mins          25
# 1 hr             18
# 4 mins            3
# 1 hr 10 mins      2
# 3 mins            2
# 50 mins           2
# 2 mins            2
# 2 hrs             1
# 1 hr 30 mins      1
# 22 mins           1
# 1 hr 25 mins      1
# 5 hrs             1
# 8 mins            1
# Name: count, dtype: int64

# %%
# Look at values in cook_time column
df['cook_time'].value_counts()
# Out:
# cook_time
# 15 mins          248
# 10 mins          236
# 20 mins          227
# 30 mins          133
# 25 mins          118
#                 ...
# 5 hrs 10 mins      1
# 1 hr 28 mins       1
# 13 mins            1
# 14 mins            1
# 1 hr 22 mins       1
# Name: count, Length: 84, dtype: int64

# %%
# Look at values in total_time column
df['total_time'].value_counts()
# Out:
# total_time
# 30 mins          161
# 40 mins          122
# 35 mins          120
# 25 mins          117
# 45 mins          102
#                 ...
# 4 hrs 55 mins      1
# 8 hrs 45 mins      1
# 38 mins            1
# 5 hrs 30 mins      1
# 1 hr 47 mins       1
# Name: count, Length: 177, dtype: int64

# %% [markdown]
# #### Time Conversion Function
# - Function that takes in a string and converts to minutes

# %%
# Define the function
def convert_to_minutes(time_str): 

    # Return the value as is if it's already NaN or empty
    if pd.isna(time_str) or not time_str:
        return time_str

    # Turn into string to process
    time_str = str(time_str).strip()
    
    # Try to convert to float directly (for 20.0, etc)
    try:
        value = float(time_str)
        return int(value)
    except ValueError:
        pass
        
    # Define regular expression raw string
    # '(\d+)\s*days?)?' accounts for days
    # '(\d+)\s*hrs?\s*(\d+)\s*mins' accounts for hour and min string (ie. 1 hr 40 min)
    # '(\d+)\s*hrs?' accounts for hours (ie. 1 hr)
    # 's*(\d+)\s*mins' accounts for mins (ie. 40 mins)
    pattern = r'(?:(\d+)\s*days?)?\s*(?:(\d+)\s*hrs?)?\s*(?:(\d+)\s*mins?)?'

    # Matches the time_str against the pattern to see if there are any matches
    match = re.match(pattern, str(time_str))

    # If a match was found, if statements will run
    if match:
        # Case 1: days, hours, and minutes (or any subset of them)
        days = int(match.group(1)) if match.group(1) else 0
        hours = int(match.group(2)) if match.group(2) else 0
        minutes = int(match.group(3)) if match.group(3) else 0
        return days * 1440 + hours * 60 + minutes

        # Handling invalid formats
        return

# %%
# Apply function to column prep_time
df['prep_time'] = df['prep_time'].apply(convert_to_minutes)

# %%
# Confirm
df['prep_time'].value_counts()
# Out:
# prep_time
# 15.0     502
# 10.0     434
# 20.0     373
# 5.0      179
# 30.0     159
# 25.0      99
# 40.0      27
# 45.0      26
# 35.0      25
# 60.0      18
# 4.0        3
# 70.0       2
# 3.0        2
# 50.0       2
# 2.0        2
# 120.0      1
# 90.0       1
# 22.0       1
# 85.0       1
# 300.0      1
# 8.0        1
# Name: count, dtype: int64

# %%
# Apply function to column cook_time
df['cook_time'] = df['cook_time'].apply(convert_to_minutes)

# %%
# Confirm
df['cook_time'].value_counts()
# Out:
# cook_time
# 15.0     248
# 10.0     236
# 20.0     227
# 30.0     133
# 25.0     118
#         ...
# 310.0      1
# 88.0       1
# 13.0       1
# 14.0       1
# 82.0       1
# Name: count, Length: 84, dtype: int64

# %%
# Apply function to column total_time
df['total_time'] = df['total_time'].apply(convert_to_minutes)

# %%
# Confirm
df['total_time'].value_counts()
# Out:
# total_time
# 30     161
# 40     122
# 35     120
# 25     117
# 45     102
#       ...
# 295      1
# 525      1
# 38       1
# 330      1
# 107      1
# Name: count, Length: 177, dtype: int64

# %%
# Check to make sure everything converted corerctly
df.isnull().sum()
# Out:
# title            0
# intro            0
# prep_time       11
# cook_time      171
# total_time       0
# servings         0
# ingredients      0
# directions       0
# nutrition        0
# recipe_url       0
# dtype: int64

# %% [markdown]
# ### 5. Fix servings column
# - 'servings' column contains extra information beyond the serving amount
# - Strip and removed all extra characters besides numeric serving
# - Convert servings column to numeric data type

# %%
# Check how data is stored in servings column
df['servings'].unique()
# Out:
# array(['16', '6', '12', '9', '64', '10', '18', '2', '4',
#        '12 large squares', '20', '5', '8', '1', '36', '24', '42', '48',
#        '6 servings', '10 to 12', '15', '4 (serving size: 1 sandwich)',
#        '4 servings', '8 servings', '3', '4 (serving size: 1 apple)',
#        '10 Servings', '12 servings', '21', '4.0', '5.0', '6.0', '1.0',
#        '2.0', '8.0', '12.0', '6 to 8', '3.0',
#        '4 (serving size: 1 sandwich [1 bun, 1 fillet, 2 Tbsp. tartar sauce, 1 slice cheese)',
#        '12 sliders', '10.0', '7.0', '4 to 6',
#        '6 (serving size: about 1 1/3 cups pasta, about 2 tenderloins)',
#        '8 to 10', '4 (serving size: about 1 1/4 cup oatmeal mixture)',
#        '2 to 3', '8 (serving size: 3 slices)',
#        '4 (serving size: one puff pastry wrapped salmon fillet)',
#        '8 (serving size: 1 Funyun’s bag)', '4 (serving size: 2 toasts)',
#        '16.0', '15.0', '18.0', '24.0', '6 (serving size: 2 tacos)', '7',
#        '4 (serving size: 1 cutlet, 2 Tbsp. sauce)',
#        '10 (serving size: about 1 cup)',
#        '6 (serving size: about 6 oz. chicken )', '13', '32',
#        '6 (serving size: about 1 1/2 cup)', '4 (serving size: 1 1/4 cup)',
#        '4 (serving size:1 1/2 cups)', '4 large servings', '72', '25',
#        '35', '12 slices', '28', '33', '45', '22', '44',
#        '4 to 6 (serving size: about 1/3 cup)', '26', '1 serving',
#        '2 servings', '14'], dtype=object)

# %%
# Clean servings column
df['servings'] = df['servings'].str.extract(r'(\d+\.?\d*)', expand=False)
# Removes extra characters

# %%
# Convert the servings column to numeric (float or int)
df['servings'] = pd.to_numeric(df['servings'], errors='coerce')

# %%
# Confirm
df['servings'].value_counts()
# Out:
# servings
# 4.0     578
# 6.0     376
# 8.0     274
# 2.0     164
# 12.0    137
# 1.0      83
# 10.0     70
# 5.0      40
# 16.0     39
# 3.0      21
# 24.0     18
# 20.0     16
# 18.0     13
# 15.0      9
# 9.0       6
# 36.0      4
# 7.0       4
# 32.0      2
# 48.0      2
# 21.0      1
# 42.0      1
# 13.0      1
# 64.0      1
# 72.0      1
# 25.0      1
# 35.0      1
# 28.0      1
# 33.0      1
# 45.0      1
# 22.0      1
# 44.0      1
# 26.0      1
# 14.0      1
# Name: count, dtype: int64

# %% [markdown]
# ## Transforming

# %% [markdown]
# ### 1. Nutrition Column
# - 'nutrition' column contains: Calories, Fat, Carbs, & Protein
# - Seperate out calories and different macros into seperate categories

# %%
df['nutrition'].head()
# Out:
# 0    {'Calories': '405', 'Fat': '31g', 'Carbs': '28...
# 2    {'Calories': '1058', 'Fat': '65g', 'Carbs': '1...
# 3    {'Calories': '824', 'Fat': '55g', 'Carbs': '80...
# 4    {'Calories': '231', 'Fat': '12g', 'Carbs': '29...
# 5    {'Calories': '534', 'Fat': '31g', 'Carbs': '61...
# Name: nutrition, dtype: object

# %%
# Function to clean nutrition data and convert it to a dictionary
def clean_and_parse_nutrition(nutrition_str):
    if isinstance(nutrition_str, str):
        # Clean string by removing 'g' and replace single quotes with double quotes
        cleaned_str = re.sub(r'(\d+)(g)', r'\1', nutrition_str)  # Removes 'g'
        cleaned_str = cleaned_str.replace("'", '"')  # Replaces single quotes with double quotes for valid JSON
        print(f"Cleaned string: {cleaned_str}")  # Print the cleaned string for debugging
        try:
            return ast.literal_eval(cleaned_str)  # Convert to dictionary
        except Exception as e:
            print(f"Error parsing string: {nutrition_str}, Error: {e}")
            return {}
    return {}

# %%
# Apply the cleaning function to the 'nutrition' column
df['nutrition'] = df['nutrition'].apply(clean_and_parse_nutrition)
# Out:
# Cleaned string: {"Calories": "405", "Fat": "31", "Carbs": "28", "Protein": "5"}
# Cleaned string: {"Calories": "1058", "Fat": "65", "Carbs": "113", "Protein": "10"}
# Cleaned string: {"Calories": "824", "Fat": "55", "Carbs": "80", "Protein": "9"}
# Cleaned string: {"Calories": "231", "Fat": "12", "Carbs": "29", "Protein": "3"}
# Cleaned string: {"Calories": "534", "Fat": "31", "Carbs": "61", "Protein": "6"}
# Cleaned string: {"Calories": "86", "Fat": "4", "Carbs": "11", "Protein": "1"}
# Cleaned string: {"Calories": "256", "Fat": "15", "Carbs": "24", "Protein": "9"}
# Cleaned string: {"Calories": "143", "Fat": "6", "Carbs": "20", "Protein": "2"}
# Cleaned string: {"Calories": "107", "Fat": "7", "Carbs": "10", "Protein": "1"}
# Cleaned string: {"Calories": "260", "Fat": "16", "Carbs": "26", "Protein": "4"}
# Cleaned string: {"Calories": "174", "Fat": "8", "Carbs": "25", "Protein": "2"}
# Cleaned string: {"Calories": "501", "Fat": "20", "Carbs": "79", "Protein": "5"}
# Cleaned string: {"Calories": "889", "Fat": "49", "Carbs": "108", "Protein": "8"}
# Cleaned string: {"Calories": "275", "Fat": "8", "Carbs": "50", "Protein": "3"}
# Cleaned string: {"Calories": "252", "Fat": "22", "Carbs": "12", "Protein": "3"}
# Cleaned string: {"Calories": "268", "Fat": "11", "Carbs": "40", "Protein": "3"}
# Cleaned string: {"Calories": "420", "Fat": "33", "Carbs": "29", "Protein": "6"}
# Cleaned string: {"Calories": "327", "Fat": "11", "Carbs": "52", "Protein": "5"}
# Cleaned string: {"Calories": "321", "Fat": "20", "Carbs": "36", "Protein": "1"}
# Cleaned string: {"Calories": "401", "Fat": "23", "Carbs": "48", "Protein": "4"}
# Cleaned string: {"Calories": "227", "Fat": "19", "Carbs": "9", "Protein": "5"}
# Cleaned string: {"Calories": "759", "Fat": "39", "Carbs": "92", "Protein": "7"}
# Cleaned string: {"Calories": "400", "Fat": "26", "Carbs": "40", "Protein": "4"}
# Cleaned string: {"Calories": "331", "Fat": "16", "Carbs": "46", "Protein": "3"}
# Cleaned string: {"Calories": "148", "Fat": "9", "Carbs": "16", "Protein": "2"}
# Cleaned string: {"Calories": "1064", "Fat": "60", "Carbs": "124", "Protein": "8"}
# Cleaned string: {"Calories": "405", "Fat": "30", "Carbs": "32", "Protein": "5"}
# Cleaned string: {"Calories": "322", "Fat": "24", "Carbs": "29", "Protein": "3"}
# Cleaned string: {"Calories": "848", "Fat": "58", "Carbs": "66", "Protein": "11"}
# Cleaned string: {"Calories": "506", "Fat": "32", "Carbs": "53", "Protein": "8"}
# Cleaned string: {"Calories": "675", "Fat": "33", "Carbs": "89", "Protein": "8"}
# Cleaned string: {"Calories": "278", "Fat": "12", "Carbs": "42", "Protein": "2"}
# Cleaned string: {"Calories": "448", "Fat": "27", "Carbs": "45", "Protein": "5"}
# Cleaned string: {"Calories": "351", "Fat": "22", "Carbs": "39", "Protein": "2"}
# Cleaned string: {"Calories": "305", "Fat": "23", "Carbs": "19", "Protein": "2"}
# Cleaned string: {"Calories": "785", "Fat": "45", "Carbs": "81", "Protein": "18"}
# Cleaned string: {"Calories": "890", "Fat": "37", "Carbs": "134", "Protein": "11"}
# Cleaned string: {"Calories": "681", "Fat": "35", "Carbs": "90", "Protein": "7"}
# Cleaned string: {"Calories": "518", "Fat": "23", "Carbs": "79", "Protein": "7"}
# Cleaned string: {"Calories": "128", "Fat": "7", "Carbs": "17", "Protein": "2"}
# Cleaned string: {"Calories": "730", "Fat": "57", "Carbs": "45", "Protein": "14"}
# Cleaned string: {"Calories": "521", "Fat": "22", "Carbs": "71", "Protein": "12"}
# Cleaned string: {"Calories": "126", "Fat": "9", "Carbs": "9", "Protein": "4"}
# Cleaned string: {"Calories": "309", "Fat": "10", "Carbs": "52", "Protein": "3"}
# Cleaned string: {"Calories": "775", "Fat": "54", "Carbs": "71", "Protein": "11"}
# Cleaned string: {"Calories": "219", "Fat": "15", "Carbs": "20", "Protein": "3"}
# Cleaned string: {"Calories": "184", "Fat": "9", "Carbs": "28", "Protein": "2"}
# Cleaned string: {"Calories": "889", "Fat": "52", "Carbs": "103", "Protein": "9"}
# Cleaned string: {"Calories": "348", "Fat": "19", "Carbs": "46", "Protein": "3"}
# Cleaned string: {"Calories": "603", "Fat": "30", "Carbs": "82", "Protein": "7"}
# Cleaned string: {"Calories": "284", "Fat": "14", "Carbs": "39", "Protein": "3"}
# Cleaned string: {"Calories": "160", "Fat": "5", "Carbs": "26", "Protein": "2"}
# Cleaned string: {"Calories": "145", "Fat": "8", "Carbs": "17", "Protein": "2"}
# Cleaned string: {"Calories": "110", "Fat": "5", "Carbs": "16", "Protein": "2"}
# Cleaned string: {"Calories": "147", "Fat": "5", "Carbs": "25", "Protein": "2"}
# Cleaned string: {"Calories": "125", "Fat": "7", "Carbs": "16", "Protein": "2"}
# Cleaned string: {"Calories": "453", "Fat": "25", "Carbs": "30", "Protein": "27"}
# Cleaned string: {"Calories": "518", "Fat": "13", "Carbs": "82", "Protein": "20"}
# Cleaned string: {"Calories": "431", "Fat": "17", "Carbs": "38", "Protein": "31"}
# Cleaned string: {"Calories": "496", "Fat": "45", "Carbs": "8", "Protein": "16"}
# Cleaned string: {"Calories": "315", "Fat": "22", "Carbs": "21", "Protein": "8"}
# Cleaned string: {"Calories": "579", "Fat": "18", "Carbs": "42", "Protein": "62"}
# Cleaned string: {"Calories": "358", "Fat": "17", "Carbs": "34", "Protein": "17"}
# Cleaned string: {"Calories": "429", "Fat": "39", "Carbs": "5", "Protein": "11"}
# Cleaned string: {"Calories": "177", "Fat": "9", "Carbs": "14", "Protein": "12"}
# Cleaned string: {"Calories": "578", "Fat": "32", "Carbs": "54", "Protein": "20"}
# Cleaned string: {"Calories": "656", "Fat": "40", "Carbs": "57", "Protein": "16"}
# Cleaned string: {"Calories": "230", "Fat": "16", "Carbs": "11", "Protein": "13"}
# Cleaned string: {"Calories": "627", "Fat": "43", "Carbs": "30", "Protein": "33"}
# Cleaned string: {"Calories": "157", "Fat": "8", "Carbs": "10", "Protein": "12"}
# Cleaned string: {"Calories": "467", "Fat": "28", "Carbs": "17", "Protein": "38"}
# Cleaned string: {"Calories": "301", "Fat": "24", "Carbs": "7", "Protein": "15"}
# Cleaned string: {"Calories": "779", "Fat": "56", "Carbs": "6", "Protein": "62"}
# Cleaned string: {"Calories": "478", "Fat": "21", "Carbs": "47", "Protein": "28"}
# Cleaned string: {"Calories": "411", "Fat": "29", "Carbs": "6", "Protein": "28"}
# Cleaned string: {"Calories": "472", "Fat": "14", "Carbs": "26", "Protein": "61"}
# Cleaned string: {"Calories": "434", "Fat": "21", "Carbs": "15", "Protein": "45"}
# Cleaned string: {"Calories": "550", "Fat": "31", "Carbs": "49", "Protein": "20"}
# Cleaned string: {"Calories": "284", "Fat": "18", "Carbs": "13", "Protein": "14"}
# Cleaned string: {"Calories": "688", "Fat": "36", "Carbs": "70", "Protein": "20"}
# Cleaned string: {"Calories": "504", "Fat": "32", "Carbs": "1", "Protein": "51"}
# Cleaned string: {"Calories": "682", "Fat": "27", "Carbs": "68", "Protein": "45"}
# Cleaned string: {"Calories": "506", "Fat": "23", "Carbs": "21", "Protein": "51"}
# Cleaned string: {"Calories": "105", "Fat": "6", "Carbs": "7", "Protein": "6"}
# Cleaned string: {"Calories": "208", "Fat": "6", "Carbs": "1", "Protein": "30"}
# Cleaned string: {"Calories": "408", "Fat": "28", "Carbs": "15", "Protein": "24"}
# Cleaned string: {"Calories": "599", "Fat": "39", "Carbs": "35", "Protein": "36"}
# Cleaned string: {"Calories": "200", "Fat": "6", "Carbs": "9", "Protein": "26"}
# Cleaned string: {"Calories": "381", "Fat": "26", "Carbs": "13", "Protein": "25"}
# Cleaned string: {"Calories": "307", "Fat": "10", "Carbs": "18", "Protein": "36"}
# Cleaned string: {"Calories": "787", "Fat": "33", "Carbs": "90", "Protein": "32"}
# Cleaned string: {"Calories": "166", "Fat": "12", "Carbs": "4", "Protein": "10"}
# Cleaned string: {"Calories": "294", "Fat": "20", "Carbs": "1", "Protein": "26"}
# Cleaned string: {"Calories": "528", "Fat": "23", "Carbs": "46", "Protein": "32"}
# Cleaned string: {"Calories": "333", "Fat": "19", "Carbs": "31", "Protein": "10"}
# Cleaned string: {"Calories": "300", "Fat": "21", "Carbs": "1", "Protein": "23"}
# Cleaned string: {"Calories": "390", "Fat": "31", "Carbs": "5", "Protein": "21"}
# Cleaned string: {"Calories": "613", "Fat": "53", "Carbs": "7", "Protein": "27"}
# Cleaned string: {"Calories": "488", "Fat": "23", "Carbs": "52", "Protein": "19"}
# Cleaned string: {"Calories": "290", "Fat": "13", "Carbs": "14", "Protein": "30"}
# Cleaned string: {"Calories": "511", "Fat": "30", "Carbs": "19", "Protein": "39"}
# Cleaned string: {"Calories": "911", "Fat": "71", "Carbs": "21", "Protein": "48"}
# Cleaned string: {"Calories": "360", "Fat": "20", "Carbs": "18", "Protein": "26"}
# Cleaned string: {"Calories": "501", "Fat": "30", "Carbs": "32", "Protein": "24"}
# Cleaned string: {"Calories": "442", "Fat": "32", "Carbs": "15", "Protein": "24"}
# Cleaned string: {"Calories": "243", "Fat": "16", "Carbs": "2", "Protein": "21"}
# Cleaned string: {"Calories": "521", "Fat": "28", "Carbs": "42", "Protein": "26"}
# Cleaned string: {"Calories": "189", "Fat": "8", "Carbs": "4", "Protein": "24"}
# Cleaned string: {"Calories": "625", "Fat": "31", "Carbs": "39", "Protein": "46"}
# Cleaned string: {"Calories": "521", "Fat": "34", "Carbs": "33", "Protein": "22"}
# Cleaned string: {"Calories": "539", "Fat": "30", "Carbs": "46", "Protein": "20"}
# Cleaned string: {"Calories": "635", "Fat": "40", "Carbs": "14", "Protein": "52"}
# Cleaned string: {"Calories": "305", "Fat": "17", "Carbs": "2", "Protein": "35"}
# Cleaned string: {"Calories": "313", "Fat": "15", "Carbs": "1", "Protein": "41"}
# Cleaned string: {"Calories": "210", "Fat": "9", "Carbs": "10", "Protein": "24"}
# Cleaned string: {"Calories": "353", "Fat": "25", "Carbs": "4", "Protein": "27"}
# Cleaned string: {"Calories": "943", "Fat": "61", "Carbs": "37", "Protein": "58"}
# Cleaned string: {"Calories": "396", "Fat": "26", "Carbs": "16", "Protein": "24"}
# Cleaned string: {"Calories": "355", "Fat": "24", "Carbs": "2", "Protein": "32"}
# Cleaned string: {"Calories": "413", "Fat": "20", "Carbs": "39", "Protein": "17"}
# Cleaned string: {"Calories": "619", "Fat": "32", "Carbs": "55", "Protein": "27"}
# Cleaned string: {"Calories": "223", "Fat": "6", "Carbs": "37", "Protein": "5"}
# Cleaned string: {"Calories": "385", "Fat": "18", "Carbs": "41", "Protein": "13"}
# Cleaned string: {"Calories": "346", "Fat": "17", "Carbs": "36", "Protein": "13"}
# Cleaned string: {"Calories": "738", "Fat": "43", "Carbs": "58", "Protein": "30"}
# Cleaned string: {"Calories": "649", "Fat": "34", "Carbs": "50", "Protein": "34"}
# Cleaned string: {"Calories": "562", "Fat": "21", "Carbs": "66", "Protein": "26"}
# Cleaned string: {"Calories": "462", "Fat": "23", "Carbs": "45", "Protein": "16"}
# Cleaned string: {"Calories": "562", "Fat": "30", "Carbs": "13", "Protein": "57"}
# Cleaned string: {"Calories": "286", "Fat": "8", "Carbs": "39", "Protein": "15"}
# Cleaned string: {"Calories": "1031", "Fat": "71", "Carbs": "53", "Protein": "44"}
# Cleaned string: {"Calories": "334", "Fat": "14", "Carbs": "37", "Protein": "15"}
# Cleaned string: {"Calories": "460", "Fat": "18", "Carbs": "56", "Protein": "17"}
# Cleaned string: {"Calories": "578", "Fat": "28", "Carbs": "59", "Protein": "22"}
# Cleaned string: {"Calories": "247", "Fat": "11", "Carbs": "27", "Protein": "11"}
# Cleaned string: {"Calories": "318", "Fat": "15", "Carbs": "30", "Protein": "15"}
# Cleaned string: {"Calories": "445", "Fat": "19", "Carbs": "43", "Protein": "28"}
# Cleaned string: {"Calories": "245", "Fat": "10", "Carbs": "30", "Protein": "9"}
# Cleaned string: {"Calories": "551", "Fat": "19", "Carbs": "81", "Protein": "17"}
# Cleaned string: {"Calories": "456", "Fat": "18", "Carbs": "53", "Protein": "21"}
# Cleaned string: {"Calories": "343", "Fat": "20", "Carbs": "24", "Protein": "16"}
# Cleaned string: {"Calories": "433", "Fat": "17", "Carbs": "57", "Protein": "12"}
# Cleaned string: {"Calories": "461", "Fat": "21", "Carbs": "57", "Protein": "11"}
# Cleaned string: {"Calories": "1301", "Fat": "78", "Carbs": "104", "Protein": "44"}
# Cleaned string: {"Calories": "164", "Fat": "5", "Carbs": "24", "Protein": "7"}
# Cleaned string: {"Calories": "569", "Fat": "26", "Carbs": "54", "Protein": "29"}
# Cleaned string: {"Calories": "654", "Fat": "35", "Carbs": "57", "Protein": "27"}
# Cleaned string: {"Calories": "732", "Fat": "16", "Carbs": "118", "Protein": "29"}
# Cleaned string: {"Calories": "443", "Fat": "15", "Carbs": "61", "Protein": "16"}
# Cleaned string: {"Calories": "291", "Fat": "16", "Carbs": "23", "Protein": "15"}
# Cleaned string: {"Calories": "325", "Fat": "14", "Carbs": "38", "Protein": "13"}
# Cleaned string: {"Calories": "301", "Fat": "17", "Carbs": "28", "Protein": "8"}
# Cleaned string: {"Calories": "321", "Fat": "24", "Carbs": "14", "Protein": "12"}
# Cleaned string: {"Calories": "4455", "Fat": "105", "Carbs": "746", "Protein": "117"}
# Cleaned string: {"Calories": "287", "Fat": "11", "Carbs": "41", "Protein": "6"}
# Cleaned string: {"Calories": "602", "Fat": "37", "Carbs": "31", "Protein": "44"}
# Cleaned string: {"Calories": "833", "Fat": "43", "Carbs": "37", "Protein": "71"}
# Cleaned string: {"Calories": "196", "Fat": "13", "Carbs": "16", "Protein": "5"}
# Cleaned string: {"Calories": "385", "Fat": "16", "Carbs": "38", "Protein": "23"}
# Cleaned string: {"Calories": "194", "Fat": "14", "Carbs": "8", "Protein": "10"}
# Cleaned string: {"Calories": "322", "Fat": "14", "Carbs": "34", "Protein": "14"}
# Cleaned string: {"Calories": "966", "Fat": "36", "Carbs": "101", "Protein": "55"}
# Cleaned string: {"Calories": "885", "Fat": "51", "Carbs": "60", "Protein": "48"}
# Cleaned string: {"Calories": "714", "Fat": "35", "Carbs": "64", "Protein": "35"}
# Cleaned string: {"Calories": "301", "Fat": "19", "Carbs": "23", "Protein": "12"}
# Cleaned string: {"Calories": "327", "Fat": "14", "Carbs": "30", "Protein": "21"}
# Cleaned string: {"Calories": "370", "Fat": "19", "Carbs": "32", "Protein": "20"}
# Cleaned string: {"Calories": "467", "Fat": "39", "Carbs": "21", "Protein": "9"}
# Cleaned string: {"Calories": "158", "Fat": "6", "Carbs": "20", "Protein": "8"}
# Cleaned string: {"Calories": "590", "Fat": "29", "Carbs": "60", "Protein": "20"}
# Cleaned string: {"Calories": "340", "Fat": "22", "Carbs": "16", "Protein": "21"}
# Cleaned string: {"Calories": "212", "Fat": "11", "Carbs": "22", "Protein": "6"}
# Cleaned string: {"Calories": "145", "Fat": "5", "Carbs": "19", "Protein": "6"}
# Cleaned string: {"Calories": "394", "Fat": "20", "Carbs": "39", "Protein": "17"}
# Cleaned string: {"Calories": "24", "Fat": "2", "Carbs": "1", "Protein": "0"}
# Cleaned string: {"Calories": "174", "Fat": "6", "Carbs": "21", "Protein": "8"}
# Cleaned string: {"Calories": "511", "Fat": "20", "Carbs": "56", "Protein": "23"}
# Cleaned string: {"Calories": "613", "Fat": "32", "Carbs": "53", "Protein": "25"}
# Cleaned string: {"Calories": "251", "Fat": "10", "Carbs": "39", "Protein": "2"}
# Cleaned string: {"Calories": "230", "Fat": "10", "Carbs": "30", "Protein": "5"}
# Cleaned string: {"Calories": "270", "Fat": "15", "Carbs": "36", "Protein": "3"}
# Cleaned string: {"Calories": "168", "Fat": "4", "Carbs": "27", "Protein": "6"}
# Cleaned string: {"Calories": "437", "Fat": "20", "Carbs": "59", "Protein": "5"}
# Cleaned string: {"Calories": "593", "Fat": "25", "Carbs": "87", "Protein": "7"}
# Cleaned string: {"Calories": "242", "Fat": "2", "Carbs": "48", "Protein": "3"}
# Cleaned string: {"Calories": "273", "Fat": "12", "Carbs": "40", "Protein": "3"}
# Cleaned string: {"Calories": "396", "Fat": "10", "Carbs": "72", "Protein": "7"}
# Cleaned string: {"Calories": "1024", "Fat": "59", "Carbs": "119", "Protein": "10"}
# Cleaned string: {"Calories": "364", "Fat": "15", "Carbs": "59", "Protein": "2"}
# Cleaned string: {"Calories": "745", "Fat": "41", "Carbs": "97", "Protein": "5"}
# Cleaned string: {"Calories": "528", "Fat": "30", "Carbs": "62", "Protein": "5"}
# Cleaned string: {"Calories": "627", "Fat": "27", "Carbs": "95", "Protein": "5"}
# Cleaned string: {"Calories": "312", "Fat": "15", "Carbs": "37", "Protein": "9"}
# Cleaned string: {"Calories": "374", "Fat": "18", "Carbs": "52", "Protein": "3"}
# Cleaned string: {"Calories": "318", "Fat": "13", "Carbs": "44", "Protein": "7"}
# Cleaned string: {"Calories": "96", "Fat": "0", "Carbs": "25", "Protein": "1"}
# Cleaned string: {"Calories": "389", "Fat": "13", "Carbs": "67", "Protein": "3"}
# Cleaned string: {"Calories": "131", "Fat": "0", "Carbs": "33", "Protein": "1"}
# Cleaned string: {"Calories": "312", "Fat": "9", "Carbs": "58", "Protein": "3"}
# Cleaned string: {"Calories": "351", "Fat": "16", "Carbs": "53", "Protein": "2"}
# Cleaned string: {"Calories": "221", "Fat": "16", "Carbs": "18", "Protein": "4"}
# Cleaned string: {"Calories": "304", "Fat": "13", "Carbs": "45", "Protein": "4"}
# Cleaned string: {"Calories": "382", "Fat": "16", "Carbs": "49", "Protein": "10"}
# Cleaned string: {"Calories": "295", "Fat": "17", "Carbs": "35", "Protein": "2"}
# Cleaned string: {"Calories": "391", "Fat": "27", "Carbs": "34", "Protein": "5"}
# Cleaned string: {"Calories": "173", "Fat": "8", "Carbs": "23", "Protein": "2"}
# Cleaned string: {"Calories": "133", "Fat": "8", "Carbs": "15", "Protein": "1"}
# Cleaned string: {"Calories": "358", "Fat": "19", "Carbs": "44", "Protein": "5"}
# Cleaned string: {"Calories": "367", "Fat": "3", "Carbs": "79", "Protein": "7"}
# Cleaned string: {"Calories": "694", "Fat": "38", "Carbs": "82", "Protein": "10"}
# Cleaned string: {"Calories": "18", "Fat": "0", "Carbs": "4", "Protein": "0"}
# Cleaned string: {"Calories": "398", "Fat": "12", "Carbs": "64", "Protein": "10"}
# Cleaned string: {"Calories": "650", "Fat": "44", "Carbs": "58", "Protein": "8"}
# Cleaned string: {"Calories": "322", "Fat": "19", "Carbs": "27", "Protein": "5"}
# Cleaned string: {"Calories": "257", "Fat": "16", "Carbs": "27", "Protein": "3"}
# Cleaned string: {"Calories": "323", "Fat": "15", "Carbs": "46", "Protein": "4"}
# Cleaned string: {"Calories": "670", "Fat": "34", "Carbs": "86", "Protein": "8"}
# Cleaned string: {"Calories": "160", "Fat": "6", "Carbs": "23", "Protein": "4"}
# Cleaned string: {"Calories": "465", "Fat": "12", "Carbs": "80", "Protein": "11"}
# Cleaned string: {"Calories": "448", "Fat": "24", "Carbs": "53", "Protein": "6"}
# Cleaned string: {"Calories": "242", "Fat": "13", "Carbs": "30", "Protein": "3"}
# Cleaned string: {"Calories": "431", "Fat": "20", "Carbs": "58", "Protein": "6"}
# Cleaned string: {"Calories": "277", "Fat": "10", "Carbs": "43", "Protein": "4"}
# Cleaned string: {"Calories": "345", "Fat": "10", "Carbs": "68", "Protein": "3"}
# Cleaned string: {"Calories": "141", "Fat": "0", "Carbs": "30", "Protein": "1"}
# Cleaned string: {"Calories": "112", "Fat": "5", "Carbs": "16", "Protein": "1"}
# Cleaned string: {"Calories": "287", "Fat": "13", "Carbs": "38", "Protein": "3"}
# Cleaned string: {"Calories": "314", "Fat": "15", "Carbs": "42", "Protein": "4"}
# Cleaned string: {"Calories": "104", "Fat": "0", "Carbs": "24", "Protein": "1"}
# Cleaned string: {"Calories": "479", "Fat": "21", "Carbs": "71", "Protein": "4"}
# Cleaned string: {"Calories": "567", "Fat": "31", "Carbs": "67", "Protein": "7"}
# Cleaned string: {"Calories": "317", "Fat": "17", "Carbs": "38", "Protein": "5"}
# Cleaned string: {"Calories": "319", "Fat": "14", "Carbs": "46", "Protein": "3"}
# Cleaned string: {"Calories": "476", "Fat": "17", "Carbs": "79", "Protein": "3"}
# Cleaned string: {"Calories": "628", "Fat": "32", "Carbs": "82", "Protein": "7"}
# Cleaned string: {"Calories": "234", "Fat": "8", "Carbs": "37", "Protein": "3"}
# Cleaned string: {"Calories": "268", "Fat": "15", "Carbs": "35", "Protein": "1"}
# Cleaned string: {"Calories": "150", "Fat": "8", "Carbs": "14", "Protein": "8"}
# Cleaned string: {"Calories": "257", "Fat": "10", "Carbs": "20", "Protein": "24"}
# Cleaned string: {"Calories": "150", "Fat": "4", "Carbs": "17", "Protein": "14"}
# Cleaned string: {"Calories": "161", "Fat": "13", "Carbs": "7", "Protein": "4"}
# Cleaned string: {"Calories": "399", "Fat": "16", "Carbs": "54", "Protein": "19"}
# Cleaned string: {"Calories": "143", "Fat": "7", "Carbs": "18", "Protein": "3"}
# Cleaned string: {"Calories": "196", "Fat": "9", "Carbs": "25", "Protein": "8"}
# Cleaned string: {"Calories": "608", "Fat": "31", "Carbs": "41", "Protein": "40"}
# Cleaned string: {"Calories": "649", "Fat": "33", "Carbs": "53", "Protein": "38"}
# Cleaned string: {"Calories": "445", "Fat": "23", "Carbs": "29", "Protein": "28"}
# Cleaned string: {"Calories": "665", "Fat": "32", "Carbs": "57", "Protein": "39"}
# Cleaned string: {"Calories": "475", "Fat": "18", "Carbs": "40", "Protein": "41"}
# Cleaned string: {"Calories": "565", "Fat": "30", "Carbs": "40", "Protein": "36"}
# Cleaned string: {"Calories": "421", "Fat": "13", "Carbs": "24", "Protein": "51"}
# Cleaned string: {"Calories": "619", "Fat": "29", "Carbs": "48", "Protein": "39"}
# Cleaned string: {"Calories": "353", "Fat": "10", "Carbs": "21", "Protein": "44"}
# Cleaned string: {"Calories": "1167", "Fat": "48", "Carbs": "125", "Protein": "62"}
# Cleaned string: {"Calories": "266", "Fat": "8", "Carbs": "9", "Protein": "38"}
# Cleaned string: {"Calories": "299", "Fat": "15", "Carbs": "39", "Protein": "8"}
# Cleaned string: {"Calories": "212", "Fat": "11", "Carbs": "23", "Protein": "10"}
# Cleaned string: {"Calories": "428", "Fat": "9", "Carbs": "30", "Protein": "55"}
# Cleaned string: {"Calories": "491", "Fat": "7", "Carbs": "67", "Protein": "34"}
# Cleaned string: {"Calories": "460", "Fat": "22", "Carbs": "16", "Protein": "48"}
# Cleaned string: {"Calories": "596", "Fat": "27", "Carbs": "63", "Protein": "26"}
# Cleaned string: {"Calories": "300", "Fat": "10", "Carbs": "22", "Protein": "29"}
# Cleaned string: {"Calories": "362", "Fat": "3", "Carbs": "44", "Protein": "38"}
# Cleaned string: {"Calories": "268", "Fat": "16", "Carbs": "9", "Protein": "23"}
# Cleaned string: {"Calories": "344", "Fat": "7", "Carbs": "45", "Protein": "25"}
# Cleaned string: {"Calories": "369", "Fat": "5", "Carbs": "65", "Protein": "18"}
# Cleaned string: {"Calories": "189", "Fat": "11", "Carbs": "19", "Protein": "5"}
# Cleaned string: {"Calories": "259", "Fat": "9", "Carbs": "20", "Protein": "24"}
# Cleaned string: {"Calories": "188", "Fat": "8", "Carbs": "13", "Protein": "18"}
# Cleaned string: {"Calories": "437", "Fat": "23", "Carbs": "25", "Protein": "34"}
# Cleaned string: {"Calories": "270", "Fat": "18", "Carbs": "12", "Protein": "16"}
# Cleaned string: {"Calories": "663", "Fat": "35", "Carbs": "75", "Protein": "14"}
# Cleaned string: {"Calories": "391", "Fat": "12", "Carbs": "55", "Protein": "18"}
# Cleaned string: {"Calories": "184", "Fat": "10", "Carbs": "9", "Protein": "14"}
# Cleaned string: {"Calories": "331", "Fat": "21", "Carbs": "13", "Protein": "22"}
# Cleaned string: {"Calories": "343", "Fat": "12", "Carbs": "29", "Protein": "34"}
# Cleaned string: {"Calories": "312", "Fat": "15", "Carbs": "17", "Protein": "26"}
# Cleaned string: {"Calories": "906", "Fat": "15", "Carbs": "168", "Protein": "22"}
# Cleaned string: {"Calories": "119", "Fat": "9", "Carbs": "8", "Protein": "2"}
# Cleaned string: {"Calories": "332", "Fat": "10", "Carbs": "48", "Protein": "12"}
# Cleaned string: {"Calories": "314", "Fat": "16", "Carbs": "20", "Protein": "22"}
# Cleaned string: {"Calories": "319", "Fat": "14", "Carbs": "17", "Protein": "30"}
# Cleaned string: {"Calories": "364", "Fat": "14", "Carbs": "45", "Protein": "15"}
# Cleaned string: {"Calories": "416", "Fat": "25", "Carbs": "16", "Protein": "34"}
# Cleaned string: {"Calories": "459", "Fat": "31", "Carbs": "16", "Protein": "33"}
# Cleaned string: {"Calories": "372", "Fat": "22", "Carbs": "16", "Protein": "28"}
# Cleaned string: {"Calories": "344", "Fat": "8", "Carbs": "60", "Protein": "9"}
# Cleaned string: {"Calories": "596", "Fat": "51", "Carbs": "19", "Protein": "22"}
# Cleaned string: {"Calories": "324", "Fat": "18", "Carbs": "13", "Protein": "28"}
# Cleaned string: {"Calories": "354", "Fat": "23", "Carbs": "16", "Protein": "22"}
# Cleaned string: {"Calories": "308", "Fat": "20", "Carbs": "5", "Protein": "26"}
# Cleaned string: {"Calories": "415", "Fat": "11", "Carbs": "55", "Protein": "26"}
# Cleaned string: {"Calories": "192", "Fat": "8", "Carbs": "15", "Protein": "17"}
# Cleaned string: {"Calories": "142", "Fat": "4", "Carbs": "7", "Protein": "18"}
# Cleaned string: {"Calories": "430", "Fat": "34", "Carbs": "7", "Protein": "27"}
# Cleaned string: {"Calories": "507", "Fat": "19", "Carbs": "59", "Protein": "27"}
# Cleaned string: {"Calories": "421", "Fat": "14", "Carbs": "49", "Protein": "27"}
# Cleaned string: {"Calories": "306", "Fat": "21", "Carbs": "13", "Protein": "18"}
# Cleaned string: {"Calories": "213", "Fat": "7", "Carbs": "12", "Protein": "28"}
# Cleaned string: {"Calories": "485", "Fat": "10", "Carbs": "80", "Protein": "22"}
# Cleaned string: {"Calories": "183", "Fat": "9", "Carbs": "16", "Protein": "12"}
# Cleaned string: {"Calories": "343", "Fat": "16", "Carbs": "14", "Protein": "37"}
# Cleaned string: {"Calories": "356", "Fat": "19", "Carbs": "14", "Protein": "36"}
# Cleaned string: {"Calories": "362", "Fat": "18", "Carbs": "23", "Protein": "26"}
# Cleaned string: {"Calories": "427", "Fat": "24", "Carbs": "15", "Protein": "38"}
# Cleaned string: {"Calories": "880", "Fat": "82", "Carbs": "13", "Protein": "26"}
# Cleaned string: {"Calories": "313", "Fat": "22", "Carbs": "14", "Protein": "19"}
# Cleaned string: {"Calories": "501", "Fat": "37", "Carbs": "19", "Protein": "30"}
# Cleaned string: {"Calories": "408", "Fat": "28", "Carbs": "16", "Protein": "23"}
# Cleaned string: {"Calories": "544", "Fat": "25", "Carbs": "64", "Protein": "17"}
# Cleaned string: {"Calories": "404", "Fat": "29", "Carbs": "13", "Protein": "25"}
# Cleaned string: {"Calories": "299", "Fat": "20", "Carbs": "18", "Protein": "17"}
# Cleaned string: {"Calories": "328", "Fat": "23", "Carbs": "13", "Protein": "18"}
# Cleaned string: {"Calories": "192", "Fat": "3", "Carbs": "33", "Protein": "12"}
# Cleaned string: {"Calories": "413", "Fat": "23", "Carbs": "46", "Protein": "9"}
# Cleaned string: {"Calories": "293", "Fat": "22", "Carbs": "22", "Protein": "5"}
# Cleaned string: {"Calories": "832", "Fat": "35", "Carbs": "79", "Protein": "48"}
# Cleaned string: {"Calories": "462", "Fat": "31", "Carbs": "41", "Protein": "9"}
# Cleaned string: {"Calories": "625", "Fat": "48", "Carbs": "19", "Protein": "34"}
# Cleaned string: {"Calories": "416", "Fat": "32", "Carbs": "11", "Protein": "23"}
# Cleaned string: {"Calories": "450", "Fat": "26", "Carbs": "18", "Protein": "39"}
# Cleaned string: {"Calories": "311", "Fat": "23", "Carbs": "6", "Protein": "20"}
# Cleaned string: {"Calories": "323", "Fat": "23", "Carbs": "17", "Protein": "14"}
# Cleaned string: {"Calories": "403", "Fat": "25", "Carbs": "21", "Protein": "27"}
# Cleaned string: {"Calories": "338", "Fat": "14", "Carbs": "12", "Protein": "42"}
# Cleaned string: {"Calories": "325", "Fat": "22", "Carbs": "4", "Protein": "28"}
# Cleaned string: {"Calories": "264", "Fat": "16", "Carbs": "9", "Protein": "20"}
# Cleaned string: {"Calories": "247", "Fat": "11", "Carbs": "8", "Protein": "29"}
# Cleaned string: {"Calories": "185", "Fat": "9", "Carbs": "19", "Protein": "8"}
# Cleaned string: {"Calories": "417", "Fat": "12", "Carbs": "50", "Protein": "26"}
# Cleaned string: {"Calories": "287", "Fat": "19", "Carbs": "9", "Protein": "22"}
# Cleaned string: {"Calories": "368", "Fat": "10", "Carbs": "42", "Protein": "28"}
# Cleaned string: {"Calories": "195", "Fat": "9", "Carbs": "16", "Protein": "15"}
# Cleaned string: {"Calories": "407", "Fat": "20", "Carbs": "51", "Protein": "10"}
# Cleaned string: {"Calories": "626", "Fat": "29", "Carbs": "50", "Protein": "41"}
# Cleaned string: {"Calories": "362", "Fat": "13", "Carbs": "45", "Protein": "21"}
# Cleaned string: {"Calories": "487", "Fat": "15", "Carbs": "82", "Protein": "9"}
# Cleaned string: {"Calories": "474", "Fat": "30", "Carbs": "13", "Protein": "38"}
# Cleaned string: {"Calories": "221", "Fat": "6", "Carbs": "33", "Protein": "10"}
# Cleaned string: {"Calories": "176", "Fat": "13", "Carbs": "16", "Protein": "4"}
# Cleaned string: {"Calories": "316", "Fat": "17", "Carbs": "13", "Protein": "27"}
# Cleaned string: {"Calories": "330", "Fat": "3", "Carbs": "57", "Protein": "21"}
# Cleaned string: {"Calories": "546", "Fat": "40", "Carbs": "12", "Protein": "28"}
# Cleaned string: {"Calories": "224", "Fat": "6", "Carbs": "34", "Protein": "11"}
# Cleaned string: {"Calories": "652", "Fat": "34", "Carbs": "79", "Protein": "13"}
# Cleaned string: {"Calories": "353", "Fat": "18", "Carbs": "32", "Protein": "19"}
# Cleaned string: {"Calories": "134", "Fat": "5", "Carbs": "7", "Protein": "15"}
# Cleaned string: {"Calories": "333", "Fat": "20", "Carbs": "23", "Protein": "19"}
# Cleaned string: {"Calories": "977", "Fat": "17", "Carbs": "163", "Protein": "44"}
# Cleaned string: {"Calories": "234", "Fat": "9", "Carbs": "20", "Protein": "19"}
# Cleaned string: {"Calories": "402", "Fat": "30", "Carbs": "24", "Protein": "15"}
# Cleaned string: {"Calories": "160", "Fat": "8", "Carbs": "6", "Protein": "16"}
# Cleaned string: {"Calories": "273", "Fat": "10", "Carbs": "31", "Protein": "17"}
# Cleaned string: {"Calories": "268", "Fat": "13", "Carbs": "5", "Protein": "31"}
# Cleaned string: {"Calories": "368", "Fat": "20", "Carbs": "11", "Protein": "36"}
# Cleaned string: {"Calories": "321", "Fat": "22", "Carbs": "8", "Protein": "23"}
# Cleaned string: {"Calories": "507", "Fat": "9", "Carbs": "83", "Protein": "25"}
# Cleaned string: {"Calories": "252", "Fat": "10", "Carbs": "14", "Protein": "26"}
# Cleaned string: {"Calories": "228", "Fat": "4", "Carbs": "44", "Protein": "8"}
# Cleaned string: {"Calories": "458", "Fat": "8", "Carbs": "87", "Protein": "10"}
# Cleaned string: {"Calories": "489", "Fat": "35", "Carbs": "16", "Protein": "28"}
# Cleaned string: {"Calories": "695", "Fat": "28", "Carbs": "66", "Protein": "45"}
# Cleaned string: {"Calories": "196", "Fat": "11", "Carbs": "10", "Protein": "15"}
# Cleaned string: {"Calories": "630", "Fat": "24", "Carbs": "79", "Protein": "24"}
# Cleaned string: {"Calories": "1262", "Fat": "85", "Carbs": "56", "Protein": "66"}
# Cleaned string: {"Calories": "1427", "Fat": "79", "Carbs": "132", "Protein": "46"}
# Cleaned string: {"Calories": "832", "Fat": "29", "Carbs": "71", "Protein": "68"}
# Cleaned string: {"Calories": "722", "Fat": "29", "Carbs": "46", "Protein": "68"}
# Cleaned string: {"Calories": "603", "Fat": "34", "Carbs": "2", "Protein": "69"}
# Cleaned string: {"Calories": "618", "Fat": "44", "Carbs": "16", "Protein": "39"}
# Cleaned string: {"Calories": "470", "Fat": "29", "Carbs": "28", "Protein": "24"}
# Cleaned string: {"Calories": "1115", "Fat": "66", "Carbs": "75", "Protein": "54"}
# Cleaned string: {"Calories": "1134", "Fat": "102", "Carbs": "10", "Protein": "42"}
# Cleaned string: {"Calories": "541", "Fat": "22", "Carbs": "38", "Protein": "51"}
# Cleaned string: {"Calories": "364", "Fat": "3", "Carbs": "60", "Protein": "23"}
# Cleaned string: {"Calories": "391", "Fat": "20", "Carbs": "5", "Protein": "47"}
# Cleaned string: {"Calories": "193", "Fat": "9", "Carbs": "4", "Protein": "22"}
# Cleaned string: {"Calories": "289", "Fat": "6", "Carbs": "42", "Protein": "16"}
# Cleaned string: {"Calories": "312", "Fat": "27", "Carbs": "1", "Protein": "17"}
# Cleaned string: {"Calories": "372", "Fat": "23", "Carbs": "22", "Protein": "19"}
# Cleaned string: {"Calories": "519", "Fat": "45", "Carbs": "2", "Protein": "25"}
# Cleaned string: {"Calories": "480", "Fat": "27", "Carbs": "29", "Protein": "29"}
# Cleaned string: {"Calories": "987", "Fat": "63", "Carbs": "63", "Protein": "41"}
# Cleaned string: {"Calories": "403", "Fat": "30", "Carbs": "17", "Protein": "17"}
# Cleaned string: {"Calories": "293", "Fat": "17", "Carbs": "4", "Protein": "28"}
# Cleaned string: {"Calories": "355", "Fat": "20", "Carbs": "25", "Protein": "18"}
# Cleaned string: {"Calories": "480", "Fat": "24", "Carbs": "42", "Protein": "25"}
# Cleaned string: {"Calories": "413", "Fat": "16", "Carbs": "43", "Protein": "22"}
# Cleaned string: {"Calories": "882", "Fat": "38", "Carbs": "94", "Protein": "36"}
# Cleaned string: {"Calories": "974", "Fat": "47", "Carbs": "48", "Protein": "85"}
# Cleaned string: {"Calories": "253", "Fat": "9", "Carbs": "21", "Protein": "24"}
# Cleaned string: {"Calories": "408", "Fat": "35", "Carbs": "5", "Protein": "17"}
# Cleaned string: {"Calories": "188", "Fat": "7", "Carbs": "20", "Protein": "11"}
# Cleaned string: {"Calories": "356", "Fat": "30", "Carbs": "6", "Protein": "15"}
# Cleaned string: {"Calories": "491", "Fat": "32", "Carbs": "16", "Protein": "33"}
# Cleaned string: {"Calories": "231", "Fat": "8", "Carbs": "32", "Protein": "9"}
# Cleaned string: {"Calories": "485", "Fat": "33", "Carbs": "1", "Protein": "45"}
# Cleaned string: {"Calories": "402", "Fat": "21", "Carbs": "19", "Protein": "33"}
# Cleaned string: {"Calories": "518", "Fat": "48", "Carbs": "1", "Protein": "19"}
# Cleaned string: {"Calories": "556", "Fat": "22", "Carbs": "62", "Protein": "27"}
# Cleaned string: {"Calories": "112", "Fat": "7", "Carbs": "5", "Protein": "1"}
# Cleaned string: {"Calories": "711", "Fat": "33", "Carbs": "30", "Protein": "73"}
# Cleaned string: {"Calories": "1257", "Fat": "50", "Carbs": "127", "Protein": "73"}
# Cleaned string: {"Calories": "409", "Fat": "19", "Carbs": "27", "Protein": "34"}
# Cleaned string: {"Calories": "240", "Fat": "9", "Carbs": "31", "Protein": "8"}
# Cleaned string: {"Calories": "424", "Fat": "21", "Carbs": "18", "Protein": "39"}
# Cleaned string: {"Calories": "717", "Fat": "43", "Carbs": "29", "Protein": "50"}
# Cleaned string: {"Calories": "1763", "Fat": "110", "Carbs": "49", "Protein": "135"}
# Cleaned string: {"Calories": "405", "Fat": "19", "Carbs": "28", "Protein": "28"}
# Cleaned string: {"Calories": "1793", "Fat": "110", "Carbs": "127", "Protein": "73"}
# Cleaned string: {"Calories": "140", "Fat": "7", "Carbs": "2", "Protein": "16"}
# Cleaned string: {"Calories": "854", "Fat": "56", "Carbs": "24", "Protein": "66"}
# Cleaned string: {"Calories": "568", "Fat": "20", "Carbs": "68", "Protein": "28"}
# Cleaned string: {"Calories": "490", "Fat": "23", "Carbs": "49", "Protein": "24"}
# Cleaned string: {"Calories": "741", "Fat": "45", "Carbs": "51", "Protein": "33"}
# Cleaned string: {"Calories": "207", "Fat": "9", "Carbs": "11", "Protein": "19"}
# Cleaned string: {"Calories": "454", "Fat": "26", "Carbs": "11", "Protein": "45"}
# Cleaned string: {"Calories": "1029", "Fat": "68", "Carbs": "53", "Protein": "50"}
# Cleaned string: {"Calories": "263", "Fat": "11", "Carbs": "13", "Protein": "28"}
# Cleaned string: {"Calories": "459", "Fat": "28", "Carbs": "15", "Protein": "39"}
# Cleaned string: {"Calories": "542", "Fat": "21", "Carbs": "63", "Protein": "26"}
# Cleaned string: {"Calories": "299", "Fat": "18", "Carbs": "16", "Protein": "17"}
# Cleaned string: {"Calories": "500", "Fat": "18", "Carbs": "34", "Protein": "49"}
# Cleaned string: {"Calories": "305", "Fat": "18", "Carbs": "24", "Protein": "12"}
# Cleaned string: {"Calories": "291", "Fat": "17", "Carbs": "32", "Protein": "7"}
# Cleaned string: {"Calories": "349", "Fat": "14", "Carbs": "52", "Protein": "9"}
# Cleaned string: {"Calories": "266", "Fat": "10", "Carbs": "21", "Protein": "25"}
# Cleaned string: {"Calories": "832", "Fat": "66", "Carbs": "40", "Protein": "40"}
# Cleaned string: {"Calories": "690", "Fat": "41", "Carbs": "47", "Protein": "38"}
# Cleaned string: {"Calories": "524", "Fat": "21", "Carbs": "59", "Protein": "26"}
# Cleaned string: {"Calories": "583", "Fat": "21", "Carbs": "79", "Protein": "22"}
# Cleaned string: {"Calories": "472", "Fat": "41", "Carbs": "15", "Protein": "27"}
# Cleaned string: {"Calories": "375", "Fat": "21", "Carbs": "17", "Protein": "32"}
# Cleaned string: {"Calories": "623", "Fat": "35", "Carbs": "78", "Protein": "20"}
# Cleaned string: {"Calories": "794", "Fat": "22", "Carbs": "116", "Protein": "29"}
# Cleaned string: {"Calories": "162", "Fat": "3", "Carbs": "4", "Protein": "29"}
# Cleaned string: {"Calories": "485", "Fat": "24", "Carbs": "21", "Protein": "48"}
# Cleaned string: {"Calories": "466", "Fat": "21", "Carbs": "17", "Protein": "53"}
# Cleaned string: {"Calories": "216", "Fat": "12", "Carbs": "20", "Protein": "9"}
# Cleaned string: {"Calories": "589", "Fat": "19", "Carbs": "71", "Protein": "31"}
# Cleaned string: {"Calories": "841", "Fat": "34", "Carbs": "101", "Protein": "34"}
# Cleaned string: {"Calories": "638", "Fat": "65", "Carbs": "15", "Protein": "24"}
# Cleaned string: {"Calories": "269", "Fat": "12", "Carbs": "6", "Protein": "31"}
# Cleaned string: {"Calories": "271", "Fat": "16", "Carbs": "11", "Protein": "25"}
# Cleaned string: {"Calories": "397", "Fat": "23", "Carbs": "40", "Protein": "13"}
# Cleaned string: {"Calories": "383", "Fat": "22", "Carbs": "20", "Protein": "25"}
# Cleaned string: {"Calories": "418", "Fat": "34", "Carbs": "11", "Protein": "20"}
# Cleaned string: {"Calories": "341", "Fat": "9", "Carbs": "61", "Protein": "5"}
# Cleaned string: {"Calories": "427", "Fat": "38", "Carbs": "15", "Protein": "27"}
# Cleaned string: {"Calories": "797", "Fat": "29", "Carbs": "98", "Protein": "40"}
# Cleaned string: {"Calories": "267", "Fat": "10", "Carbs": "30", "Protein": "13"}
# Cleaned string: {"Calories": "262", "Fat": "16", "Carbs": "8", "Protein": "21"}
# Cleaned string: {"Calories": "209", "Fat": "11", "Carbs": "10", "Protein": "19"}
# Cleaned string: {"Calories": "366", "Fat": "27", "Carbs": "16", "Protein": "17"}
# Cleaned string: {"Calories": "377", "Fat": "28", "Carbs": "11", "Protein": "24"}
# Cleaned string: {"Calories": "352", "Fat": "6", "Carbs": "57", "Protein": "17"}
# Cleaned string: {"Calories": "506", "Fat": "12", "Carbs": "60", "Protein": "37"}
# Cleaned string: {"Calories": "273", "Fat": "11", "Carbs": "17", "Protein": "29"}
# Cleaned string: {"Calories": "389", "Fat": "30", "Carbs": "16", "Protein": "24"}
# Cleaned string: {"Calories": "466", "Fat": "34", "Carbs": "12", "Protein": "32"}
# Cleaned string: {"Calories": "17", "Fat": "0", "Carbs": "4", "Protein": "1"}
# Cleaned string: {"Calories": "377", "Fat": "25", "Carbs": "20", "Protein": "21"}
# Cleaned string: {"Calories": "218", "Fat": "9", "Carbs": "26", "Protein": "7"}
# Cleaned string: {"Calories": "285", "Fat": "15", "Carbs": "14", "Protein": "25"}
# Cleaned string: {"Calories": "679", "Fat": "29", "Carbs": "76", "Protein": "31"}
# Cleaned string: {"Calories": "496", "Fat": "38", "Carbs": "9", "Protein": "36"}
# Cleaned string: {"Calories": "527", "Fat": "35", "Carbs": "26", "Protein": "36"}
# Cleaned string: {"Calories": "742", "Fat": "28", "Carbs": "83", "Protein": "41"}
# Cleaned string: {"Calories": "554", "Fat": "28", "Carbs": "62", "Protein": "18"}
# Cleaned string: {"Calories": "619", "Fat": "34", "Carbs": "64", "Protein": "20"}
# Cleaned string: {"Calories": "369", "Fat": "18", "Carbs": "24", "Protein": "29"}
# Cleaned string: {"Calories": "456", "Fat": "10", "Carbs": "76", "Protein": "16"}
# Cleaned string: {"Calories": "807", "Fat": "12", "Carbs": "138", "Protein": "38"}
# Cleaned string: {"Calories": "258", "Fat": "11", "Carbs": "27", "Protein": "12"}
# Cleaned string: {"Calories": "439", "Fat": "15", "Carbs": "49", "Protein": "28"}
# Cleaned string: {"Calories": "554", "Fat": "28", "Carbs": "43", "Protein": "35"}
# Cleaned string: {"Calories": "746", "Fat": "60", "Carbs": "30", "Protein": "32"}
# Cleaned string: {"Calories": "314", "Fat": "15", "Carbs": "25", "Protein": "22"}
# Cleaned string: {"Calories": "709", "Fat": "36", "Carbs": "53", "Protein": "42"}
# Cleaned string: {"Calories": "687", "Fat": "28", "Carbs": "82", "Protein": "28"}
# Cleaned string: {"Calories": "391", "Fat": "25", "Carbs": "9", "Protein": "35"}
# Cleaned string: {"Calories": "519", "Fat": "20", "Carbs": "39", "Protein": "44"}
# Cleaned string: {"Calories": "684", "Fat": "35", "Carbs": "51", "Protein": "39"}
# Cleaned string: {"Calories": "766", "Fat": "25", "Carbs": "87", "Protein": "45"}
# Cleaned string: {"Calories": "823", "Fat": "60", "Carbs": "16", "Protein": "54"}
# Cleaned string: {"Calories": "729", "Fat": "35", "Carbs": "63", "Protein": "44"}
# Cleaned string: {"Calories": "405", "Fat": "28", "Carbs": "19", "Protein": "19"}
# Cleaned string: {"Calories": "695", "Fat": "44", "Carbs": "34", "Protein": "43"}
# Cleaned string: {"Calories": "466", "Fat": "22", "Carbs": "32", "Protein": "35"}
# Cleaned string: {"Calories": "487", "Fat": "32", "Carbs": "14", "Protein": "37"}
# Cleaned string: {"Calories": "590", "Fat": "47", "Carbs": "2", "Protein": "42"}
# Cleaned string: {"Calories": "310", "Fat": "14", "Carbs": "30", "Protein": "17"}
# Cleaned string: {"Calories": "256", "Fat": "15", "Carbs": "20", "Protein": "12"}
# Cleaned string: {"Calories": "652", "Fat": "47", "Carbs": "25", "Protein": "30"}
# Cleaned string: {"Calories": "935", "Fat": "72", "Carbs": "39", "Protein": "31"}
# Cleaned string: {"Calories": "288", "Fat": "18", "Carbs": "9", "Protein": "22"}
# Cleaned string: {"Calories": "315", "Fat": "11", "Carbs": "25", "Protein": "28"}
# Cleaned string: {"Calories": "184", "Fat": "10", "Carbs": "2", "Protein": "21"}
# Cleaned string: {"Calories": "445", "Fat": "28", "Carbs": "9", "Protein": "39"}
# Cleaned string: {"Calories": "260", "Fat": "15", "Carbs": "19", "Protein": "12"}
# Cleaned string: {"Calories": "317", "Fat": "18", "Carbs": "10", "Protein": "27"}
# Cleaned string: {"Calories": "203", "Fat": "15", "Carbs": "10", "Protein": "10"}
# Cleaned string: {"Calories": "238", "Fat": "8", "Carbs": "12", "Protein": "29"}
# Cleaned string: {"Calories": "198", "Fat": "3", "Carbs": "33", "Protein": "11"}
# Cleaned string: {"Calories": "580", "Fat": "33", "Carbs": "35", "Protein": "35"}
# Cleaned string: {"Calories": "608", "Fat": "25", "Carbs": "60", "Protein": "34"}
# Cleaned string: {"Calories": "453", "Fat": "14", "Carbs": "45", "Protein": "25"}
# Cleaned string: {"Calories": "1262", "Fat": "76", "Carbs": "80", "Protein": "70"}
# Cleaned string: {"Calories": "961", "Fat": "63", "Carbs": "35", "Protein": "61"}
# Cleaned string: {"Calories": "741", "Fat": "44", "Carbs": "2", "Protein": "64"}
# Cleaned string: {"Calories": "721", "Fat": "36", "Carbs": "52", "Protein": "46"}
# Cleaned string: {"Calories": "737", "Fat": "45", "Carbs": "45", "Protein": "38"}
# Cleaned string: {"Calories": "234", "Fat": "12", "Carbs": "17", "Protein": "14"}
# Cleaned string: {"Calories": "871", "Fat": "36", "Carbs": "38", "Protein": "90"}
# Cleaned string: {"Calories": "1892", "Fat": "145", "Carbs": "108", "Protein": "40"}
# Cleaned string: {"Calories": "196", "Fat": "7", "Carbs": "27", "Protein": "7"}
# Cleaned string: {"Calories": "669", "Fat": "39", "Carbs": "27", "Protein": "50"}
# Cleaned string: {"Calories": "969", "Fat": "75", "Carbs": "36", "Protein": "39"}
# Cleaned string: {"Calories": "632", "Fat": "47", "Carbs": "22", "Protein": "29"}
# Cleaned string: {"Calories": "245", "Fat": "11", "Carbs": "29", "Protein": "9"}
# Cleaned string: {"Calories": "264", "Fat": "1", "Carbs": "52", "Protein": "12"}
# Cleaned string: {"Calories": "393", "Fat": "14", "Carbs": "34", "Protein": "33"}
# Cleaned string: {"Calories": "279", "Fat": "20", "Protein": "23"}
# Cleaned string: {"Calories": "233", "Fat": "13", "Carbs": "2", "Protein": "27"}
# Cleaned string: {"Calories": "215", "Fat": "14", "Carbs": "2", "Protein": "19"}
# Cleaned string: {"Calories": "155", "Fat": "6", "Carbs": "16", "Protein": "8"}
# Cleaned string: {"Calories": "481", "Fat": "24", "Carbs": "25", "Protein": "39"}
# Cleaned string: {"Calories": "486", "Fat": "5", "Carbs": "105", "Protein": "15"}
# Cleaned string: {"Calories": "396", "Fat": "30", "Carbs": "2", "Protein": "28"}
# Cleaned string: {"Calories": "255", "Fat": "14", "Carbs": "23", "Protein": "11"}
# Cleaned string: {"Calories": "232", "Fat": "13", "Carbs": "16", "Protein": "12"}
# Cleaned string: {"Calories": "151", "Fat": "11", "Carbs": "4", "Protein": "11"}
# Cleaned string: {"Calories": "348", "Fat": "21", "Carbs": "20", "Protein": "27"}
# Cleaned string: {"Calories": "275", "Fat": "16", "Carbs": "4", "Protein": "29"}
# Cleaned string: {"Calories": "264", "Fat": "14", "Carbs": "17", "Protein": "18"}
# Cleaned string: {"Calories": "268", "Fat": "15", "Carbs": "8", "Protein": "23"}
# Cleaned string: {"Calories": "248", "Fat": "11", "Carbs": "16", "Protein": "25"}
# Cleaned string: {"Calories": "520", "Fat": "32", "Carbs": "25", "Protein": "30"}
# Cleaned string: {"Calories": "268", "Fat": "5", "Carbs": "22", "Protein": "33"}
# Cleaned string: {"Calories": "425", "Fat": "26", "Carbs": "3", "Protein": "41"}
# Cleaned string: {"Calories": "593", "Fat": "38", "Carbs": "23", "Protein": "38"}
# Cleaned string: {"Calories": "763", "Fat": "50", "Carbs": "26", "Protein": "51"}
# Cleaned string: {"Calories": "168", "Fat": "4", "Carbs": "27", "Protein": "6"}
# Cleaned string: {"Calories": "427", "Fat": "34", "Carbs": "11", "Protein": "22"}
# Cleaned string: {"Calories": "353", "Fat": "16", "Carbs": "37", "Protein": "16"}
# Cleaned string: {"Calories": "807", "Fat": "35", "Carbs": "109", "Protein": "17"}
# Cleaned string: {"Calories": "525", "Fat": "40", "Carbs": "10", "Protein": "32"}
# Cleaned string: {"Calories": "567", "Fat": "46", "Carbs": "23", "Protein": "18"}
# Cleaned string: {"Calories": "385", "Fat": "22", "Carbs": "9", "Protein": "37"}
# Cleaned string: {"Calories": "210", "Fat": "13", "Carbs": "6", "Protein": "17"}
# Cleaned string: {"Calories": "441", "Fat": "32", "Carbs": "18", "Protein": "26"}
# Cleaned string: {"Calories": "280", "Fat": "10", "Carbs": "6", "Protein": "37"}
# Cleaned string: {"Calories": "361", "Fat": "29", "Carbs": "13", "Protein": "15"}
# Cleaned string: {"Calories": "168", "Fat": "6", "Carbs": "13", "Protein": "15"}
# Cleaned string: {"Calories": "250", "Fat": "7", "Carbs": "38", "Protein": "10"}
# Cleaned string: {"Calories": "343", "Fat": "20", "Carbs": "35", "Protein": "9"}
# Cleaned string: {"Calories": "439", "Fat": "27", "Carbs": "44", "Protein": "11"}
# Cleaned string: {"Calories": "169", "Fat": "8", "Carbs": "17", "Protein": "6"}
# Cleaned string: {"Calories": "945", "Fat": "61", "Carbs": "76", "Protein": "27"}
# Cleaned string: {"Calories": "379", "Fat": "27", "Carbs": "26", "Protein": "10"}
# Cleaned string: {"Calories": "554", "Fat": "26", "Carbs": "52", "Protein": "31"}
# Cleaned string: {"Calories": "496", "Fat": "36", "Carbs": "10", "Protein": "33"}
# Cleaned string: {"Calories": "349", "Fat": "15", "Carbs": "38", "Protein": "16"}
# Cleaned string: {"Calories": "441", "Fat": "12", "Carbs": "65", "Protein": "20"}
# Cleaned string: {"Calories": "311", "Fat": "6", "Carbs": "42", "Protein": "23"}
# Cleaned string: {"Calories": "333", "Fat": "15", "Carbs": "3", "Protein": "46"}
# Cleaned string: {"Calories": "94", "Fat": "8", "Carbs": "6", "Protein": "2"}
# Cleaned string: {"Calories": "424", "Fat": "10", "Carbs": "69", "Protein": "16"}
# Cleaned string: {"Calories": "453", "Fat": "28", "Carbs": "40", "Protein": "13"}
# Cleaned string: {"Calories": "176", "Fat": "4", "Carbs": "32", "Protein": "5"}
# Cleaned string: {"Calories": "521", "Fat": "35", "Carbs": "16", "Protein": "35"}
# Cleaned string: {"Calories": "224", "Fat": "13", "Carbs": "25", "Protein": "5"}
# Cleaned string: {"Calories": "185", "Fat": "12", "Carbs": "18", "Protein": "3"}
# Cleaned string: {"Calories": "517", "Fat": "32", "Carbs": "39", "Protein": "24"}
# Cleaned string: {"Calories": "470", "Fat": "19", "Carbs": "44", "Protein": "35"}
# Cleaned string: {"Calories": "1039", "Fat": "59", "Carbs": "84", "Protein": "47"}
# Cleaned string: {"Calories": "499", "Fat": "24", "Carbs": "53", "Protein": "21"}
# Cleaned string: {"Calories": "704", "Fat": "53", "Carbs": "39", "Protein": "26"}
# Cleaned string: {"Calories": "483", "Fat": "18", "Carbs": "69", "Protein": "16"}
# Cleaned string: {"Calories": "382", "Fat": "16", "Carbs": "34", "Protein": "26"}
# Cleaned string: {"Calories": "599", "Fat": "45", "Carbs": "7", "Protein": "41"}
# Cleaned string: {"Calories": "626", "Fat": "42", "Carbs": "33", "Protein": "28"}
# Cleaned string: {"Calories": "575", "Fat": "38", "Carbs": "32", "Protein": "30"}
# Cleaned string: {"Calories": "174", "Fat": "9", "Carbs": "20", "Protein": "7"}
# Cleaned string: {"Calories": "342", "Fat": "29", "Carbs": "14", "Protein": "8"}
# Cleaned string: {"Calories": "311", "Fat": "17", "Carbs": "37", "Protein": "8"}
# Cleaned string: {"Calories": "166", "Fat": "5", "Carbs": "30", "Protein": "4"}
# Cleaned string: {"Calories": "321", "Fat": "24", "Carbs": "6", "Protein": "20"}
# Cleaned string: {"Calories": "355", "Fat": "19", "Carbs": "31", "Protein": "17"}
# Cleaned string: {"Calories": "352", "Fat": "12", "Carbs": "52", "Protein": "11"}
# Cleaned string: {"Calories": "372", "Fat": "23", "Carbs": "36", "Protein": "8"}
# Cleaned string: {"Calories": "195", "Fat": "5", "Carbs": "35", "Protein": "5"}
# Cleaned string: {"Calories": "463", "Fat": "31", "Carbs": "22", "Protein": "26"}
# Cleaned string: {"Calories": "610", "Fat": "40", "Carbs": "23", "Protein": "43"}
# Cleaned string: {"Calories": "236", "Fat": "10", "Carbs": "29", "Protein": "9"}
# Cleaned string: {"Calories": "214", "Fat": "15", "Carbs": "16", "Protein": "6"}
# ...
# Cleaned string: {"Calories": "409", "Fat": "33", "Carbs": "14", "Protein": "15"}
# Cleaned string: {"Calories": "359", "Fat": "26", "Carbs": "17", "Protein": "14"}
# Cleaned string: {"Calories": "705", "Fat": "26", "Carbs": "91", "Protein": "29"}
# Cleaned string: {"Calories": "877", "Fat": "58", "Carbs": "43", "Protein": "44"}
# Cleaned string: {"Calories": "731", "Fat": "45", "Carbs": "45", "Protein": "38"}
# Cleaned string: {"Calories": "494", "Fat": "15", "Carbs": "72", "Protein": "19"}
# Cleaned string: {"Calories": "918", "Fat": "52", "Carbs": "75", "Protein": "36"}
# Cleaned string: {"Calories": "245", "Fat": "20", "Carbs": "10", "Protein": "9"}
# Cleaned string: {"Calories": "185", "Fat": "11", "Carbs": "15", "Protein": "10"}
# Cleaned string: {"Calories": "294", "Fat": "23", "Carbs": "7", "Protein": "16"}
# Cleaned string: {"Calories": "530", "Fat": "38", "Carbs": "36", "Protein": "16"}
# Cleaned string: {"Calories": "1105", "Fat": "47", "Carbs": "129", "Protein": "40"}
# Cleaned string: {"Calories": "468", "Fat": "38", "Carbs": "1", "Protein": "30"}
# Cleaned string: {"Calories": "143", "Fat": "11", "Carbs": "2", "Protein": "10"}
# Cleaned string: {"Calories": "296", "Fat": "27", "Carbs": "1", "Protein": "13"}
# Cleaned string: {"Calories": "236", "Fat": "19", "Carbs": "3", "Protein": "14"}
# Cleaned string: {"Calories": "917", "Fat": "64", "Carbs": "51", "Protein": "39"}
# Cleaned string: {"Calories": "816", "Fat": "55", "Carbs": "68", "Protein": "20"}
# Cleaned string: {"Calories": "250", "Fat": "14", "Carbs": "15", "Protein": "17"}
# Cleaned string: {"Calories": "407", "Fat": "31", "Carbs": "8", "Protein": "27"}
# Cleaned string: {"Calories": "451", "Fat": "26", "Carbs": "32", "Protein": "22"}
# Cleaned string: {"Calories": "373", "Fat": "23", "Carbs": "19", "Protein": "22"}
# Cleaned string: {"Calories": "636", "Fat": "39", "Carbs": "39", "Protein": "27"}
# Cleaned string: {"Calories": "388", "Fat": "30", "Carbs": "13", "Protein": "25"}
# Cleaned string: {"Calories": "484", "Fat": "27", "Carbs": "32", "Protein": "29"}
# Cleaned string: {"Calories": "143", "Fat": "10", "Carbs": "1", "Protein": "13"}
# Cleaned string: {"Calories": "746", "Fat": "51", "Carbs": "46", "Protein": "28"}
# Cleaned string: {"Calories": "340", "Fat": "23", "Carbs": "9", "Protein": "23"}
# Cleaned string: {"Calories": "1928", "Fat": "70", "Carbs": "248", "Protein": "70"}
# Cleaned string: {"Calories": "291", "Fat": "21", "Carbs": "2", "Protein": "22"}
# Cleaned string: {"Calories": "311", "Fat": "22", "Carbs": "17", "Protein": "11"}
# Cleaned string: {"Calories": "1767", "Fat": "59", "Carbs": "246", "Protein": "59"}
# Cleaned string: {"Calories": "473", "Fat": "30", "Carbs": "29", "Protein": "20"}
# Cleaned string: {"Calories": "124", "Fat": "8", "Carbs": "3", "Protein": "10"}
# Cleaned string: {"Calories": "651", "Fat": "44", "Carbs": "26", "Protein": "38"}
# Cleaned string: {"Calories": "528", "Fat": "35", "Carbs": "27", "Protein": "26"}
# Cleaned string: {"Calories": "223", "Fat": "9", "Carbs": "18", "Protein": "16"}
# Cleaned string: {"Calories": "1522", "Fat": "74", "Carbs": "164", "Protein": "55"}
# Cleaned string: {"Calories": "690", "Fat": "58", "Carbs": "27", "Protein": "17"}
# Cleaned string: {"Calories": "72", "Fat": "5", "Carbs": "0", "Protein": "6"}
# Cleaned string: {"Calories": "444", "Fat": "24", "Carbs": "39", "Protein": "18"}
# Cleaned string: {"Calories": "286", "Fat": "18", "Carbs": "19", "Protein": "13"}
# Cleaned string: {"Calories": "558", "Fat": "32", "Carbs": "32", "Protein": "36"}
# Cleaned string: {"Calories": "534", "Fat": "27", "Carbs": "57", "Protein": "17"}
# Cleaned string: {"Calories": "800", "Fat": "39", "Carbs": "82", "Protein": "33"}
# Cleaned string: {"Calories": "518", "Fat": "20", "Carbs": "60", "Protein": "23"}
# Cleaned string: {"Calories": "1018", "Fat": "58", "Carbs": "64", "Protein": "59"}
# Cleaned string: {"Calories": "665", "Fat": "35", "Carbs": "45", "Protein": "42"}
# Cleaned string: {"Calories": "365", "Fat": "13", "Carbs": "48", "Protein": "19"}
# Cleaned string: {"Calories": "622", "Fat": "30", "Carbs": "50", "Protein": "37"}
# Cleaned string: {"Calories": "1004", "Fat": "37", "Carbs": "132", "Protein": "37"}
# Cleaned string: {"Calories": "253", "Fat": "12", "Carbs": "25", "Protein": "10"}
# Cleaned string: {"Calories": "555", "Fat": "19", "Carbs": "61", "Protein": "33"}
# Cleaned string: {"Calories": "900", "Fat": "46", "Carbs": "68", "Protein": "51"}
# Cleaned string: {"Calories": "720", "Fat": "32", "Carbs": "65", "Protein": "42"}
# Cleaned string: {"Calories": "793", "Fat": "29", "Carbs": "108", "Protein": "26"}
# Cleaned string: {"Calories": "759", "Fat": "40", "Carbs": "53", "Protein": "47"}
# Cleaned string: {"Calories": "632", "Fat": "23", "Carbs": "72", "Protein": "30"}
# Cleaned string: {"Calories": "241", "Fat": "8", "Carbs": "26", "Protein": "17"}
# Cleaned string: {"Calories": "473", "Fat": "26", "Carbs": "28", "Protein": "31"}
# Cleaned string: {"Calories": "50", "Fat": "2", "Carbs": "7", "Protein": "2"}
# Cleaned string: {"Calories": "653", "Fat": "36", "Carbs": "47", "Protein": "36"}
# Cleaned string: {"Calories": "171", "Fat": "7", "Carbs": "23", "Protein": "6"}
# Cleaned string: {"Calories": "165", "Fat": "5", "Carbs": "12", "Protein": "18"}
# Cleaned string: {"Calories": "2456", "Fat": "83", "Carbs": "321", "Protein": "101"}
# Cleaned string: {"Calories": "854", "Fat": "24", "Carbs": "121", "Protein": "48"}
# Cleaned string: {"Calories": "636", "Fat": "21", "Carbs": "82", "Protein": "38"}
# Cleaned string: {"Calories": "374", "Fat": "17", "Carbs": "36", "Protein": "19"}
# Cleaned string: {"Calories": "595", "Fat": "21", "Carbs": "28", "Protein": "40"}
# Cleaned string: {"Calories": "452", "Fat": "26", "Carbs": "12", "Protein": "40"}
# Cleaned string: {"Calories": "792", "Fat": "29", "Carbs": "95", "Protein": "37"}
# Cleaned string: {"Calories": "395", "Fat": "11", "Carbs": "36", "Protein": "39"}
# Cleaned string: {"Calories": "632", "Fat": "44", "Carbs": "33", "Protein": "32"}
# Cleaned string: {"Calories": "279", "Fat": "11", "Carbs": "36", "Protein": "10"}
# Cleaned string: {"Calories": "753", "Fat": "37", "Carbs": "68", "Protein": "38"}
# Cleaned string: {"Calories": "352", "Fat": "18", "Carbs": "34", "Protein": "19"}
# Cleaned string: {"Calories": "583", "Fat": "29", "Carbs": "46", "Protein": "33"}
# Cleaned string: {"Calories": "363", "Fat": "15", "Carbs": "46", "Protein": "14"}
# Cleaned string: {"Calories": "400", "Fat": "11", "Carbs": "52", "Protein": "25"}
# Cleaned string: {"Calories": "329", "Fat": "12", "Carbs": "36", "Protein": "13"}
# Cleaned string: {"Calories": "483", "Fat": "30", "Carbs": "14", "Protein": "39"}
# Cleaned string: {"Calories": "498", "Fat": "16", "Carbs": "50", "Protein": "27"}
# Cleaned string: {"Calories": "390", "Fat": "25", "Carbs": "32", "Protein": "15"}
# Cleaned string: {"Calories": "507", "Fat": "25", "Carbs": "32", "Protein": "38"}
# Cleaned string: {"Calories": "102", "Fat": "6", "Carbs": "8", "Protein": "5"}
# Cleaned string: {"Calories": "464", "Fat": "30", "Carbs": "25", "Protein": "24"}
# Cleaned string: {"Calories": "264", "Fat": "19", "Carbs": "11", "Protein": "13"}
# Cleaned string: {"Calories": "591", "Fat": "37", "Carbs": "40", "Protein": "25"}
# Cleaned string: {"Calories": "99", "Fat": "8", "Carbs": "0", "Protein": "7"}
# Cleaned string: {"Calories": "145", "Fat": "9", "Carbs": "1", "Protein": "14"}
# Cleaned string: {"Calories": "314", "Fat": "23", "Carbs": "12", "Protein": "22"}
# Cleaned string: {"Calories": "463", "Fat": "32", "Carbs": "20", "Protein": "25"}
# Cleaned string: {"Calories": "527", "Fat": "39", "Carbs": "9", "Protein": "34"}
# Cleaned string: {"Calories": "282", "Fat": "13", "Carbs": "31", "Protein": "10"}
# Cleaned string: {"Calories": "203", "Fat": "16", "Carbs": "1", "Protein": "14"}
# Cleaned string: {"Calories": "134", "Fat": "10", "Carbs": "0", "Protein": "9"}
# Cleaned string: {"Calories": "320", "Fat": "14", "Carbs": "25", "Protein": "25"}
# Cleaned string: {"Calories": "546", "Fat": "30", "Carbs": "55", "Protein": "23"}
# Cleaned string: {"Calories": "187", "Fat": "10", "Carbs": "14", "Protein": "9"}
# Cleaned string: {"Calories": "356", "Fat": "26", "Carbs": "8", "Protein": "22"}
# Cleaned string: {"Calories": "415", "Fat": "27", "Carbs": "30", "Protein": "14"}
# Cleaned string: {"Calories": "384", "Fat": "25", "Carbs": "26", "Protein": "15"}
# Cleaned string: {"Calories": "531", "Fat": "39", "Carbs": "6", "Protein": "38"}
# Cleaned string: {"Calories": "151", "Fat": "10", "Carbs": "9", "Protein": "7"}
# Cleaned string: {"Calories": "245", "Fat": "19", "Carbs": "3", "Protein": "15"}
# Cleaned string: {"Calories": "879", "Fat": "71", "Carbs": "30", "Protein": "32"}
# Cleaned string: {"Calories": "291", "Fat": "19", "Carbs": "13", "Protein": "17"}
# Cleaned string: {"Calories": "363", "Fat": "24", "Carbs": "14", "Protein": "22"}
# Cleaned string: {"Calories": "155", "Fat": "10", "Carbs": "8", "Protein": "7"}
# Cleaned string: {"Calories": "461", "Fat": "34", "Carbs": "21", "Protein": "18"}
# Cleaned string: {"Calories": "447", "Fat": "42", "Carbs": "2", "Protein": "16"}
# Cleaned string: {"Calories": "281", "Fat": "14", "Carbs": "21", "Protein": "18"}
# Cleaned string: {"Calories": "296", "Fat": "4", "Carbs": "45", "Protein": "21"}
# Cleaned string: {"Calories": "421", "Fat": "33", "Carbs": "17", "Protein": "14"}
# Cleaned string: {"Calories": "135", "Fat": "9", "Carbs": "3", "Protein": "10"}
# Cleaned string: {"Calories": "506", "Fat": "42", "Carbs": "14", "Protein": "20"}
# Cleaned string: {"Calories": "238", "Fat": "10", "Carbs": "16", "Protein": "21"}
# Cleaned string: {"Calories": "314", "Fat": "21", "Carbs": "6", "Protein": "25"}
# Cleaned string: {"Calories": "380", "Fat": "20", "Carbs": "40", "Protein": "11"}
# Cleaned string: {"Calories": "126", "Fat": "11", "Protein": "7"}
# Cleaned string: {"Calories": "316", "Fat": "22", "Carbs": "21", "Protein": "18"}
# Cleaned string: {"Calories": "707", "Fat": "60", "Carbs": "6", "Protein": "36"}
# Cleaned string: {"Calories": "451", "Fat": "32", "Carbs": "16", "Protein": "25"}
# Cleaned string: {"Calories": "312", "Fat": "24", "Carbs": "15", "Protein": "18"}
# Cleaned string: {"Calories": "215", "Fat": "14", "Carbs": "2", "Protein": "19"}
# Cleaned string: {"Calories": "120", "Fat": "3", "Carbs": "13", "Protein": "10"}
# Cleaned string: {"Calories": "238", "Fat": "17", "Carbs": "3", "Protein": "19"}
# Cleaned string: {"Calories": "134", "Fat": "10", "Carbs": "0", "Protein": "9"}
# Cleaned string: {"Calories": "647", "Fat": "41", "Carbs": "35", "Protein": "34"}
# Cleaned string: {"Calories": "413", "Fat": "33", "Carbs": "14", "Protein": "16"}
# Cleaned string: {"Calories": "352", "Fat": "28", "Carbs": "13", "Protein": "12"}
# Cleaned string: {"Calories": "481", "Fat": "38", "Carbs": "21", "Protein": "27"}
# Cleaned string: {"Calories": "374", "Fat": "24", "Carbs": "16", "Protein": "22"}
# Cleaned string: {"Calories": "316", "Fat": "23", "Carbs": "4", "Protein": "22"}
# Cleaned string: {"Calories": "341", "Fat": "25", "Carbs": "9", "Protein": "20"}
# Cleaned string: {"Calories": "573", "Fat": "45", "Carbs": "23", "Protein": "31"}
# Cleaned string: {"Calories": "354", "Fat": "21", "Carbs": "15", "Protein": "20"}
# Cleaned string: {"Calories": "381", "Fat": "24", "Carbs": "28", "Protein": "14"}
# Cleaned string: {"Calories": "530", "Fat": "36", "Carbs": "14", "Protein": "37"}
# Cleaned string: {"Calories": "514", "Fat": "32", "Carbs": "38", "Protein": "20"}
# Cleaned string: {"Calories": "639", "Fat": "43", "Carbs": "37", "Protein": "25"}
# Cleaned string: {"Calories": "419", "Fat": "19", "Carbs": "13", "Protein": "46"}
# Cleaned string: {"Calories": "653", "Fat": "28", "Carbs": "14", "Protein": "77"}
# Cleaned string: {"Calories": "761", "Fat": "68", "Carbs": "19", "Protein": "19"}
# Cleaned string: {"Calories": "484", "Fat": "34", "Carbs": "8", "Protein": "38"}
# Cleaned string: {"Calories": "255", "Fat": "19", "Carbs": "5", "Protein": "6"}
# Cleaned string: {"Calories": "405", "Fat": "23", "Carbs": "15", "Protein": "33"}
# Cleaned string: {"Calories": "584", "Fat": "41", "Carbs": "8", "Protein": "42"}
# Cleaned string: {"Calories": "1206", "Fat": "86", "Carbs": "61", "Protein": "48"}
# Cleaned string: {"Calories": "145", "Fat": "4", "Carbs": "3", "Protein": "19"}
# Cleaned string: {"Calories": "169", "Fat": "5", "Carbs": "1", "Protein": "30"}
# Cleaned string: {"Calories": "109", "Fat": "3", "Carbs": "15", "Protein": "5"}
# Cleaned string: {"Calories": "196", "Fat": "15", "Carbs": "1", "Protein": "14"}
# Cleaned string: {"Calories": "524", "Fat": "24", "Carbs": "54", "Protein": "31"}
# Cleaned string: {"Calories": "484", "Fat": "21", "Carbs": "35", "Protein": "36"}
# Cleaned string: {"Calories": "224", "Fat": "12", "Carbs": "6", "Protein": "26"}
# Cleaned string: {"Calories": "1270", "Fat": "124", "Carbs": "4", "Protein": "39"}
# Cleaned string: {"Calories": "284", "Fat": "17", "Carbs": "7", "Protein": "28"}
# Cleaned string: {"Calories": "417", "Fat": "30", "Carbs": "31", "Protein": "5"}
# Cleaned string: {"Calories": "961", "Fat": "69", "Carbs": "38", "Protein": "46"}
# Cleaned string: {"Calories": "439", "Fat": "33", "Carbs": "23", "Protein": "14"}
# Cleaned string: {"Calories": "339", "Fat": "19", "Carbs": "2", "Protein": "37"}
# Cleaned string: {"Calories": "522", "Fat": "19", "Carbs": "53", "Protein": "36"}
# Cleaned string: {"Calories": "514", "Fat": "12", "Carbs": "45", "Protein": "40"}
# Cleaned string: {"Calories": "873", "Fat": "19", "Carbs": "115", "Protein": "63"}
# Cleaned string: {"Calories": "549", "Fat": "47", "Carbs": "5", "Protein": "28"}
# Cleaned string: {"Calories": "332", "Fat": "20", "Carbs": "8", "Protein": "20"}
# Cleaned string: {"Calories": "889", "Fat": "64", "Carbs": "33", "Protein": "45"}
# Cleaned string: {"Calories": "644", "Fat": "25", "Carbs": "62", "Protein": "43"}
# Cleaned string: {"Calories": "370", "Fat": "26", "Carbs": "2", "Protein": "28"}
# Cleaned string: {"Calories": "652", "Fat": "51", "Carbs": "5", "Protein": "44"}
# Cleaned string: {"Calories": "423", "Fat": "34", "Carbs": "14", "Protein": "17"}
# Cleaned string: {"Calories": "342", "Fat": "14", "Carbs": "44", "Protein": "10"}
# Cleaned string: {"Calories": "3274", "Fat": "215", "Carbs": "232", "Protein": "69"}
# Cleaned string: {"Calories": "249", "Fat": "10", "Carbs": "8", "Protein": "30"}
# Cleaned string: {"Calories": "632", "Fat": "41", "Carbs": "16", "Protein": "49"}
# Cleaned string: {"Calories": "337", "Fat": "11", "Carbs": "43", "Protein": "15"}
# Cleaned string: {"Calories": "500", "Fat": "28", "Carbs": "24", "Protein": "36"}
# Cleaned string: {"Calories": "161", "Fat": "9", "Carbs": "6", "Protein": "8"}
# Cleaned string: {"Calories": "417", "Fat": "37", "Carbs": "8", "Protein": "16"}
# Cleaned string: {"Calories": "531", "Fat": "28", "Carbs": "11", "Protein": "35"}
# Cleaned string: {"Calories": "391", "Fat": "28", "Carbs": "27", "Protein": "10"}
# Cleaned string: {"Calories": "571", "Fat": "33", "Carbs": "12", "Protein": "50"}
# Cleaned string: {"Calories": "906", "Fat": "44", "Carbs": "72", "Protein": "54"}
# Cleaned string: {"Calories": "693", "Fat": "62", "Carbs": "13", "Protein": "23"}
# Cleaned string: {"Calories": "903", "Fat": "70", "Carbs": "31", "Protein": "40"}
# Cleaned string: {"Calories": "293", "Fat": "17", "Carbs": "13", "Protein": "22"}
# Cleaned string: {"Calories": "407", "Fat": "11", "Carbs": "53", "Protein": "37"}
# Cleaned string: {"Calories": "388", "Fat": "3", "Carbs": "61", "Protein": "28"}
# Cleaned string: {"Calories": "569", "Fat": "47", "Carbs": "12", "Protein": "25"}
# Cleaned string: {"Calories": "826", "Fat": "57", "Carbs": "47", "Protein": "32"}
# Cleaned string: {"Calories": "718", "Fat": "51", "Carbs": "11", "Protein": "51"}
# Cleaned string: {"Calories": "417", "Fat": "28", "Carbs": "8", "Protein": "24"}
# Cleaned string: {"Calories": "345", "Fat": "18", "Carbs": "40", "Protein": "7"}
# Cleaned string: {"Calories": "582", "Fat": "40", "Carbs": "16", "Protein": "32"}
# Cleaned string: {"Calories": "1647", "Fat": "113", "Carbs": "105", "Protein": "64"}
# Cleaned string: {"Calories": "616", "Fat": "31", "Carbs": "69", "Protein": "16"}
# Cleaned string: {"Calories": "583", "Fat": "31", "Carbs": "22", "Protein": "32"}

# %%
# Extract the nutritional components into separate columns
df['calories'] = df['nutrition'].apply(lambda x: int(x.get('Calories', 0)) if x else 0)
df['fat'] = df['nutrition'].apply(lambda x: int(x.get('Fat', '0').strip()) if x else 0)
df['carbs'] = df['nutrition'].apply(lambda x: int(x.get('Carbs', '0').strip()) if x else 0)
df['protein'] = df['nutrition'].apply(lambda x: int(x.get('Protein', '0').strip()) if x else 0)

# %%
# Drop nutrition column, no longer need
df = df.drop(columns=['nutrition'])

# %%
# Confirm
df.head(3)
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
#
#    total_time  servings                                        ingredients  \
# 0         300      16.0  ['1/3 cup butter, melted', '1/4 cup white suga...
# 2          25       6.0  ['1 cup dark chocolate chips', '20 creme-fille...
# 3         135      12.0  ['cooking spray', '2 1/4 cups all-purpose flou...
#
#                                           directions  \
# 0  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
# 2  ['Melt chocolate chips in a microwave-safe bow...
# 3  ['Gather all ingredients.\n\n \n\n\n\n\n\n \n ...
#
#                                           recipe_url  calories  fat  carbs  \
# 0  https://www.allrecipes.com/french-silk-pie-bar...       405   31     28
# 2  https://www.allrecipes.com/no-bake-espresso-ma...      1058   65    113
# 3  https://www.allrecipes.com/blackout-cake-recip...       824   55     80
#
#    protein
# 0        5
# 2       10
# 3        9

# %% [markdown]
# ## Clean and Preprocess 'ingredients'

# %% [markdown]
# ### 1. Convert Column

# %%
df['ingredients'].head()
# Out:
# 0    ['1/3 cup butter, melted', '1/4 cup white suga...
# 2    ['1 cup dark chocolate chips', '20 creme-fille...
# 3    ['cooking spray', '2 1/4 cups all-purpose flou...
# 4    ['1 sheet of prepared puff pastry, thawed', '9...
# 5    ['5 Little Debbie® Christmas Tree Brownies', '...
# Name: ingredients, dtype: object

# %%
df['ingredients'].unique()
# ingredients column contains: quantities, units, and descriptors
# Out:
# array(["['1/3 cup butter, melted', '1/4 cup white sugar', '1 1/4 cups finely crushed chocolate or regular graham crackers (about 9 sheets)', '7 ounces bittersweet chocolate', '4 large eggs, at room temperature', '3/4 cup white sugar', '1/4 cup packed brown sugar', '3 tablespoons water, at room temperature', '1/4 teaspoon salt', '1 tablespoon vanilla extract', '1/2 cup unsalted butter, at room temperature, cut into 8 pieces', '1/2 cup heavy cream', '3 ounces cream cheese, softened', '3 tablespoons white sugar', '1 teaspoon vanilla extract', '1 pinch salt', '1 1/2 cups heavy cream', 'chocolate curls or chocolate sprinkles']",
#        "['1 cup dark chocolate chips', '20 creme-filled chocolate sandwich cookies (such as OREO®)', '4 tablespoons butter, melted', '1 tablespoon instant espresso powder', '1 tablespoon hot water', '1 1/2 tablespoons cocoa powder, plus more for sprinkling', '1 tablespoon coffee liqueur (such as Kahlua®)', '8 ounces cream cheese, softened', '1/2 cup white sugar', '1 (8 ounce) container frozen whipped topping, such as Cool Whip®, thawed', 'chocolate covered espresso beans, for garnish (optional)']",
#        "['cooking spray', '2 1/4 cups all-purpose flour', '1 3/4 cups white sugar', '1 cup unsweetened cocoa', '2 teaspoons baking powder', '1 teaspoon baking soda', '3/4 teaspoon kosher salt', '1 cup whole buttermilk, at room temperature', '3/4 cup canola oil', '3 large eggs, at room temperature', '1 tablespoon vanilla extract', '1/2 cup hot strong brewed coffee', '1 (3.9-ounce) package chocolate instant pudding and pie filling (such as Jell-O®)', '2 1/2 cups heavy cream', '2 cups semisweet chocolate chips', '3/4 cup unsalted butter, cut into pieces', '1/2 cup heavy whipping cream', '1 tablespoon vanilla extract', '1/2 teaspoon kosher salt']",
#        ...,
#        "['4 small avocados, peeled and mashed', '3  roma (plum) tomatoes, chopped', '1 large shallot, minced', '1  jalapeno pepper, minced', '½  lemon, juiced', '1 cup low-sodium chicken broth', '¼ cup corn oil', '1  red bell pepper, cut into thin strips', '1  yellow bell pepper, cut into thin strips', '1 (4 ounce) package button mushrooms, sliced thin', '1 teaspoon coriander seeds, crushed', '1 teaspoon celery seed', '¼ teaspoon freshly cracked black pepper', '2 tablespoons water', '3 tablespoons corn oil', '3 large shallots, sliced', '4 cloves garlic, smashed', '3 ½ cups water', '2 tablespoons white wine vinegar', '¼ cup cold unsalted butter, cut into 1/2-inch cubes', '½ teaspoon sea salt', '2 tablespoons olive oil', '4 (6 ounce) beef tenderloin fillets, room temperature', '1 (16 ounce) package corn chips']",
#        "['18 ounces refrigerated French bread dough', '1 tablespoon olive oil, or as needed', '1 medium potato, thinly sliced (Optional)', '3 slices smoked bacon', '¼ cup butter', '½ cup chopped onion', '¾ cup light cream', '1 pinch ground nutmeg', 'salt and pepper to taste']",
#        "['¼ cup all-purpose flour', '1 teaspoon salt', '½ teaspoon ground black pepper', '2 pounds cubed stew meat', '4 tablespoons butter', '1  onion, chopped', '2  carrots, chopped', '1 clove garlic, minced', '2 cups red wine', '1  bay leaf', '3 tablespoons chopped fresh parsley', '½ teaspoon dried thyme', '1 (6 ounce) can sliced mushrooms', '1 (16 ounce) can canned onions']"],
#       dtype=object)

# %%
type(df['ingredients'].iloc[0])
# ingredients are stored as a series of strings, want to convert to a list to be able to loop through and apply transformations
# Out:
# str

# %%
# Convert ingredients column for each cell to contain a list of ingredient strings
df['ingredients'] = df['ingredients'].apply(ast.literal_eval)

# %%
# Confirm
type(df['ingredients'].iloc[0])
# Out:
# list

# %% [markdown]
# ### 2. Normalize Text

# %%
df['ingredients'][0]
# I want to remove punctuation, parentheses any anything in them, all lowercase, and strip any extra whitespace
# Out:
# ['1/3 cup butter, melted',
#  '1/4 cup white sugar',
#  '1 1/4 cups finely crushed chocolate or regular graham crackers (about 9 sheets)',
#  '7 ounces bittersweet chocolate',
#  '4 large eggs, at room temperature',
#  '3/4 cup white sugar',
#  '1/4 cup packed brown sugar',
#  '3 tablespoons water, at room temperature',
#  '1/4 teaspoon salt',
#  '1 tablespoon vanilla extract',
#  '1/2 cup unsalted butter, at room temperature, cut into 8 pieces',
#  '1/2 cup heavy cream',
#  '3 ounces cream cheese, softened',
#  '3 tablespoons white sugar',
#  '1 teaspoon vanilla extract',
#  '1 pinch salt',
#  '1 1/2 cups heavy cream',
#  'chocolate curls or chocolate sprinkles']

# %%
# Write a function to lower(), strip(), remove punctuation, numerics, and anything in parentheses
def first_clean_text(ingredient_list):
    clean_ingredients = [] # Create an empty list where cleaned ingredients will be stored

    number_pattern = r'\d+' # regular expression to remove all numbers
    fraction_pattern = r'[\u00BC-\u00BE\u2150-\u215E]' # unicode fraction types
    
    for item in ingredient_list: # iterate through each ingredient
        item = item.lower().strip() # converts all text to lower case and removes extra spaces
        item = re.sub(r'\(.*?\)', '', item) # regular expression to remove any text within parenteses 
        item = re.sub(fraction_pattern, '', item) # removes unicode fractions
        item = item.translate(str.maketrans('', '', string.punctuation)) # removes any punctuation using a built in python table
        item = re.sub(number_pattern, '', item) # removes all numbers
        item = item.strip() # strip any extra spaces after the rest
        clean_ingredients.append(item) # takes the cleaned ingredient item and add it to the clean_ingredients list
        
    return clean_ingredients

# %%
# Apply the funciton to the ingredients column, save as a new column just in case
df['cleaned_ingredients'] = df['ingredients'].apply(first_clean_text)

# %%
# Confirm
df['cleaned_ingredients'][0]
# Out:
# ['cup butter melted',
#  'cup white sugar',
#  'cups finely crushed chocolate or regular graham crackers',
#  'ounces bittersweet chocolate',
#  'large eggs at room temperature',
#  'cup white sugar',
#  'cup packed brown sugar',
#  'tablespoons water at room temperature',
#  'teaspoon salt',
#  'tablespoon vanilla extract',
#  'cup unsalted butter at room temperature cut into  pieces',
#  'cup heavy cream',
#  'ounces cream cheese softened',
#  'tablespoons white sugar',
#  'teaspoon vanilla extract',
#  'pinch salt',
#  'cups heavy cream',
#  'chocolate curls or chocolate sprinkles']

# %%
# Write a function to remove all numerics and all units of measure
def clean_units(ingredient_list):
    no_units_ingredients = []  # Create an empty list where cleaned ingredients will be stored
    # define the untis of measurement
    quantity_and_units = r'\b(cup|cups|ounce|ounces|oz|tablespoon|tablespoons|tbsp|teaspoon|teaspoons|tsp|pinch|pinches|container|containers|quart|quarts|packet|packets|package|packages|sheetsheets|can|cans|sleeve|sleeves|whole|slice|slices|clove|cloves|pound|pounds|large|medium|small|tiny|jumbo|sheet|sheets|mini)\b'

    for item in ingredient_list:
        item = re.sub(quantity_and_units, '', item) # remove units
        item = item.strip() # remove any extra whitespace after removal
        no_units_ingredients.append(item)

    return no_units_ingredients

# %%
# Apply the funciton to the cleaned_ingredients column
df['cleaned_ingredients'] = df['cleaned_ingredients'].apply(clean_units)

# %%
# Confirm
df['cleaned_ingredients'][0]
# Out:
# ['butter melted',
#  'white sugar',
#  'finely crushed chocolate or regular graham crackers',
#  'bittersweet chocolate',
#  'eggs at room temperature',
#  'white sugar',
#  'packed brown sugar',
#  'water at room temperature',
#  'salt',
#  'vanilla extract',
#  'unsalted butter at room temperature cut into  pieces',
#  'heavy cream',
#  'cream cheese softened',
#  'white sugar',
#  'vanilla extract',
#  'salt',
#  'heavy cream',
#  'chocolate curls or chocolate sprinkles']

# %%
from collections import Counter

# %%
all_ingredients = [ingredient for sublist in df['cleaned_ingredients'] for ingredient in sublist]
ingredient_counts = Counter(all_ingredients)

# %%
ingredient_counts
# Out:
# Counter({'salt': 534,
#          'olive oil': 346,
#          'water': 328,
#          'garlic minced': 303,
#          'white sugar': 272,
#          'allpurpose flour': 231,
#          'soy sauce': 210,
#          'ground black pepper': 204,
#          'vegetable oil': 200,
#          'eggs': 193,
#          'kosher salt': 180,
#          'freshly ground black pepper': 176,
#          'milk': 175,
#          'butter': 170,
#          'vanilla extract': 159,
#          'garlic powder': 138,
#          'onion chopped': 135,
#          'cornstarch': 133,
#          'ground cumin': 130,
#          'salt and ground black pepper to taste': 119,
#          'cayenne pepper': 117,
#          'salt and freshly ground black pepper to taste': 111,
#          'dried oregano': 105,
#          'heavy cream': 103,
#          'minced garlic': 100,
#          'egg': 99,
#          'brown sugar': 97,
#          'lemon juice': 89,
#          'chicken broth': 89,
#          'sesame oil': 86,
#          'unsalted butter': 83,
#          'baking powder': 81,
#          'salt to taste': 78,
#          'salt and pepper to taste': 78,
#          'cooking spray': 75,
#          'honey': 74,
#          'chili powder': 72,
#          'shredded cheddar cheese': 71,
#          'ground beef': 71,
#          'paprika': 71,
#          'mayonnaise': 68,
#          'ground cinnamon': 67,
#          'worcestershire sauce': 64,
#          'chopped fresh cilantro': 62,
#          'grated parmesan cheese': 61,
#          'onion powder': 59,
#          'chopped onion': 57,
#          'sour cream': 57,
#          'tomato paste': 54,
#          'rice vinegar': 54,
#          'dijon mustard': 53,
#          'eggs beaten': 52,
#          'chopped fresh parsley': 51,
#          'ground turmeric': 50,
#          'smoked paprika': 47,
#          'red pepper flakes': 46,
#          'ground coriander': 45,
#          'baking soda': 44,
#          'ground nutmeg': 44,
#          'olive oil divided': 44,
#          'shredded mozzarella cheese': 44,
#          'garlic chopped': 43,
#          'fish sauce': 43,
#          'garlic crushed': 42,
#          'extravirgin olive oil': 42,
#          'ketchup': 41,
#          'crumbled feta cheese': 41,
#          'salt or to taste': 40,
#          'italian seasoning': 40,
#          'lime juice': 40,
#          'canola oil': 39,
#          'onion diced': 39,
#          'heavy whipping cream': 38,
#          'ground ginger': 38,
#          'sugar': 38,
#          'butter melted': 36,
#          'egg beaten': 36,
#          'dried thyme': 35,
#          'white vinegar': 35,
#          'lean ground beef': 35,
#          'green onions chopped': 35,
#          'lemon juiced': 34,
#          'cream cheese softened': 33,
#          'ground pork': 33,
#          'dried basil': 33,
#          'bay leaves': 33,
#          'lemon zest': 32,
#          'garam masala': 32,
#          'freshly grated parmesan cheese': 32,
#          'tomato sauce': 32,
#          'flour tortillas': 32,
#          'oyster sauce': 32,
#          'coconut milk': 32,
#          'kosher salt divided': 31,
#          'corn tortillas': 31,
#          'lime juiced': 30,
#          'dried parsley': 30,
#          'green bell pepper chopped': 29,
#          'garlic': 29,
#          'mirin': 29,
#          'crushed red pepper': 29,
#          'chicken stock': 28,
#          'black pepper': 28,
#          'skinless boneless chicken breast halves': 28,
#          'fresh lemon juice': 27,
#          'red wine vinegar': 27,
#          'dry white wine': 27,
#          'ground black pepper to taste': 27,
#          'butter divided': 27,
#          'plain yogurt': 26,
#          'bacon': 26,
#          'apple cider vinegar': 25,
#          'beef broth': 25,
#          'lowsodium soy sauce': 25,
#          'onion finely chopped': 25,
#          'cayenne pepper or to taste': 25,
#          'unsweetened cocoa powder': 24,
#          'freshly squeezed lemon juice': 24,
#          'bay leaf': 24,
#          'balsamic vinegar': 24,
#          'red bell pepper chopped': 24,
#          'orange juice': 24,
#          'distilled white vinegar': 24,
#          'confectioners sugar': 23,
#          'granulated garlic': 23,
#          'minced fresh ginger': 23,
#          'minced fresh ginger root': 23,
#          'vegetable oil divided': 22,
#          'ricotta cheese': 22,
#          'sesame seeds': 22,
#          'vegetable oil for frying': 22,
#          'curry powder': 22,
#          'packed brown sugar': 21,
#          'unsalted butter melted': 21,
#          'cold water': 21,
#          'granulated sugar': 21,
#          'butter softened': 21,
#          'light brown sugar': 21,
#          'sliced green onions': 21,
#          'sake': 21,
#          'egg yolks': 20,
#          'onion sliced': 20,
#          'white wine': 20,
#          'crushed red pepper flakes': 20,
#          'peanut oil': 20,
#          'ground turkey': 20,
#          'diced onion': 20,
#          'eggs at room temperature': 19,
#          'melted butter': 19,
#          'chopped cilantro': 19,
#          'rice wine vinegar': 19,
#          'garlic salt': 18,
#          'hoisin sauce': 18,
#          '': 18,
#          'peanut butter': 18,
#          'grated fresh ginger': 18,
#          'yellow onion chopped': 18,
#          'chopped celery': 18,
#          'powdered sugar': 17,
#          'sweetened condensed milk': 17,
#          'unsalted butter softened': 17,
#          'extra virgin olive oil': 17,
#          'shrimp peeled and deveined': 17,
#          'seasoned salt': 17,
#          'eggs lightly beaten': 17,
#          'shredded lettuce': 17,
#          'banana': 16,
#          'almond extract': 16,
#          'buttermilk': 16,
#          'sliced fresh mushrooms': 16,
#          'freshly ground black pepper divided': 16,
#          'shredded monterey jack cheese': 16,
#          'salsa': 16,
#          'finely chopped onion': 16,
#          'seasoned rice vinegar': 16,
#          'black beans rinsed and drained': 16,
#          'ground allspice': 15,
#          'water or as needed': 15,
#          'all purpose flour': 15,
#          'flour': 15,
#          'fresh lime juice': 15,
#          'minced onion': 15,
#          'freshly ground black pepper to taste': 15,
#          'light soy sauce': 15,
#          'bean sprouts': 15,
#          'skinless boneless chicken breasts': 15,
#          'oil for frying': 15,
#          'cumin seeds': 15,
#          'pepper': 15,
#          'ice cubes': 15,
#          'sea salt': 14,
#          'dried rosemary': 14,
#          'chopped red onion': 14,
#          'chopped fresh basil': 14,
#          'vegetable broth': 14,
#          'water divided': 14,
#          'grated fresh ginger root': 14,
#          'garlic  minced': 14,
#          'tomatoes chopped': 14,
#          'salt divided': 14,
#          'panko bread crumbs': 14,
#          'fresh spinach': 14,
#          'semisweet chocolate chips': 13,
#          'ground': 13,
#          'unsalted butter divided': 13,
#          'kosher salt or to taste': 13,
#          'red pepper flakes or to taste': 13,
#          'olive oil or as needed': 13,
#          'tomatoes diced': 13,
#          'broccoli florets': 13,
#          'onion thinly sliced': 13,
#          'green onions sliced': 13,
#          'diced tomatoes': 13,
#          'halfandhalf': 13,
#          'chopped green onion': 13,
#          'salt and freshly ground black pepper': 13,
#          'packed light brown sugar': 12,
#          'active dry yeast': 12,
#          'lowsodium chicken broth': 12,
#          'yellow onion diced': 12,
#          'sliced mushrooms': 12,
#          'chopped fresh oregano': 12,
#          'chopped green bell pepper': 12,
#          'maple syrup': 12,
#          'skinless boneless chicken thighs': 12,
#          'hot pepper sauce': 12,
#          'turkey neck and giblets removed': 12,
#          'ground black pepper or to taste': 12,
#          'lime cut into wedges': 12,
#          'hamburger buns': 12,
#          'black beans drained and rinsed': 12,
#          'taco seasoning mix': 12,
#          'shredded swiss cheese': 12,
#          'white sugar or to taste': 11,
#          'red wine': 11,
#          'pizza sauce': 11,
#          'nonstick cooking spray': 11,
#          'lemon zested': 11,
#          'toasted sesame oil': 11,
#          'toasted sesame seeds': 11,
#          'reducedsodium soy sauce': 11,
#          'dried rice noodles': 11,
#          'red bell pepper sliced': 11,
#          'spaghetti': 11,
#          'crushed tomatoes': 11,
#          'stalks celery chopped': 11,
#          'chopped fresh dill': 11,
#          'cumin': 11,
#          'carrots chopped': 11,
#          'shredded cooked chicken': 11,
#          'instant espresso powder': 10,
#          'boiling water': 10,
#          'chopped pecans': 10,
#          'canola oil divided': 10,
#          'bunch green onions chopped': 10,
#          'lemon zested and juiced': 10,
#          'provolone cheese': 10,
#          'warm water': 10,
#          'dried marjoram': 10,
#          'evaporated milk': 10,
#          'avocado  peeled pitted and sliced': 10,
#          'chopped garlic': 10,
#          'ginger paste': 10,
#          'chopped green onions': 10,
#          'tomato diced': 10,
#          'dark soy sauce': 10,
#          'white wine vinegar': 10,
#          'turkey': 10,
#          'ground chicken': 10,
#          'egg whites': 9,
#          'minced fresh rosemary': 9,
#          'garlic sliced': 9,
#          'sliced red onion': 9,
#          'garlic peeled': 9,
#          'panko breadcrumbs': 9,
#          'red bell pepper diced': 9,
#          'shredded parmesan cheese': 9,
#          'rolled oats': 9,
#          'green onions thinly sliced': 9,
#          'soy sauce or to taste': 9,
#          'uncooked  shrimp peeled and deveined': 9,
#          'snow peas': 9,
#          'green bell pepper sliced': 9,
#          'cooking oil': 9,
#          'chicken cut into pieces': 9,
#          'ground cardamom': 9,
#          'onions chopped': 9,
#          'dried sage': 9,
#          'cooked white rice': 9,
#          'poultry seasoning': 9,
#          'swiss cheese': 9,
#          'creamy peanut butter': 9,
#          'greek yogurt': 9,
#          'cherry tomatoes halved': 9,
#          'kosher salt plus more to taste': 9,
#          'lasagna noodles': 9,
#          'vanilla yogurt': 9,
#          'wonton wrappers': 9,
#          'hot water': 8,
#          'firmly packed light brown sugar': 8,
#          'whipping cream': 8,
#          'olive oil cooking spray': 8,
#          'hot sauce': 8,
#          'chicken bouillon granules': 8,
#          'lemon wedges for serving': 8,
#          'pineapple juice': 8,
#          'skewers': 8,
#          'prepared pizza dough': 8,
#          'greek seasoning': 8,
#          'shredded mozzarella cheese divided': 8,
#          'minced fresh parsley': 8,
#          'sesame oil divided': 8,
#          'white pepper': 8,
#          'red bell pepper thinly sliced': 8,
#          'freshly grated ginger': 8,
#          'tomato chopped': 8,
#          'garlic finely chopped': 8,
#          'onions finely chopped': 8,
#          'black peppercorns': 8,
#          'shredded sharp cheddar cheese': 8,
#          'vegetable oil for frying or as needed': 8,
#          'garlic powder or to taste': 8,
#          'onion quartered': 8,
#          'chopped fresh thyme': 8,
#          'oil for frying or as needed': 8,
#          'white bread': 8,
#          'chopped fresh mint': 8,
#          'egg lightly beaten': 8,
#          'dry bread crumbs': 8,
#          'bread crumbs': 8,
#          'ground lamb': 8,
#          'quinoa': 8,
#          'tomato sliced': 8,
#          'avocado  peeled pitted and diced': 8,
#          'salmon filets': 8,
#          'grated parmesan cheese divided': 8,
#          'penne pasta': 8,
#          'garlic smashed': 8,
#          'cream of tartar': 7,
#          'unsalted butter at room temperature': 7,
#          'milk or more as needed': 7,
#          'crumbled cotija cheese': 7,
#          'minced ginger': 7,
#          'frozen peas': 7,
#          'herbes de provence': 7,
#          'hamburger buns split': 7,
#          'lukewarm water': 7,
#          'crushed red pepper flakes or to taste': 7,
#          'pepperoni': 7,
#          'thinly sliced green onions': 7,
#          'grated lemon zest': 7,
#          'frozen blueberries': 7,
#          'raisins': 7,
#          'skinless boneless chicken thighs cut into bitesized pieces': 7,
#          'ground white pepper': 7,
#          'fresh green beans trimmed': 7,
#          'onion minced': 7,
#          'baby spinach': 7,
#          'frozen chopped spinach thawed and drained': 7,
#          'cajun seasoning': 7,
#          'shredded cheddar cheese divided': 7,
#          'water to cover': 7,
#          'halfandhalf cream': 7,
#          'stalk celery chopped': 7,
#          'red onion thinly sliced': 7,
#          'vegetable oil or as needed': 7,
#          'cayenne pepper to taste': 7,
#          'diced red onion': 7,
#          'chopped cooked chicken': 7,
#          'flank steak': 7,
#          'tahini': 7,
#          'kosher salt to taste': 7,
#          'cooked rice': 7,
#          'lemon': 7,
#          'pure maple syrup': 7,
#          'nori': 7,
#          'potato starch': 7,
#          'dried dill': 7,
#          'frozen strawberries': 7,
#          'dark chocolate chips': 6,
#          'cream cheese at room temperature': 6,
#          'cocoa powder': 6,
#          'oil': 6,
#          'chopped walnuts': 6,
#          'light corn syrup': 6,
#          'white sugar divided': 6,
#          'shortening': 6,
#          'baking spray with flour': 6,
#          'fine salt': 6,
#          'dry mustard': 6,
#          'pork tenderloins': 6,
#          'salt plus more to taste': 6,
#          'chinese fivespice powder': 6,
#          'pork tenderloin': 6,
#          'olive oil or more as needed': 6,
#          'packed dark brown sugar': 6,
#          'vegetable oil or more as needed': 6,
#          'extravirgin olive oil divided': 6,
#          'allpurpose flour or as needed': 6,
#          'halved cherry tomatoes': 6,
#          'jar marinara sauce': 6,
#          'chopped sundried tomatoes': 6,
#          'chopped tomatoes': 6,
#          'shredded carrots': 6,
#          'allpurpose flour or more as needed': 6,
#          'unsweetened coconut milk': 6,
#          'freshly grated lemon zest': 6,
#          'fresh blueberries': 6,
#          'half and half': 6,
#          'grapeseed oil': 6,
#          'chopped red bell pepper': 6,
#          'ramen noodles': 6,
#          'cooked jasmine rice': 6,
#          'freshly ground white pepper': 6,
#          'boneless skinless chicken thighs cut into inch pieces': 6,
#          'chopped fresh cilantro or to taste': 6,
#          'garlic paste': 6,
#          'lemon cut into wedges': 6,
#          'ghee': 6,
#          'water or more as needed': 6,
#          'onion coarsely chopped': 6,
#          'garlic minced or more to taste': 6,
#          'boneless skinless chicken thighs': 6,
#          'chopped fresh spinach': 6,
#          'chicken cut into  pieces': 6,
#          'uncooked white rice': 6,
#          'chicken': 6,
#          'chopped fresh chives': 6,
#          'uncooked jasmine rice': 6,
#          'chopped fresh ginger': 6,
#          'crushed garlic': 6,
#          'dry onion soup mix': 6,
#          'cheddar cheese': 6,
#          'shredded mexican cheese blend': 6,
#          'chopped italian parsley': 6,
#          'taco seasoning': 6,
#          'minced shallot': 6,
#          'cottage cheese': 6,
#          'white onion quartered': 6,
#          'plain greek yogurt': 6,
#          'avocado sliced': 6,
#          'wasabi paste': 6,
#          'chipotle peppers in adobo sauce': 6,
#          'limes juiced': 6,
#          'shredded rotisserie chicken': 6,
#          'condensed cream of chicken soup': 6,
#          'breakfast sausage': 6,
#          'vanilla extract divided': 5,
#          'graham cracker crumbs': 5,
#          'chocolate chips': 5,
#          'of salt': 5,
#          'salted butter softened': 5,
#          'thickcut bacon': 5,
#          'freshly ground black pepper or to taste': 5,
#          'barbecue sauce': 5,
#          'lime': 5,
#          'sliced fresh strawberries': 5,
#          'honey or to taste': 5,
#          'chopped broccoli': 5,
#          'diced celery': 5,
#          'freshly cracked black pepper': 5,
#          'garlic thinly sliced': 5,
#          'butter or as needed': 5,
#          'fresh baby spinach': 5,
#          'sliced celery': 5,
#          'cornmeal': 5,
#          'pesto': 5,
#          'dried dill weed': 5,
#          'thinly sliced red onion': 5,
#          'frozen hash brown potatoes thawed': 5,
#          'red onion chopped': 5,
#          'tap water': 5,
#          'sliced almonds': 5,
#          'allpurpose flour divided': 5,
#          'selfrising flour': 5,
#          'lesssodium soy sauce': 5,
#          'bunch fresh cilantro chopped': 5,
#          'sriracha sauce': 5,
#          'soy sauce divided': 5,
#          'cooking oil divided': 5,
#          'fresh broccoli florets': 5,
#          'green onion chopped': 5,
#          'sliced water chestnuts drained': 5,
#          'sliced red bell pepper': 5,
#          'vinegar': 5,
#          'chopped peanuts': 5,
#          'sherry': 5,
#          'monosodium glutamate': 5,
#          'stalks celery sliced': 5,
#          'shrimp  peeled and deveined': 5,
#          'fresh bean sprouts': 5,
#          'garlic roughly chopped': 5,
#          'diced tomatoes drained': 5,
#          'salt and black pepper to taste': 5,
#          'minced garlic divided': 5,
#          'cumin seed': 5,
#          'grated carrots': 5,
#          'milk or as needed': 5,
#          'tomatoes sliced': 5,
#          'cube chicken bouillon': 5,
#          'green bell pepper diced': 5,
#          'peanut oil for frying': 5,
#          'kosher salt and ground black pepper to taste': 5,
#          'celery seed': 5,
#          'cider vinegar': 5,
#          'chopped fresh parsley for garnish': 5,
#          'skinless boneless chicken breast halves  cut into  inch cubes': 5,
#          'coconut oil': 5,
#          'lime zested': 5,
#          'limes cut into wedges': 5,
#          'fresh basil leaves': 5,
#          'frozen mixed vegetables': 5,
#          'diced red bell pepper': 5,
#          'finely chopped green onion': 5,
#          'rice wine': 5,
#          'freshly squeezed lime juice': 5,
#          'red onion sliced': 5,
#          'sharp cheddar cheese': 5,
#          'diced green bell pepper': 5,
#          'ground mustard': 5,
#          'american cheese': 5,
#          'ground paprika': 5,
#          'shallot chopped': 5,
#          'slivered almonds': 5,
#          'black beans drained': 5,
#          'finely chopped red onion': 5,
#          'kernel corn drained': 5,
#          'carrot chopped': 5,
#          'finely chopped fresh flatleaf parsley': 5,
#          'garlic pressed': 5,
#          'garlic finely minced': 5,
#          'lemon wedges': 5,
#          'yellow onion sliced': 5,
#          'shallot minced': 5,
#          'bulk pork sausage': 5,
#          'water plus more as needed': 5,
#          'monterey jack cheese shredded': 5,
#          'green onion thinly sliced': 5,
#          'cheddar cheese shredded': 5,
#          'chopped yellow onion': 5,
#          'head cabbage shredded': 5,
#          'aluminum foil': 5,
#          'avocado diced': 5,
#          'taco shells': 5,
#          'reducedsodium chicken broth': 5,
#          'egg at room temperature': 4,
#          'firmly packed brown sugar': 4,
#          'sour cream at room temperature': 4,
#          'heavy cream divided': 4,
#          'dark brown sugar': 4,
#          'egg yolk': 4,
#          'pure vanilla extract': 4,
#          'grain mustard': 4,
#          'apple cider': 4,
#          'chopped fresh flatleaf parsley': 4,
#          'dried mexican oregano': 4,
#          'diced onions': 4,
#          'black pepper divided': 4,
#          'gochujang': 4,
#          'ground cayenne pepper': 4,
#          'onions cut into wedges': 4,
#          'fresh mushrooms sliced': 4,
#          'condensed cream of mushroom soup': 4,
#          'bread flour': 4,
#          'bacon cut into inch pieces': 4,
#          'finely chopped fresh parsley': 4,
#          'skim milk': 4,
#          'shredded quesadilla cheese': 4,
#          'dried oregano or to taste': 4,
#          'allpurpose flour plus more for dusting': 4,
#          'refrigerated biscuits': 4,
#          'button mushrooms sliced': 4,
#          'frozen puff pastry thawed': 4,
#          'sliced black olives drained': 4,
#          'milk ricotta cheese': 4,
#          'garlic grated': 4,
#          'pita breads': 4,
#          'shredded mild cheddar cheese': 4,
#          'fine\xa0sea salt': 4,
#          'vanilla ice cream': 4,
#          'unbaked pie crust': 4,
#          'blueberries': 4,
#          'orange liqueur': 4,
#          'flaky sea salt': 4,
#          'fresh orange juice': 4,
#          'grated orange zest': 4,
#          'lemon curd': 4,
#          'orange marmalade': 4,
#          'cold unsalted butter': 4,
#          'green peas': 4,
#          'shredded cabbage': 4,
#          'sesame seeds for garnish': 4,
#          'red bell pepper cut into thin strips': 4,
#          'flour tortillas warmed': 4,
#          'sliced carrots': 4,
#          'low sodium soy sauce': 4,
#          'onion cut into wedges': 4,
#          'dry sherry': 4,
#          'palm sugar': 4,
#          'skinless boneless chicken breast halves  cut into strips': 4,
#          'sweet onion chopped': 4,
#          'finely chopped cilantro': 4,
#          'frozen green peas': 4,
#          'skinless boneless chicken breast halves  cut into bitesize pieces': 4,
#          'curry paste': 4,
#          'shallot finely chopped': 4,
#          'ginger garlic paste': 4,
#          'tomato puree': 4,
#          'basmati rice': 4,
#          'chopped fresh cilantro leaves': 4,
#          'ground red pepper': 4,
#          'salt or more to taste': 4,
#          'piece cinnamon stick': 4,
#          'cayenne pepper or more to taste': 4,
#          'skinless boneless chicken breasts cut into inch pieces': 4,
#          'roma  tomatoes chopped': 4,
#          'long grain white rice': 4,
#          'ground thyme': 4,
#          'white onion': 4,
#          'yellow bell pepper chopped': 4,
#          'lard': 4,
#          'onions sliced': 4,
#          'drained capers': 4,
#          'finely diced onion': 4,
#          'dried thyme leaves': 4,
#          'prepared horseradish': 4,
#          'egg noodles': 4,
#          'tamarind paste': 4,
#          'fish sauce or more to taste': 4,
#          'lime zested and juiced': 4,
#          'cucumber sliced': 4,
#          'thai red curry paste': 4,
#          'bunch fresh cilantro': 4,
#          'red bell pepper cut into strips': 4,
#          'shallots sliced': 4,
#          'cilantro leaves': 4,
#          'chopped fresh cilantro divided': 4,
#          'drops sesame oil or to taste': 4,
#          'shredded carrot': 4,
#          'mustard': 4,
#          'beef stock': 4,
#          'hot cooked white rice': 4,
#          'chopped sweet onion': 4,
#          'dashes hot sauce': 4,
#          'red onion diced': 4,
#          'minced fresh chives': 4,
#          'garlic minced divided': 4,
#          'italian seasoned bread crumbs': 4,
#          'diced cooked chicken': 4,
#          'frozen corn': 4,
#          'minced fresh oregano': 4,
#          'dried cranberries': 4,
#          'jar salsa': 4,
#          'feta cheese crumbled': 4,
#          'chopped parsley': 4,
#          'baby spinach leaves': 4,
#          'sliced black olives': 4,
#          'onion cut into chunks': 4,
#          'chopped fresh rosemary': 4,
#          'sprigs fresh rosemary': 4,
#          'pasta shells': 4,
#          'dried italian seasoning': 4,
#          'chopped fresh basil plus more for garnish': 4,
#          'jar spaghetti sauce': 4,
#          'flour tortilla': 4,
#          'orange juiced': 4,
#          'softened butter': 4,
#          'salmon fillets': 4,
#          'minced fresh garlic': 4,
#          'cod filets': 4,
#          'everything bagel seasoning': 4,
#          'capers': 4,
#          'white miso paste': 4,
#          'sherry vinegar': 4,
#          'chopped white onion': 4,
#          'bread': 4,
#          'carrots diced': 4,
#          'miso paste': 4,
#          'white onion finely chopped': 4,
#          'chopped fresh tomato': 4,
#          'diced tomatoes undrained': 4,
#          'skinless boneless chicken thighs cut into inch pieces': 4,
#          'fresh thyme leaves': 4,
#          'salted butter': 4,
#          'strawberries': 4,
#          'cold milk': 4,
#          'stalks celery cut into inch pieces': 4,
#          'pork sausage': 4,
#          'stalks celery diced': 4,
#          'sriracha hot sauce': 4,
#          'thinly sliced green onion': 4,
#          'finely chopped green onions': 4,
#          'masa harina': 4,
#          'chinese rice wine': 4,
#          'enchilada sauce': 4,
#          'sesame seeds or to taste': 4,
#          'coffee liqueur': 3,
#          'buttermilk at room temperature': 3,
#          'chocolate syrup': 3,
#          'quick oats': 3,
#          'almond butter': 3,
#          'full fat cream cheese at room temperature': 3,
#          'unsalted butter cubed': 3,
#          'cake flour': 3,
#          'milk at room temperature': 3,
#          'egg whites at room temperature': 3,
#          'irish cream liqueur': 3,
#          'salted butter melted': 3,
#          'cold butter': 3,
#          'milk chocolate chips': 3,
#          'dark rum': 3,
#          'milk divided': 3,
#          'coarse sea salt': 3,
#          'wooden skewers': 3,
#          'bonein pork chops about inch thick': 3,
#          'flour plus more for dusting': 3,
#          'fresh cilantro for garnish': 3,
#          'garlic  thinly sliced': 3,
#          'frozen puff pastry': 3,
#          'cauliflower florets': 3,
#          'frozen peas thawed': 3,
#          'hot cooked rice': 3,
#          'serrano peppers': 3,
#          'bonein pork chops': 3,
#          'sliced zucchini': 3,
#          'uncooked rice': 3,
#          'prepared yellow mustard': 3,
#          'vegetable oil divided or as needed': 3,
#          'vertically sliced onion': 3,
#          'frozen orange juice concentrate': 3,
#          'fresh parsley for garnish': 3,
#          'nutmeg': 3,
#          'chipotle powder': 3,
#          'minced red onion': 3,
#          'barbeque sauce': 3,
#          'dried italian herb seasoning': 3,
#          'lemon juice or to taste': 3,
#          'bottle barbeque sauce': 3,
#          'butter cubed': 3,
#          'boneless pork chops': 3,
#          'fajita seasoning': 3,
#          'beer': 3,
#          'prepared pizza sauce': 3,
#          'freshly grated parmigiano reggiano cheese': 3,
#          'marinara sauce': 3,
#          'pizza dough': 3,
#          'grated garlic': 3,
#          'crumbled blue cheese': 3,
#          'envelope active dry yeast': 3,
#          'shredded lowmoisture partskim mozzarella cheese': 3,
#          'shredded mozzarella cheese or more to taste': 3,
#          'corn kernels': 3,
#          'pizza sauce or as needed': 3,
#          'freshly grated parmesan cheese divided': 3,
#          'red onion': 3,
#          'hoagie rolls': 3,
#          'grape tomatoes halved': 3,
#          'finely grated parmigianoreggiano cheese': 3,
#          'refrigerated crescent rolls': 3,
#          'carrot grated': 3,
#          'english muffins split': 3,
#          'refried beans': 3,
#          'blue cheese crumbled': 3,
#          'sliced provolone cheese': 3,
#          'tapioca starch': 3,
#          'orange zest': 3,
#          'caramel sauce': 3,
#          'butter cut into cubes': 3,
#          'finely ground graham cracker crumbs': 3,
#          'strawberry preserves': 3,
#          'chopped strawberries': 3,
#          'fresh raspberries': 3,
#          'brandy': 3,
#          'bourbon whiskey': 3,
#          'butter or margarine': 3,
#          'strawberries hulled': 3,
#          'water chestnuts drained': 3,
#          'raw shrimp peeled and deveined': 3,
#          'sesame oil or to taste': 3,
#          'chopped zucchini': 3,
#          'matchstickcut carrots': 3,
#          'chopped broccoli florets': 3,
#          'sliced green onions for garnish': 3,
#          'cornstarch divided': 3,
#          'ground white pepper or to taste': 3,
#          'peanut oil divided': 3,
#          'yellow bell pepper cut into thin strips': 3,
#          'mexican oregano': 3,
#          'chopped fresh mango': 3,
#          'carrots thinly sliced': 3,
#          'sesame seeds toasted': 3,
#          'red chili flakes': 3,
#          'onion cut into  chunks': 3,
#          'carrot thinly sliced': 3,
#          'skinless boneless chicken breast meat  cubed': 3,
#          'sliced green bell pepper': 3,
#          'thinly sliced onion': 3,
#          'canola oil or as needed': 3,
#          'salmon filet': 3,
#          'teriyaki sauce': 3,
#          'fish sauce or to taste': 3,
#          'cooking sherry': 3,
#          'freshly chopped cilantro': 3,
#          'lowfat plain yogurt': 3,
#          'white onion chopped': 3,
#          'cinnamon sticks': 3,
#          'water as needed': 3,
#          'chickpeas drained': 3,
#          'carrots cubed': 3,
#          'garlic finely grated': 3,
#          'chicken broth or as needed': 3,
#          'onions minced': 3,
#          'roma tomatoes diced': 3,
#          'chopped tomato': 3,
#          'curry powder or to taste': 3,
#          'potatoes peeled and cubed': 3,
#          'peas drained': 3,
#          'dried red chile peppers': 3,
#          'chopped cabbage': 3,
#          'fresh ginger root': 3,
#          'chopped parsley for garnish': 3,
#          'fresh shrimp peeled and deveined': 3,
#          'pork neck bones': 3,
#          'lemons halved': 3,
#          'seasoning salt': 3,
#          'peeled tomatoes chopped': 3,
#          'ground black pepper divided': 3,
#          'chopped carrot': 3,
#          'pork spareribs': 3,
#          'portobello mushroom caps': 3,
#          'chicken tenders': 3,
#          'yellow cornmeal': 3,
#          'chicken broth or more as needed': 3,
#          'chopped green onion or to taste': 3,
#          'ham': 3,
#          'wedges lime': 3,
#          'brown sugar or to taste': 3,
#          'lemons juiced': 3,
#          'lowsodium beef broth': 3,
#          'green curry paste': 3,
#          'red curry paste': 3,
#          'pineapple chunks drained': 3,
#          'garlic  crushed': 3,
#          'asian fish sauce': 3,
#          'chopped shallots': 3,
#          'corn oil': 3,
#          'light coconut milk': 3,
#          'red curry paste or more to taste': 3,
#          'chopped fresh pineapple': 3,
#          'chopped roasted peanuts': 3,
#          'coarsely chopped garlic': 3,
#          'diced fresh tomato': 3,
#          'chilegarlic sauce': 3,
#          'canned coconut milk': 3,
#          'chili oil': 3,
#          'fine dry bread crumbs': 3,
#          'sweet pickle relish': 3,
#          'crumbled queso fresco': 3,
#          'dried tarragon': 3,
#          'crumbled feta': 3,
#          'guacamole': 3,
#          'deli ham': 3,
#          'poppy seeds': 3,
#          'havarti cheese': 3,
#          'ranch dressing': 3,
#          'boneless skinless chicken breast halves': 3,
#          'yellow mustard': 3,
#          'sprigs thyme': 3,
#          'ground chuck': 3,
#          'seafood seasoning': 3,
#          'feta cheese': 3,
#          'shallots minced': 3,
#          'fresh bread crumbs': 3,
#          'ranch dressing mix': 3,
#          'chopped scallions': 3,
#          'tuna drained': 3,
#          'dash hot pepper sauce': 3,
#          'pine nuts': 3,
#          'lowfat cottage cheese': 3,
#          'kidney beans drained': 3,
#          'corn chips': 3,
#          'red quinoa': 3,
#          'mixed salad greens': 3,
#          'finely chopped fresh rosemary': 3,
#          'thinly sliced scallions': 3,
#          'sliced kalamata olives': 3,
#          'finely chopped red bell pepper': 3,
#          'finely chopped fresh cilantro': 3,
#          'golden raisins': 3,
#          'lettuce leaves': 3,
#          'crumbled feta cheese or to taste': 3,
#          'chickpeas drained and rinsed': 3,
#          'chopped romaine lettuce': 3,
#          'bunch cilantro chopped': 3,
#          'carrots shredded': 3,
#          'ground dried rosemary': 3,
#          'pita bread rounds': 3,
#          'tzatziki sauce': 3,
#          'zucchini thinly sliced': 3,
#          'chicken leg quarters': 3,
#          'green bell peppers': 3,
#          'eggs well beaten': 3,
#          'cherry tomatoes': 3,
#          'garlic minced or to taste': 3,
#          'boneless skinless chicken breasts': 3,
#          'thinly sliced shallot': 3,
#          'reduced sodium chicken broth': 3,
#          'chicken breast cutlets': 3,
#          'marsala wine': 3,
#          'skinon bonein chicken thighs': 3,
#          'italian herb seasoning blend': 3,
#          'sliced onion': 3,
#          'peeled tomatoes': 3,
#          'chia seeds': 3,
#          'vanilla bean paste': 3,
#          'roma tomatoes quartered': 3,
#          'dashes worcestershire sauce': 3,
#          'avocado chopped': 3,
#          'sour cream or as needed': 3,
#          'cantanzaro herbs': 3,
#          'lime wedges': 3,
#          'poblano pepper chopped': 3,
#          'chopped fresh cilantro for garnish': 3,
#          'peeled deveined raw shrimp': 3,
#          'finely grated parmesan cheese': 3,
#          'prepared pesto': 3,
#          'cayenne': 3,
#          'cooked brown rice': 3,
#          'sourdough bread': 3,
#          'lime zest': 3,
#          'frozen chopped spinach  thawed drained and squeezed dry': 3,
#          'eggs separated': 3,
#          'mushrooms sliced': 3,
#          'shredded pepper jack cheese': 3,
#          'uncooked shortgrain white rice': 3,
#          'uncooked glutinous white rice': 3,
#          'frenchfried onions': 3,
#          'shredded cheese': 3,
#          'vegetable oil or to taste': 3,
#          'finely chopped fresh chives': 3,
#          'japanese sushistyle rice': 3,
#          'black sesame seeds': 3,
#          'tamari': 3,
#          'chopped english cucumber': 3,
#          'fresh spinach chopped': 3,
#          'red potatoes cubed': 3,
#          'bonein skinon chicken thighs': 3,
#          'minced shallots': 3,
#          'olive oil or to taste': 3,
#          'yellow bell pepper sliced': 3,
#          'shredded iceberg lettuce': 3,
#          'crunchy taco shells': 3,
#          'skinless boneless chicken breast': 3,
#          'bacon chopped': 3,
#          'cream cheese cubed and softened': 3,
#          'garlic  finely chopped': 3,
#          'diced green chiles': 3,
#          'thyme sprigs': 3,
#          'pinto beans drained and rinsed': 3,
#          'ice': 3,
#          'natural peanut butter': 3,
#          'cinnamon': 3,
#          'freshly grated nutmeg': 3,
#          'chopped fresh sage': 3,
#          'thinly sliced carrots': 3,
#          'fullfat cottage cheese': 3,
#          'corn drained': 3,
#          'boiling water as needed': 3,
#          'chuck roast': 3,
#          'cubed beef stew meat': 3,
#          'mustard powder': 3,
#          'chopped fresh ginger root': 3,
#          'potato gnocchi': 3,
#          'very cold heavy cream': 3,
#          'curd cottage cheese': 3,
#          'light cream': 3,
#          'frozen shredded hash brown potatoes thawed': 3,
#          'frozen hash brown potatoes': 3,
#          'bittersweet chocolate': 2,
#          'chocolate instant pudding and pie filling': 2,
#          'unsalted butter cut into pieces': 2,
#          'maple syrup or to taste': 2,
#          'graham crackers': 2,
#          'frozen blackberries': 2,
#          'egg yolk at room temperature': 2,
#          'fine sea salt': 2,
#          'plus   white sugar divided': 2,
#          'rainbow jimmie sprinkles': 2,
#          'marshmallows': 2,
#          'salt divided or to taste': 2,
#          'fullfat sour cream at room temperature': 2,
#          'instant espresso coffee powder': 2,
#          'whipped cream or as needed': 2,
#          'semisweet chocolate chopped': 2,
#          'hot water or more as needed': 2,
#          'sweetened whipped cream for serving': 2,
#          'coconut cream': 2,
#          'coconut sugar': 2,
#          'envelope unflavored gelatin': 2,
#          'pie shell baked': 2,
#          ...})

# %%
# Now I want to remove all prep words
prep_words = ['minced','freshly','ground','chopped','to taste','dried','shredded','ground','grated','beaten','crushed','extravirgin','crumbled',
              'or','diced','whipping','melted','lean','juiced','divided','skinless','boneless','halves','fresh','dry','plain','finely','roasted',
              'unsweetened','distilled','granulated','packed','cold','softened','light','sliced','at room temperature','for','frying','sweetened',
              'extra virgin','peeled''and deveined','seasoned','rinsed and','drained','as needed','cubes','semisweet','florets','thinly','lowsodium',
              'removed','cut','into','wedges','and rinsed','mix','nonstick','toasted','reducedsodium','stalks','instant','boiling','bunch','zested',
              'warm','peeled','pitted','dark','rolled','uncooked','cooked','creamy','halved','plus','granules','serving','skewers','prepared',
              'smashed','and diced','filets','more','split','lukewarm','bitesized','pieces','thawed','and drained','to','cover','stalk','pure',
              'with flour','fine','dry','jar','inch','of','thickcut','lessodium','low','long grain','prepared','drops','dashes','leaves','chunk',
              'chunks','garnish','full','fat','wooden skewers','about','bonein','cubed','bottle','envelope','refrigerated','raw','filet','and cubed',
              'caps','canned','and squeezed','shortgrain','glutinous','japanese sushistyle','crunchy','sprig','sprigs','natural','fullfat','very',
              'baked','regular','deepdish','fireroasted','sushi','japanese','chinese','scrubbed','pint','thin','seperated','rings','lengthwise',
              'head','seperated','marinated','quartered','cored','seeded','splash','coarsely','wholemilk','coarsely','miniature','dipping','meat'
              'complete','italianstyle','jarred','ball','torn','hardboiled','and','reducedfat','processed','lb','pickled','firm','soaked',
              'coarsely','flaked','flaky','lesssodium','roughly','if needed','cube','pressed','undrained','bittersweet','seperated','snipped',
              'dusting','warmed','sodium','lowfat','with juice','gallons','tenderizer','matchsticks','extrafirm','stick','cleaned','pimentostuffed',
              'longgrain','flavoring','stems','lowfat','rinsed','mixed','well','cutlets','reduced','blend','deveined','pounded','thickness',
              'curd','rainbow jimmie','chilled','pureed','quickcooking','fullycooked','soft','drizzling','squeezed','shelled','diagonally','strips',
              'parts','seperated','bitesize','broken','indian','clarified','cube','new','in water','minutes','debearded','crosswise','from',
              'squares parchement paper','ranchstyle','bibb','lightly','thick','and deveined','in water minutes','drizzling','cracked','thick',
              'fillets','freshlysqueezed','patted','links','piece','ripe','portions','such as','holiday','premium','milkfat','blanched','superfine',
              'xinch parchment paper','heads','extra','sunsulphured','frozen','lowersodium','reserved','jars','stemmed','trimmed','horizontally',
              's’moresized','strong','mashed','pan','matchstick','with','unsulphured','shaved','separated','sea','julienned','lacinato',
              'squares parchment paper','discarded','high','protein','good culture®','round','breaded','fully','chunky','saltfree','roast',
              'red pink white jimmie','canadian','mild','precut','dutch process','wholewheat','java chip flavored','dairy free','virgin','cooled',
              'almond breeze','blue diamond','highquality','crumbs','firmly','fatfree','nondairy','crumb','dash','lowmoisture partskim','oilpacked',
              'stewed','asian','jellied','silver skin','rounds','bag','scoop','brushing','additional greasing','topping','until smooth','morsels',
              'gel','box','rolling','buttery','arils','nonfat','deep','fluid','lump','milkfish','the','other cooking apples eighths','whitefleshed',
              'in shell','any color','complete','using holes on grater','optional toppings','kosher','root','additional','if','desired','aged',
              'dredging','sifted','milk choice','in half','aluminum foil','thirds','up','flakes','raos®','malk®','greasing','rubbed','vertically',
              'concentrate','soybased','loosely','loaf','sticks','genoa','italianseasoned','quarters','spears','in oil','fire','brewed','bulk',
              'turbinado','demerara','matchsticksize','montreal','knorr®','whisked','strained','sandwich','excess','base',
              'caramel pumpkin pie spice candy eyes','bits','waxed paper','pepperidge farm®','spread boursin®','other cooking apples eighths',
              'dots® honey mustard pretzels','centercut','red pink white jimmie','converted','snacksized bags cookies',
              '® teddy grahams® oreos® nilla wafers®','reese’s® peanut butter hershey’s® chocolate bar','stirfry','other temperature oil',
              'morefor','carton','several','thincut','nonpareil','bone in','doublecut','any chile pepper','louisianastyle','seafood seasoning',
              'chile de','cheesy','snaps','in adobo','hawaiianstyle','dice','mostly','sauceless','few hot sauce','spice','rack','membrane','oval',
              'jimmy dean® original hearty','crumbles','goodquality','flatleaf','top','oil cooking','stale italian','cured picnic','hickory chips',
              'readytoeat','country style','italian flat leaf','thickly','racks','chocolate curls','other','thickskinned','thinskinned','english']

# %%
# Write a function to remove all the prep words for the ingredients
def remove_prep_words(ingredient_list):
    
    pattern = pattern = r'(?<!\w)(?:' + '|'.join(re.escape(word) for word in prep_words) + r')(?!\w)' # regular expression pattern to remove prep_words
    cleaned = [re.sub(pattern, '', ingredient).strip() for ingredient in ingredient_list] # remove words and clean up extra whitespace
    
    return [re.sub(r'\s+', ' ', ing) for ing in cleaned if ing]

# %%
df['cleaned_ingredients'] = df['cleaned_ingredients'].apply(remove_prep_words)

# %%
# Confirm
df['cleaned_ingredients'][0]
# Out:
# ['butter',
#  'white sugar',
#  'chocolate graham crackers',
#  'chocolate',
#  'eggs',
#  'white sugar',
#  'brown sugar',
#  'water',
#  'salt',
#  'vanilla extract',
#  'unsalted butter',
#  'heavy cream',
#  'cream cheese',
#  'white sugar',
#  'vanilla extract',
#  'salt',
#  'heavy cream',
#  'chocolate sprinkles']

# %%
all_ingredients = [ingredient for sublist in df['cleaned_ingredients'] for ingredient in sublist]
ingredient_counts = Counter(all_ingredients)
ingredient_counts
# Out:
# Counter({'salt': 988,
#          'garlic': 738,
#          'black pepper': 515,
#          'olive oil': 499,
#          'water': 451,
#          'onion': 432,
#          'butter': 324,
#          'soy sauce': 302,
#          'eggs': 301,
#          'white sugar': 299,
#          'vegetable oil': 280,
#          'allpurpose flour': 263,
#          'salt black pepper': 261,
#          'milk': 209,
#          'ginger': 207,
#          'brown sugar': 187,
#          'unsalted butter': 176,
#          'cilantro': 174,
#          'vanilla extract': 168,
#          'heavy cream': 168,
#          'cayenne pepper': 162,
#          'parsley': 155,
#          'egg': 154,
#          'garlic powder': 151,
#          'lemon juice': 149,
#          'green onions': 149,
#          'cumin': 145,
#          'cornstarch': 140,
#          'parmesan cheese': 140,
#          'oregano': 137,
#          'red pepper': 130,
#          'chicken broth': 124,
#          'sesame oil': 118,
#          'chicken breast': 117,
#          'tomatoes': 116,
#          'red bell pepper': 115,
#          'beef': 112,
#          'cheddar cheese': 108,
#          'lemon': 108,
#          'basil': 107,
#          'green bell pepper': 93,
#          'carrots': 91,
#          'red onion': 90,
#          'cooking spray': 88,
#          'thyme': 88,
#          'cinnamon': 84,
#          'celery': 84,
#          'honey': 82,
#          'baking powder': 81,
#          'sour cream': 81,
#          'salt pepper': 81,
#          'mozzarella cheese': 80,
#          'chili powder': 78,
#          'paprika': 78,
#          'lime': 77,
#          'mayonnaise': 76,
#          'rice vinegar': 71,
#          'worcestershire sauce': 70,
#          'bacon': 68,
#          'chicken': 67,
#          'sugar': 64,
#          'lime juice': 64,
#          'tomato': 63,
#          'shrimp': 63,
#          'onion powder': 62,
#          'yellow onion': 62,
#          'white vinegar': 62,
#          'cream cheese': 59,
#          'canola oil': 59,
#          'nutmeg': 59,
#          'feta cheese': 58,
#          'chicken thighs': 58,
#          'spinach': 57,
#          'dijon mustard': 55,
#          'chicken breasts': 55,
#          'tomato paste': 54,
#          'fish sauce': 54,
#          'avocado': 53,
#          'mushrooms': 53,
#          'white wine': 53,
#          'onions': 53,
#          'italian seasoning': 53,
#          'green onion': 53,
#          'lemon zest': 52,
#          'sesame seeds': 52,
#          'turmeric': 51,
#          'coconut milk': 50,
#          'smoked paprika': 49,
#          'carrot': 48,
#          'broccoli': 47,
#          'cucumber': 47,
#          'coriander': 45,
#          'rosemary': 45,
#          'bread': 45,
#          'baking soda': 44,
#          'ketchup': 43,
#          'pork': 42,
#          'yogurt': 40,
#          'banana': 39,
#          'beef broth': 39,
#          'white onion': 39,
#          'bay': 39,
#          'potatoes': 38,
#          'black beans': 38,
#          'flour tortillas': 37,
#          'turkey': 37,
#          'strawberries': 36,
#          'orange juice': 36,
#          'lettuce': 36,
#          'cocoa powder': 35,
#          'corn tortillas': 35,
#          'tomato sauce': 35,
#          'white rice': 35,
#          'garam masala': 34,
#          'chicken stock': 34,
#          'confectioners sugar': 33,
#          'oil': 33,
#          'peanut butter': 33,
#          'cabbage': 33,
#          'ham': 32,
#          'shallot': 32,
#          'rice': 32,
#          'monterey jack cheese': 32,
#          'peanut oil': 32,
#          'oyster sauce': 32,
#          'chocolate chips': 31,
#          'taco seasoning': 30,
#          'balsamic vinegar': 29,
#          'mirin': 29,
#          'zucchini': 28,
#          'dill': 28,
#          'ice': 28,
#          'maple syrup': 27,
#          'red wine vinegar': 27,
#          'salsa': 27,
#          'white pepper': 27,
#          'curry powder': 27,
#          'apple cider vinegar': 26,
#          'shallots': 26,
#          'chives': 26,
#          'pineapple': 26,
#          'baby spinach': 26,
#          'sage': 25,
#          'bay leaf': 25,
#          'bean sprouts': 25,
#          'swiss cheese': 25,
#          'salmon': 24,
#          'ricotta cheese': 23,
#          'scallions': 23,
#          'powdered sugar': 22,
#          'egg yolks': 22,
#          'flour': 22,
#          'hot sauce': 22,
#          'garlic salt': 22,
#          'hamburger buns': 22,
#          'pizza sauce': 22,
#          'mint': 22,
#          'sake': 22,
#          'buttermilk': 21,
#          'chicken bouillon': 21,
#          'cherry tomatoes': 21,
#          'peanuts': 21,
#          'sharp cheddar cheese': 21,
#          'blueberries': 20,
#          'roma tomatoes': 20,
#          'hot pepper sauce': 20,
#          'salted butter': 19,
#          'pecans': 19,
#          'pizza dough': 19,
#          'greek yogurt': 19,
#          'rice wine vinegar': 19,
#          'sweet onion': 19,
#          'pepper': 19,
#          'condensed milk': 18,
#          'cottage cheese': 18,
#          'pork chops': 18,
#          'yellow bell pepper': 18,
#          'hoisin sauce': 18,
#          'provolone cheese': 18,
#          'jasmine rice': 18,
#          'almond extract': 17,
#          'mustard': 17,
#          'jalapeno pepper': 17,
#          'pepperoni': 17,
#          'sundried tomatoes': 17,
#          'vegetable broth': 17,
#          'white bread': 17,
#          'panko bread': 17,
#          'active yeast': 16,
#          'capers': 16,
#          'italian parsley': 16,
#          'water chestnuts': 16,
#          'spaghetti': 16,
#          'beef chuck': 16,
#          'kalamata olives': 16,
#          'quinoa': 16,
#          'romaine lettuce': 16,
#          'chocolate': 15,
#          'allspice': 15,
#          'all purpose flour': 15,
#          'pork tenderloin': 15,
#          'peas': 15,
#          'pork loin': 15,
#          'black olives': 15,
#          'limes': 15,
#          'chickpeas': 15,
#          'cumin seeds': 15,
#          'turkey neck giblets': 15,
#          'cream': 14,
#          'egg whites': 14,
#          'peaches': 14,
#          'snow peas': 14,
#          'cooking oil': 14,
#          'rice noodles': 14,
#          'halfandhalf': 14,
#          'oats': 13,
#          'orange': 13,
#          'red wine': 13,
#          'pork sausage': 13,
#          'marinara sauce': 13,
#          'jalapeño pepper': 13,
#          'vanilla yogurt': 13,
#          'vegetables': 13,
#          'lemons': 13,
#          'bok choy': 13,
#          'black peppercorns': 13,
#          'puff pastry': 12,
#          'corn': 12,
#          'hash brown potatoes': 12,
#          'green beans': 12,
#          'cod': 12,
#          'cajun seasoning': 12,
#          'wonton wrappers': 12,
#          'american cheese': 12,
#          'rotisserie chicken': 12,
#          'turkey breast': 12,
#          'espresso powder': 11,
#          'hot water': 11,
#          'bananas': 11,
#          'cotija cheese': 11,
#          'artichoke hearts': 11,
#          'orange zest': 11,
#          'raisins': 11,
#          'flank steak': 11,
#          'ginger paste': 11,
#          'asparagus': 11,
#          'ranch dressing': 11,
#          'iceberg lettuce': 11,
#          'avocados': 11,
#          'mexican cheese': 11,
#          'corn syrup': 10,
#          'almonds': 10,
#          'walnuts': 10,
#          'apple': 10,
#          'orange bell pepper': 10,
#          'parmigianoreggiano cheese': 10,
#          'greek seasoning': 10,
#          'pesto': 10,
#          'grape tomatoes': 10,
#          'marjoram': 10,
#          'evaporated milk': 10,
#          'slivered almonds': 10,
#          'tofu': 10,
#          'shiitake mushrooms': 10,
#          'sriracha sauce': 10,
#          'mango': 10,
#          'chicken breast meat': 10,
#          'green chile peppers': 10,
#          'cardamom': 10,
#          'lamb': 10,
#          'coconut': 10,
#          'white wine vinegar': 10,
#          'ribs celery': 10,
#          'poultry seasoning': 10,
#          'rice wine': 10,
#          'onion soup': 10,
#          'penne pasta': 10,
#          'nori': 10,
#          'lasagna noodles': 10,
#          'coconut oil': 9,
#          'olive spray': 9,
#          'baking spray': 9,
#          'pork shoulder': 9,
#          'kernel corn': 9,
#          'cauliflower': 9,
#          'deli ham': 9,
#          'yellow mustard': 9,
#          'herbes de provence': 9,
#          'panko breadcrumbs': 9,
#          'pineapple juice': 9,
#          'jalapeno peppers': 9,
#          'cornmeal': 9,
#          'breakfast sausage': 9,
#          'ramen noodles': 9,
#          'sherry': 9,
#          'brown rice': 9,
#          'halfandhalf cream': 9,
#          'yukon gold potatoes': 9,
#          'chipotle peppers sauce': 9,
#          'breadcrumbs': 9,
#          'pepper jack cheese': 9,
#          'kale': 9,
#          'taco shells': 9,
#          'blackberries': 8,
#          'egg yolk': 8,
#          'graham cracker': 8,
#          'raspberries': 8,
#          'whipped cream': 8,
#          'shortening': 8,
#          'liquid smoke': 8,
#          'mexican oregano': 8,
#          'jalapeno': 8,
#          'button mushrooms': 8,
#          'cremini mushrooms': 8,
#          'muffins': 8,
#          'vanilla ice cream': 8,
#          'strawberries hulled': 8,
#          'green peas': 8,
#          'beef sirloin': 8,
#          'bell pepper': 8,
#          'eggplant': 8,
#          'potato': 8,
#          'sriracha hot sauce': 8,
#          'baby carrots': 8,
#          'tortilla chips': 8,
#          'wasabi paste': 8,
#          'whipped': 7,
#          'marshmallows': 7,
#          'cream tartar': 7,
#          'fivespice powder': 7,
#          'prosciutto': 7,
#          'italian herb seasoning': 7,
#          'green bell peppers': 7,
#          'beer': 7,
#          'arugula': 7,
#          'dill weed': 7,
#          'milk ricotta cheese': 7,
#          'pita breads': 7,
#          'unbaked pie crust': 7,
#          'pie crust': 7,
#          'hot white rice': 7,
#          'red chile pepper': 7,
#          'thai basil': 7,
#          'kidney beans': 7,
#          'andouille sausage': 7,
#          'green olives': 7,
#          'chicken meat': 7,
#          'chuck': 7,
#          'plum tomatoes': 7,
#          'cranberries': 7,
#          'pinto beans': 7,
#          'tahini': 7,
#          'green cabbage': 7,
#          'spaghetti sauce': 7,
#          'almond milk': 7,
#          'poblano pepper': 7,
#          'russet potatoes': 7,
#          'potato starch': 7,
#          'sprinkles': 6,
#          'graham crackers': 6,
#          'coarse salt': 6,
#          'coleslaw': 6,
#          'gruyère cheese': 6,
#          'pork tenderloins': 6,
#          'barbecue sauce': 6,
#          'avocado oil': 6,
#          'cayenne': 6,
#          'gruyere cheese': 6,
#          'serrano peppers': 6,
#          'corn kernels': 6,
#          'table salt': 6,
#          'barbeque sauce': 6,
#          'yellow onions': 6,
#          'blue cheese': 6,
#          'red chili': 6,
#          'mozzarella': 6,
#          'french bread': 6,
#          'flour tortilla': 6,
#          'tap water': 6,
#          'apples': 6,
#          'half half': 6,
#          'cherries': 6,
#          'red cabbage': 6,
#          'grapeseed oil': 6,
#          'chilegarlic sauce': 6,
#          'vinegar': 6,
#          'red chile peppers': 6,
#          'garlic paste': 6,
#          'basmati rice': 6,
#          'ghee': 6,
#          'jalapeño peppers': 6,
#          'cumin seed': 6,
#          'horseradish': 6,
#          'red curry paste': 6,
#          'bamboo shoots': 6,
#          'red potatoes': 6,
#          'tarragon': 6,
#          'beef stock': 6,
#          'cannellini beans': 6,
#          'alfredo sauce': 6,
#          'skinon chicken thighs': 6,
#          'beef stew meat': 6,
#          'condensed cream chicken soup': 6,
#          'egg white': 5,
#          'red onions': 5,
#          'apple cider': 5,
#          'sauerkraut': 5,
#          'tamarind paste': 5,
#          'salted peanuts': 5,
#          'gochujang': 5,
#          'italian sausage': 5,
#          'red bell peppers': 5,
#          'condensed cream mushroom soup': 5,
#          'fajita seasoning': 5,
#          'bread flour': 5,
#          'parmigiano reggiano cheese': 5,
#          'peach': 5,
#          'cheese': 5,
#          'pecorino romano cheese': 5,
#          'caramel sauce': 5,
#          'milk greek yogurt': 5,
#          'selfrising flour': 5,
#          'udon noodles': 5,
#          'chili oil': 5,
#          'pork butt': 5,
#          'beef sirloin steak': 5,
#          'monosodium glutamate': 5,
#          'makrut lime': 5,
#          'white mushrooms': 5,
#          'red food coloring': 5,
#          'tomato puree': 5,
#          'cashews': 5,
#          'curry': 5,
#          'garbanzo beans': 5,
#          'roma tomato': 5,
#          'tomatoes green chiles': 5,
#          'creole seasoning': 5,
#          'lard': 5,
#          'smoked sausage': 5,
#          'celery seed': 5,
#          'cider vinegar': 5,
#          'mustard powder': 5,
#          'thai red curry paste': 5,
#          'panko': 5,
#          'guacamole': 5,
#          'dill pickle': 5,
#          'havarti cheese': 5,
#          'italian bread': 5,
#          'salad dressing': 5,
#          'steak seasoning': 5,
#          'phyllo dough': 5,
#          'pasta shells': 5,
#          'banana peppers': 5,
#          'everything bagel seasoning': 5,
#          'white miso paste': 5,
#          'lime zest': 5,
#          'coffee liqueur': 4,
#          'molasses': 4,
#          'almond flour': 4,
#          'irish cream liqueur': 4,
#          'rum': 4,
#          'unsalted pistachios': 4,
#          'beets': 4,
#          'vegetable shortening': 4,
#          'grain mustard': 4,
#          'sweet potato': 4,
#          'pork loin chops': 4,
#          'hot rice': 4,
#          'tomatoes green chilies': 4,
#          'smoked ham': 4,
#          'parmigianoreggiano': 4,
#          'romano cheese': 4,
#          'pork spareribs': 4,
#          'pepperoncini': 4,
#          'balsamic glaze': 4,
#          'sausage': 4,
#          'skim milk': 4,
#          'quesadilla cheese': 4,
#          'pita bread': 4,
#          'biscuits': 4,
#          'pepperoncini peppers': 4,
#          'refried beans': 4,
#          'tapioca starch': 4,
#          'orange liqueur': 4,
#          'strawberry preserves': 4,
#          'old fashioned oats': 4,
#          'orange marmalade': 4,
#          'butter margarine': 4,
#          'sugar snap peas': 4,
#          'matchstickcut carrots': 4,
#          'chili crisp': 4,
#          'green onions white green': 4,
#          'teriyaki sauce': 4,
#          'palm sugar': 4,
#          'napa cabbage': 4,
#          'curry paste': 4,
#          'ginger garlic paste': 4,
#          'paneer': 4,
#          'salami': 4,
#          'chicken tenders': 4,
#          'egg noodles': 4,
#          'poblano peppers': 4,
#          'green curry paste': 4,
#          'mussels': 4,
#          'sweet pickle relish': 4,
#          'feta': 4,
#          'sirloin': 4,
#          'pine nuts': 4,
#          'corn chips': 4,
#          'watercress': 4,
#          'butternut squash': 4,
#          'tzatziki sauce': 4,
#          'berries': 4,
#          'pistachios': 4,
#          'red enchilada sauce': 4,
#          'radishes': 4,
#          'jalapeño': 4,
#          'tilapia': 4,
#          'sherry vinegar': 4,
#          'soy milk': 4,
#          'miso paste': 4,
#          'rice flour': 4,
#          'black sesame seeds': 4,
#          'edamame': 4,
#          'chili beans': 4,
#          'beef tenderloin': 4,
#          'corn husks': 4,
#          'masa harina': 4,
#          'enchilada sauce': 4,
#          'chocolate syrup': 3,
#          'white chocolate chips': 3,
#          'quick oats': 3,
#          'almond butter': 3,
#          'cake flour': 3,
#          'cherry pie filling': 3,
#          'milk chocolate chips': 3,
#          'coconut cream': 3,
#          'unflavored gelatin': 3,
#          'chocolate wafer cookies': 3,
#          'pumpkin': 3,
#          'chestnuts': 3,
#          'tomatillos husks': 3,
#          'italian breadcrumbs': 3,
#          'baby back ribs': 3,
#          'liquid seasoning': 3,
#          'chipotle powder': 3,
#          'ancho chile powder': 3,
#          'chipotle pepper': 3,
#          'fontina cheese': 3,
#          'chili': 3,
#          'croutons': 3,
#          'bell peppers': 3,
#          'sharp white cheddar cheese': 3,
#          'hoagie rolls': 3,
#          'prebaked pizza crust': 3,
#          'crescent rolls': 3,
#          'colbyjack cheese': 3,
#          'red peppers': 3,
#          'milk yogurt': 3,
#          'vanilla pudding': 3,
#          'granny smith apples': 3,
#          'crescent roll dough': 3,
#          'brandy': 3,
#          'bourbon whiskey': 3,
#          'pie crusts': 3,
#          'spring onions': 3,
#          'baby corn': 3,
#          'ribeye steak': 3,
#          'chicken breast tenderloins': 3,
#          'cooking sherry': 3,
#          'shrimp tails': 3,
#          'sirloin steak': 3,
#          'scallops': 3,
#          'red lentils': 3,
#          'dinner rolls': 3,
#          'meat': 3,
#          'pork neck bones': 3,
#          'oranges': 3,
#          'artichokes': 3,
#          'seasoning salt': 3,
#          'portobello mushroom': 3,
#          'seasoning': 3,
#          'yellow cornmeal': 3,
#          'farfalle pasta': 3,
#          'corn oil': 3,
#          'thai chiles': 3,
#          'serrano pepper': 3,
#          'unsalted dryroasted peanuts': 3,
#          'unsalted peanuts': 3,
#          'queso fresco': 3,
#          'poppy seeds': 3,
#          'green apple': 3,
#          'kaiser rolls': 3,
#          'hot mustard': 3,
#          'venison': 3,
#          'tuna': 3,
#          'cucumbers': 3,
#          'goat cheese': 3,
#          'red quinoa': 3,
#          'salad greens': 3,
#          'caesar salad dressing': 3,
#          'golden raisins': 3,
#          'pear': 3,
#          'eggplants': 3,
#          'chicken leg': 3,
#          'flat leaf parsley': 3,
#          'oil sundried tomatoes': 3,
#          'olives': 3,
#          'bamboo': 3,
#          'white wine pinot grigio': 3,
#          'pasta': 3,
#          'fettuccine': 3,
#          'marsala wine': 3,
#          'vodka': 3,
#          'chia seeds': 3,
#          'black forest ham': 3,
#          'pancake': 3,
#          'vanilla bean paste': 3,
#          'mascarpone cheese': 3,
#          'pistachio cream': 3,
#          'beef bouillon': 3,
#          'mexican crema': 3,
#          'cantanzaro herbs': 3,
#          'halibut': 3,
#          'sweet chili sauce': 3,
#          'chorizo': 3,
#          'clams': 3,
#          'brussels sprouts': 3,
#          'pepitas': 3,
#          'imitation crabmeat': 3,
#          'peppers': 3,
#          'sourdough bread': 3,
#          'adobo seasoning': 3,
#          'queso asadero': 3,
#          'pork belly': 3,
#          'frenchfried onions': 3,
#          'tamari': 3,
#          'jalapenos': 3,
#          'hollandaise sauce': 3,
#          'chicken legs thighs wings': 3,
#          'ancho chiles': 3,
#          'salsa verde': 3,
#          'green chiles': 3,
#          'coconut water': 3,
#          'brown gravy': 3,
#          'baby portobello mushrooms': 3,
#          'vegetable stock': 3,
#          'great northern beans': 3,
#          'corned beef brisket': 3,
#          'baking potatoes': 3,
#          'potato gnocchi': 3,
#          'salted pistachios': 3,
#          'seaweed': 3,
#          'hot coffee': 2,
#          'chocolate pudding pie filling': 2,
#          'hawaiian sweet rolls': 2,
#          'chocolate cookies': 2,
#          'espresso coffee powder': 2,
#          'coconut sugar': 2,
#          'pie shell': 2,
#          'greekstyle yogurt': 2,
#          'devils food cake': 2,
#          'white cake': 2,
#          'ice water': 2,
#          'pumpkin puree': 2,
#          'pretzels': 2,
#          'caramel': 2,
#          'slider buns': 2,
#          'smoked gouda': 2,
#          'cranberry sauce': 2,
#          'figs': 2,
#          'chicken broth stock': 2,
#          'bacon grease': 2,
#          'rosemary rosemary': 2,
#          'cherry cola': 2,
#          'hot chile peppers': 2,
#          'buttermilk biscuits': 2,
#          'veal': 2,
#          'baby back pork ribs': 2,
#          'hungarian sweet paprika': 2,
#          'hot italian sausage': 2,
#          'pizza crust': 2,
#          'hot honey': 2,
#          'summer squash': 2,
#          'chicken nuggets': 2,
#          'ranch seasoning': 2,
#          'pomegranate': 2,
#          'honeycrisp apples': 2,
#          'apple pie': 2,
#          'yellow cake': 2,
#          'nectarines': 2,
#          'plums': 2,
#          'fruit': 2,
#          'crackers': 2,
#          'candied ginger': 2,
#          'snap peas': 2,
#          'caramel ice cream': 2,
#          'sweet thai chili sauce': 2,
#          'red chili pepper': 2,
#          'black white sesame seeds': 2,
#          'vermicelli noodles': 2,
#          'chili garlic sauce': 2,
#          'shaoxing wine': 2,
#          'green pepper': 2,
#          'coconut aminos': 2,
#          'arrowroot powder': 2,
#          'green bell pepper squares': 2,
#          'white cooking wine': 2,
#          'celery ribs': 2,
#          'jalapeño chile pepper': 2,
#          'lamb shoulder': 2,
#          'serrano chile pepper': 2,
#          'tandoori masala': 2,
#          'lamb chops': 2,
#          'saffron': 2,
#          'fenugreek': 2,
#          'green chile pepper': 2,
#          'cardamom pods': 2,
#          'cashew': 2,
#          'mustard seed': 2,
#          'redskinned potatoes': 2,
#          'cumin powder': 2,
#          'red kidney beans': 2,
#          'tomato juice': 2,
#          'peppercorns': 2,
#          'fish stock': 2,
#          'beef steaks': 2,
#          'crab': 2,
#          'grits': 2,
#          'chitterlings': 2,
#          'saltine crackers': 2,
#          'pork liver': 2,
#          'rump': 2,
#          'cooking wine': 2,
#          'pickle relish': 2,
#          'crawfish tails': 2,
#          'fettuccine pasta': 2,
#          'lemon pepper': 2,
#          'chiligarlic sauce': 2,
#          'turkey chicken': 2,
#          'crabmeat': 2,
#          'pandan': 2,
#          'rice vermicelli': 2,
#          'tiger prawns': 2,
#          'yellow curry powder': 2,
#          'mahi mahi': 2,
#          'pad thai rice noodles': 2,
#          'birds eye chile': 2,
#          'thai peanut sauce': 2,
#          'brioche hamburger buns': 2,
#          'gouda cheese': 2,
#          'adobo sauce chipotle peppers': 2,
#          'pico de gallo': 2,
#          'turkey gravy': 2,
#          'truffle oil': 2,
#          'bison': 2,
#          'pickles': 2,
#          'rotini pasta': 2,
#          'champagne vinegar': 2,
#          'bow tie pasta': 2,
#          'wood ear mushrooms': 2,
#          'rotelle pasta': 2,
#          'yellow corn kernels': 2,
#          'flat iron steak': 2,
#          'plum tomato': 2,
#          'gorgonzola cheese': 2,
#          'green leaf lettuce': 2,
#          'cherry tomato': 2,
#          'oregano oregano': 2,
#          'linguine pasta': 2,
#          'macaroni': 2,
#          'yellow potatoes': 2,
#          'chicken broth vegetable broth': 2,
#          'beef short ribs': 2,
#          'brown mushrooms': 2,
#          'chicken beef broth': 2,
#          'asiago cheese': 2,
#          'ziti pasta': 2,
#          'arborio rice': 2,
#          'leek': 2,
#          'bay scallops': 2,
#          'castelvetrano olives': 2,
#          'sweet italian sausage': 2,
#          'fennel seeds': 2,
#          'onion salt': 2,
#          'condensed chicken broth': 2,
#          'pinot grigio': 2,
#          'tortilla': 2,
#          'syrup': 2,
#          'agave syrup': 2,
#          'maraschino cherries': 2,
#          'halloumi cheese': 2,
#          'pumpkin pie': 2,
#          'hawaiian rolls': 2,
#          'tequila': 2,
#          'celery salt': 2,
#          'tomato salsa': 2,
#          'chocolate hazelnut spread': 2,
#          'hash browns': 2,
#          'pomegranate juice': 2,
#          'sambal oelek': 2,
#          'chives green onions': 2,
#          'oil sundried tomato': 2,
#          'crab meat': 2,
#          'salmon skin': 2,
#          'butter beans': 2,
#          'oyster mushrooms': 2,
#          'hot chili sauce': 2,
#          'spaghetti squash': 2,
#          'hot chile pepper': 2,
#          'sunflower seeds': 2,
#          'nori seaweed': 2,
#          'chile paste': 2,
#          'soba noodles': 2,
#          'leeks': 2,
#          'gyoza wrappers': 2,
#          'curry roux': 2,
#          'shiitake mushroom': 2,
#          'center pork chops': 2,
#          'peas carrots': 2,
#          'sweet cooking wine': 2,
#          'ramen noodles seasoning': 2,
#          'kombu': 2,
#          'bonito': 2,
#          'white sesame seeds': 2,
#          'deli turkey': 2,
#          'beef hotdogs': 2,
#          'cheese sauce': 2,
#          'lentils': 2,
#          'hot dog buns': 2,
#          'garlic bread': 2,
#          'tomato sauce marinara sauce': 2,
#          'buffalo sauce': 2,
#          'kimchi': 2,
#          'chicken legs thighs': 2,
#          'spring roll wrappers': 2,
#          'york strip steak': 2,
#          'lumpia wrappers': 2,
#          'beef steak': 2,
#          'corned beef': 2,
#          'chorizo de bilbao': 2,
#          'luncheon meat': 2,
#          'achiote powder': 2,
#          'coffee': 2,
#          'smoked kielbasa sausage': 2,
#          'kiwi': 2,
#          'mexican seasoning': 2,
#          'guajillo chile peppers': 2,
#          'tomato powder': 2,
#          'buttermilk powder': 2,
#          'cheese powder': 2,
#          'skirt steaks': 2,
#          'arbol peppers': 2,
#          'old bay': 2,
#          'chili seasoning': 2,
#          'salad shrimp': 2,
#          'lobster tails': 2,
#          'white corn tortillas': 2,
#          'cream chicken soup': 2,
#          'anchovy': 2,
#          'baby potatoes': 2,
#          'italian cheese': 2,
#          'flax seeds': 2,
#          'vanilla greek yogurt': 2,
#          'strawberry': 2,
#          'mangos': 2,
#          'cantaloupe': 2,
#          'flaxseed meal': 2,
#          'chamoy': 2,
#          'chililime seasoning': 2,
#          'lemonpepper seasoning': 2,
#          'champagne': 2,
#          'stuffing': 2,
#          'celery in': 2,
#          'turkey legs': 2,
#          'turkey bacon': 2,
#          'green onion cilantro': 2,
#          'andouille smoked sausage': 2,
#          'tomatoes basil garlic oregano': 2,
#          'cheese tortellini': 2,
#          'black mushrooms': 2,
#          'rendered turkey': 2,
#          'lower beef broth': 2,
#          'sriracha': 2,
#          'creme fraiche': 2,
#          'condensed french onion soup': 2,
#          'prime rib': 2,
#          'au jus gravy': 2,
#          'cheese ravioli': 2,
#          'dumpling wrappers': 2,
#          'biscuit dough': 2,
#          'marshmallow cream': 2,
#          'chai': 2,
#          'dish pie crust': 2,
#          'furikake': 2,
#          'cauliflower rice': 2,
#          'mayo dressing': 2,
#          'chocolate cake': 2,
#          'pea pods': 2,
#          'shichimi togarashi': 2,
#          'aleppo chili': 2,
#          'bagels': 2,
#          'smoked salmon': 2,
#          'white hominy': 2,
#          'bread crusts': 2,
#          'mignon steaks': 2,
#          'chocolate graham crackers': 1,
#          'chocolate sprinkles': 1,
#          'cremefilled chocolate cookies': 1,
#          'cocoa powder sprinkling': 1,
#          'whipped cool whip®': 1,
#          'chocolate covered espresso beans': 1,
#          'cocoa': 1,
#          'chocolate squares': 1,
#          'gingerbread men cookies': 1,
#          'little debbie® christmas tree brownies': 1,
#          'candycoated chips': 1,
#          'pretzels strawberries cookies apples': 1,
#          'chocolate candy bars': 1,
#          'nutter butter® teddy grahams® oreos® nilla wafers®': 1,
#          'chocolate candy bar': 1,
#          'neutral oil': 1,
#          'stout beer': 1,
#          'hot butter': 1,
#          'flour cake': 1,
#          'applesauce': 1,
#          'cashew butter': 1,
#          'pastry flour': 1,
#          'chocolate chip cookie dough': 1,
#          'vanilla gelato': 1,
#          'chocolate drizzle': 1,
#          'creme chocolate cookies': 1,
#          'spray': 1,
#          'vanilla almondmilk': 1,
#          'coconut flour': 1,
#          'creamfilled chocolate cookies': 1,
#          'chocolate frosting': 1,
#          'vanilla frosting': 1,
#          'unsalted matzo boards': 1,
#          'baileys® irish cream': 1,
#          'chocolate cookie crust': 1,
#          'coffee ice cream': 1,
#          'hot fudge': 1,
#          'pink food coloring': 1,
#          'bar chocolate': 1,
#          'unsalted butter laminating dough': 1,
#          'pretzel': 1,
#          'chocolate candies': 1,
#          'candy corn': 1,
#          'espresso': 1,
#          'walnuts hazelnuts': 1,
#          'vanilla cookies': 1,
#          'apple chips': 1,
#          'cacao chocolate': 1,
#          'chestnut spread': 1,
#          'chipotle peppers': 1,
#          'adobo sauce': 1,
#          'honey agave syrup': 1,
#          'smoked pork': 1,
#          'fuji apples': 1,
#          'shallot chive cheese': 1,
#          'chipotle chili powder': 1,
#          'apricots': 1,
#          'honey mustard pretzels': 1,
#          'rib pork chops': 1,
#          'smoked pork chops': 1,
#          'juniper berries': 1,
#          'pulled pork': 1,
#          'black beans kidney beans': 1,
#          'corn bread': 1,
#          'bacon grease shortening': 1,
#          'country ham': 1,
#          'hatch green chiles hot': 1,
#          'avocado oil butter': 1,
#          'salted cashews': 1,
#          'parsley scallions': 1,
#          'liquid hickory smoke': 1,
#          'lard vegetable oil': 1,
#          'brown sugar barbecue rub': 1,
#          'sweet spicy barbecue sauce': 1,
#          'apricot preserves': 1,
#          'guajillo ancho chili pepper': 1,
#          'mexico chili powder': 1,
#          'chipotle': 1,
#          'water chicken broth': 1,
#          'white yellow onion': 1,
#          'muffin buttered': 1,
#          'parsley cilantro': 1,
#          'white wine chicken stock': 1,
#          'sweet sour sauce': 1,
#          'brown white mushrooms': 1,
#          'bucatini': 1,
#          'milk beef broth': 1,
#          'fennel seed': 1,
#          'pork ribs': 1,
#          'ham steak': 1,
#          'ham rump portion': 1,
#          'dijon honey mustard': 1,
#          'pork butt steaks': 1,
#          'brown mustard': 1,
#          ...})

# %% [markdown]
# ### Create clusters for total_time, calories, carbs, proteins, fats

# %%
# total_time

def categorize_time(total_time):
   
    if total_time <= 30:
        return '30 minutes or less!'
    elif 31 <= total_time <= 60:
        return 'Hour of less!'
    elif 61 <= total_time <= 120:
        return 'Long recipes!'
    else:
        return 'Livin in the kitchin!'


# Assuming df has a column 'total_time' which stores the time in minutes
df['time_category'] = df['total_time'].apply(categorize_time)

# %%
df.head(3)
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 2          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 3         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 2      1058   65    113       10
# 3       824   55     80        9
#
#                                  cleaned_ingredients          time_category
# 0  [butter, white sugar, chocolate graham cracker...  Livin in the kitchin!
# 2  [chocolate chips, cremefilled chocolate cookie...    30 minutes or less!
# 3  [cooking spray, allpurpose flour, white sugar,...  Livin in the kitchin!

# %%
# calories column

def categorize_calories(calories):
   
    if calories <= 300:
        return 'Low Cal!'
    elif 301 <= calories <= 600:
        return 'Average Cal!'
    elif 601 <= calories <= 1000:
        return 'High Cal!'
    else:
        return "Don't Look!"


# Assuming df has a column 'total_time' which stores the time in minutes
df['calorie_category'] = df['calories'].apply(categorize_calories)

# %%
df.head(3)
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 2          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 3         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 2      1058   65    113       10
# 3       824   55     80        9
#
#                                  cleaned_ingredients          time_category  \
# 0  [butter, white sugar, chocolate graham cracker...  Livin in the kitchin!
# 2  [chocolate chips, cremefilled chocolate cookie...    30 minutes or less!
# 3  [cooking spray, allpurpose flour, white sugar,...  Livin in the kitchin!
#
#   calorie_category
# 0     Average Cal!
# 2      Don't Look!
# 3        High Cal!

# %%
# fats column

def categorize_fats(fat):
   
    if fat <= 15:
        return 'Low Fat!'
    elif 16 <= fat <= 45:
        return 'Average Fat!'
    else:
        return "High Fat!"


# Assuming df has a column 'total_time' which stores the time in minutes
df['fat_category'] = df['fat'].apply(categorize_fats)

# %%
df.head(3)
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 2          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 3         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 2      1058   65    113       10
# 3       824   55     80        9
#
#                                  cleaned_ingredients          time_category  \
# 0  [butter, white sugar, chocolate graham cracker...  Livin in the kitchin!
# 2  [chocolate chips, cremefilled chocolate cookie...    30 minutes or less!
# 3  [cooking spray, allpurpose flour, white sugar,...  Livin in the kitchin!
#
#   calorie_category  fat_category
# 0     Average Cal!  Average Fat!
# 2      Don't Look!     High Fat!
# 3        High Cal!     High Fat!

# %%
# carbs column

def categorize_carbs(carbs):
   
    if carbs <= 25:
        return 'Low Carbs!'
    elif 26 <= carbs <= 80:
        return 'Average Carbs!'
    else:
        return "High Carbs!"


# Assuming df has a column 'total_time' which stores the time in minutes
df['carbs_category'] = df['carbs'].apply(categorize_carbs)

# %%
df.head(3)
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 2          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 3         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 2      1058   65    113       10
# 3       824   55     80        9
#
#                                  cleaned_ingredients          time_category  \
# 0  [butter, white sugar, chocolate graham cracker...  Livin in the kitchin!
# 2  [chocolate chips, cremefilled chocolate cookie...    30 minutes or less!
# 3  [cooking spray, allpurpose flour, white sugar,...  Livin in the kitchin!
#
#   calorie_category  fat_category  carbs_category
# 0     Average Cal!  Average Fat!  Average Carbs!
# 2      Don't Look!     High Fat!     High Carbs!
# 3        High Cal!     High Fat!  Average Carbs!

# %%
# protein column

def categorize_proteins(proteins):
   
    if proteins <= 25:
        return 'Low Protein!'
    elif 26 <= proteins <= 80:
        return 'Average Protein!'
    else:
        return "High Protein!"


# Assuming df has a column 'total_time' which stores the time in minutes
df['protein_category'] = df['protein'].apply(categorize_proteins)

# %%
df.head()
# Out:
#                                   title  \
# 0                  French Silk Pie Bars
# 2  No Bake Espresso Martini Cheesecakes
# 3                         Blackout Cake
# 4           Sleeping Gingerbread Treats
# 5        Little Debbie Brownie Tree Dip
#
#                                                intro  prep_time  cook_time  \
# 0  These French silk pie bars are sooo good. They...       40.0       20.0
# 2  These no bake espresso martini cheesecakes hav...       20.0        5.0
# 3  Blackout cake is a moist and tender cake with ...       40.0       20.0
# 4                            Shhhh they're sleeping!       15.0       15.0
# 5  Turn your favorite sweet treat into the best h...       15.0        NaN
#
#    total_time  servings                                         recipe_url  \
# 0         300      16.0  https://www.allrecipes.com/french-silk-pie-bar...
# 2          25       6.0  https://www.allrecipes.com/no-bake-espresso-ma...
# 3         135      12.0  https://www.allrecipes.com/blackout-cake-recip...
# 4          30       9.0  https://www.allrecipes.com/sleeping-gingerbrea...
# 5         135       6.0  https://www.allrecipes.com/little-debbie-brown...
#
#    calories  fat  carbs  protein  \
# 0       405   31     28        5
# 2      1058   65    113       10
# 3       824   55     80        9
# 4       231   12     29        3
# 5       534   31     61        6
#
#                                  cleaned_ingredients          time_category  \
# 0  [butter, white sugar, chocolate graham cracker...  Livin in the kitchin!
# 2  [chocolate chips, cremefilled chocolate cookie...    30 minutes or less!
# 3  [cooking spray, allpurpose flour, white sugar,...  Livin in the kitchin!
# 4  [puff pastry, chocolate squares, gingerbread m...    30 minutes or less!
# 5  [little debbie® christmas tree brownies, cream...  Livin in the kitchin!
#
#   calorie_category  fat_category  carbs_category protein_category
# 0     Average Cal!  Average Fat!  Average Carbs!     Low Protein!
# 2      Don't Look!     High Fat!     High Carbs!     Low Protein!
# 3        High Cal!     High Fat!  Average Carbs!     Low Protein!
# 4         Low Cal!      Low Fat!  Average Carbs!     Low Protein!
# 5     Average Cal!  Average Fat!  Average Carbs!     Low Protein!

# %%
df.to_csv('../data/recipes_cleaned.csv', index=False)
